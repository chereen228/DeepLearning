# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("crawl/naver_cafe_ssal_contents_2019_전처리완.xlsx")
df.head(2)
# Out:
#                   title   nickname        date  \
# 0   다운타운 **름 썩은곰팡이 쌀 ..  taniamama  2019.01.30
# 1  쌀마들렌 3종(모카, 허니유자, 쑥)        쪼로밋  2019.01.08
#
#                                              content  \
# 0  안녕하세요,,18개월 아기 기르는 엄마입니다..이럴땐 어떻게 대처 해야할지 모르겠어...
# 1  엄청 오랜만에 베이킹 하는거 같네용..ㅠㅠ버터도 거의바닥이었고..가루류도 없는데다가...
#
#                                             comments
# 0  요즘 여기 쌀 할인하던데 같은쌀일까요||전 2018년 10월에 풍 * 햅쌀 이라고 ...
# 1  쑥 마들렌!! 완전 맛나겠다용~~~쑥향 솔솔~~😍||콩가루 묻힐까하다가 깔끔한게 나...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9554 entries, 0 to 9553
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     9554 non-null   object
#  1   nickname  9554 non-null   object
#  2   date      9554 non-null   object
#  3   content   9549 non-null   object
#  4   comments  9036 non-null   object
# dtypes: object(5)
# memory usage: 373.3+ KB

# %%
# Null값 제거
df = df.dropna(axis=0, how='any', subset=['content'])
df = df.reset_index()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9549 entries, 0 to 9548
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     9549 non-null   int64
#  1   title     9549 non-null   object
#  2   nickname  9549 non-null   object
#  3   date      9549 non-null   object
#  4   content   9549 non-null   object
#  5   comments  9032 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 447.7+ KB

# %% [markdown]
# ## 문장 나누기

# %%
import re

# %%
q = " "
for i in range(9549):
    q += str(df['content'][i])

# %%
# 문장어미 구분자 대치
q = q.replace('네요','네요||-||').replace('하죠','하죠||-||').replace('데요','데요||-||').replace('이네요','이네요||-||')
q = q.replace('네요.','네요||-||').replace('되죠','되죠||-||').replace('대요','대요||-||').replace('이요','이요||-||')
q = q.replace('돼요.','돼요||-||').replace('되요','되요||-||').replace('다닙니다','다닙니다||-||').replace('입니다','입니다||-||')
q = q.replace('입니다.','입니다||-||').replace('니다','니다||-||').replace('중입니다','중입니다||-||').replace('입니다','입니다||-||')
q = q.replace('나요.','나요||-||').replace('어요','어요||-||').replace('까요','까요||-||').replace('에요','에요||-||')
q = q.replace('이에요','이에요||-||').replace('봐요','봐요||-||').replace('아요.','아요||-||').replace('와요','와요||-||')
q = q.replace('해요','해요||-||').replace('려요','려요||-||').replace('구요','구요||-||').replace('고요','고요||-||')
q = q.replace('죠','죠||-||').replace(':)','').replace('더라','더라||-||').replace('게요','게요||-||').replace('께요','께요||-||').replace('세요','세요||-||').replace('든요','든요||-||').replace('예요','예요||-||').replace('서요','서요||-||')

# %%
#특수문자 제거
q = q.replace('.','').replace('?','').replace('~','').replace('!','').replace('^','').replace('#','').replace('★','').replace('ㅋ','').replace('ㅜ','').replace('ㅠ','').replace('ㅎ','').replace('ㅏ','').replace('ㅡ','')

# %%
p = q.split('||-||')
type(p)
# Out:
# list

# %%
p
# Out:
# [' 안녕하세요',
#  ',,18개월 아기 기르는 엄마입니다',
#  '',
#  '',
#  '이럴땐 어떻게 대처 해야할지 모르겠어서 올려봐요',
#  '보통 6개월에 한번 사던쌀이 아들이 같이 밥을 먹기 시작하면서 3개월에 한번 삽니다',
#  '늘 같은곳에 보관해도 아무문제 없었고이번문제의 쌀은 2번째 구매해 먹어봤어요',
#  '쌀을 뜯고 얼마도지않아 쌀을 씻을때 부서지는 현상이 자주일어나더니3/1쯤 먹으니 누렇게 변색된 쌀들이 뭉쳐서 10센트 만한 크기로 가끔 보였습니다',
#  '그때만해도 대수롭지 않게 골라내고 밥을 했었는데 이제 거진 쌀을 다 먹어갈때쯤 오늘 쌀을 뜨는데깜짝 놀랐어요',
#  '쌀이 쌀봉지 바닥에 어른 손바닥 보다 크게 눌러붙어 곰팡이가 생겨있고 그동안 봐왔던 누렇게 변색된 쌀들이 뭉탱이로 썩어 있었습니다',
#  '이걸 지금까지 먹은거야 싶어**름 에 전화넣으니커스터머 서비스 전화받으신 분이 사과도없이 어디에 보관했냐며 씽크대옆 수납장에 보관했다했는데 싱크대 아래는 안된다며씽크대 옆인데요',
#  ' 하니아기먹는쌀은 조금더 좋은거사먹이라며경기미를 추천해주시는데경기미 돌이 가끔 나와 안먹는다니아무말씀 없이 일단 가지고오랍니다',
#  '그래서 아기랑 가지고 갔어요',
#  '\xa0**름 에 앞면있는분들이 조금 계셔서 그전에 쥐파먹은김도 그냥 넘어가구 곰팡이핀 생선도 그냥 넘어가고 배추도 갈라보니 썩은것도 그냥 넘어가고 했는데 이번쌀은 못참겠더군요\xa0커스터머에 가지고가니 아침조에너 저녁조로 바뀌는사람한테 전달도 안되있어 다시설명 해야했고갑자기 키작고 다소 어려보이시는 남자분이 오시더니저를 응대하더군요\xa0그분첫마디도 역시 보관을 어디다 하셨냐며그래서 제가 어디다했던 이런적이 한번도 없었고 이런쌀인지 모르고 지금까지 먹었는데 사과가 먼저죠',
#  ' 하니 사과안합니다',
#  '슬슬 열이 받는데 그 남자분 저보고 그럼 나머지 쌀은 어딨냐며 묻네요',
#  '황당하여라기분이 너무상하면서 화가나더라',
#  '구요',
# ...

# %%
#re.split('[.!?]', q2)

# %%
p_df = pd.DataFrame(p)
p_df.head()
# Out:
#                             0
# 0                       안녕하세요
# 1         ,,18개월 아기 기르는 엄마입니다
# 2
# 3
# 4  이럴땐 어떻게 대처 해야할지 모르겠어서 올려봐요

# %%
p_df.to_csv('sentence_cafe2019_2.csv', encoding='utf-8-sig')

# %%
df = pd.read_csv('sentence_cafe2019.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34958 entries, 0 to 34957
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     34958 non-null  int64
#  1   sentence  34958 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 546.3+ KB

# %%
df = df.dropna(axis=0, how='any', subset=['sentence'])
df = df.reset_index()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34958 entries, 0 to 34957
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   level_0   34958 non-null  int64
#  1   index     34958 non-null  int64
#  2   sentence  34958 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 819.5+ KB

# %%
# 데이터 다시저장
df.to_csv('2019cafe_sentences.csv', encoding='utf-8-sig')

# %%
df = pd.read_csv('2019cafe_sentences.csv')
df.head()
# Out:
#    index                                        sentence
# 0      0                                           안녕하세요
# 1      1                             ,,18개월 아기 기르는 엄마입니다
# 2      2                      이럴땐 어떻게 대처 해야할지 모르겠어서 올려봐요
# 3      3  보통 6개월에 한번 사던쌀이 아들이 같이 밥을 먹기 시작하면서 3개월에 한번 삽니다
# 4      4      늘 같은곳에 보관해도 아무문제 없었고이번문제의 쌀은 2번째 구매해 먹어봤어요

# %%
# 이상값 지우기
cava=df['sentence'].value_counts()
idvali=cava[cava >= 10].index.tolist()
idvali
# Out:
# ['구요',
#  '고요',
#  '안녕하세요',
#  '360° Video도움말 MULTI TRACK멀티트랙의 트랙별 영상은 우측 관련영상에서 볼 수 있습니다',
#  '5분 이상 소요될 수 있으며, 영상의 길이에 따라 소요 시간은 달라집니다',
#  'SNS 공유소스 코드Band Twitter Facebook Blog CafeURL 주소복사HTML 소스544 x 306740 x 416936 x 5261280 x 720복사Flash 미지원으로 Object 코드 퍼가기 기능은 더 이상 지원되지않습니다',
#  '#NAME?',
#  '감사합니다',
#  ' 감사합니다',
#  ' 안녕하세요',
#  ' Loading player_likesound_mutesound_mutesound_volume2sound_volume3 [x]Player Size:0 x 0Current Resolution:0PMax Abr Resolution:0PProtocol:hlsCurrent Bandwidth:Average Bandwidth:Buffer Health:Frame Drop Rate:0/0 도움말라이센스Video Statistic Version 41748 (HLS)Build Date (2020/2/12)NAVER Corp     동영상 인코딩 중입니다',
#  '당신의\xa0한마디가 카페를 만들어갑니다',
#  '필요하신분 가져가세요',
#  ')※질문이 아닌글을 남기시면\xa0게시글 이동요청후 글이 삭제됩니다',
#  '게시물에\xa0주요내용이 없는 외부링크 공유 게시물은 삭제될 수 있습니다',
#  '원활한 카페 운영을 위해 이해와 협조 부탁드립니다']

# %%
df2 = df
for i in idvali:
    df2 = df2[df2['sentence'] != i]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33219 entries, 1 to 34957
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     33219 non-null  int64
#  1   sentence  33219 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 778.6+ KB

# %%
df2.to_csv('2019cafe_sentences_2.csv', encoding='utf-8-sig')

# %%
data = pd.read_csv('2019cafe_sentences_2.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32688 entries, 0 to 32687
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     32688 non-null  int64
#  1   sentence  32688 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 510.9+ KB

# %%
data.to_csv('2019cafe_sentences_re.csv', encoding='utf-8-sig')

# %% [markdown]
# ## 카테고리 별 분리

# %%
df = pd.read_csv('2019cafe_sentences_re.csv')
df
# Out:
#        index                                           sentence
# 0          0                                ,,18개월 아기 기르는 엄마입니다
# 1          1                         이럴땐 어떻게 대처 해야할지 모르겠어서 올려봐요
# 2          2     보통 6개월에 한번 사던쌀이 아들이 같이 밥을 먹기 시작하면서 3개월에 한번 삽니다
# 3          3         늘 같은곳에 보관해도 아무문제 없었고이번문제의 쌀은 2번째 구매해 먹어봤어요
# 4          4  쌀을 뜯고 얼마도지않아 쌀을 씻을때 부서지는 현상이 자주일어나더니3/1쯤 먹으니 누...
# ...      ...                                                ...
# 32683  32683       구매하실분들은 인터넷 쇼핑몰 특성상 감수 또는 주의을 해서 구매 하시기 바랍니다
# 32684  32684                   여기 상품 올려 주시는분이랑 판매자랑은 아무연관이 없습니다
# 32685  32685           제품및 배송 문제점에 대해서는 해당 물품 판매사이트에 연락 하셔야 합니다
# 32686  32686   여기게시판은 비상업적으로 운영 되며 상업적 목적의 상품 노출및 광고는 제제 대상이...
# 32687  32687   쌀튀밥 두개 (유통기한 2020317)어그 130사이즈(사용감 잇네용)검정 운동화...
#
# [32688 rows x 2 columns]

# %%
# 세 문장씩 합치기

#for i in range(31177):
 #   df_sen['three'][i] = df_sen['sentence'].iloc[i:i+3].sum()
#print(df_sen)

# %%
"""k = 0
for i in range(1, 4108):
    df.iloc[i-1:i+2,:]
    i = baby_df['index'][k]
    k = k+1"""

# %%
# 아이를 위한 레시피 콘텐츠
baby_df = df.loc[df['sentence'].str.contains('이유식|아이|아기|애기|아가|미음|분유')]
baby_df
# Out:
#        index                                           sentence
# 0          0                                ,,18개월 아기 기르는 엄마입니다
# 8          8   하니아기먹는쌀은 조금더 좋은거사먹이라며경기미를 추천해주시는데경기미 돌이 가끔 나와...
# 9          9                                    그래서 아기랑 가지고 갔어요
# 31        31  앞으로 마들렌은 쌀가루로 하는걸로 결정내일부터 다시 애기들 어린이집 가는데벌써 행복합니다
# 74        74   어제 마*컬*에서 향미쌀을 팔길래 이런거 아닐까싶어서 시켰는데 맞아요밥냄새부터 달...
# ...      ...                                                ...
# 32662  32662                       )이유식 초기로 쌀가루 받은거로 10일 정도 했어요
# 32664  32664                                     힙 이유식을 선물 받았어요
# 32669  32669   불린쌀로 먼저 찌고 갈으래는데 어른들 해먹으려고 쌀밥 해노은거를 바로 갈아도 상관...
# 32679  32679                                분유스푼으로 쌀가루 몇그램 나올까요
# 32687  32687   쌀튀밥 두개 (유통기한 2020317)어그 130사이즈(사용감 잇네용)검정 운동화...
#
# [4107 rows x 2 columns]

# %%
coindex=baby_df.index
list(coindex)
# Out:
# [0,
#  8,
#  9,
#  31,
#  74,
#  75,
#  91,
#  122,
#  123,
#  124,
#  125,
#  130,
#  131,
#  132,
#  153,
#  163,
#  168,
#  180,
#  216,
#  232,
#  252,
#  255,
#  284,
#  294,
#  298,
#  306,
#  320,
#  321,
#  344,
#  348,
#  354,
#  363,
#  372,
#  422,
#  435,
#  449,
#  469,
#  481,
#  482,
#  485,
#  488,
#  531,
#  558,
#  574,
#  577,
#  578,
#  579,
#  582,
#  583,
#  621,
#  622,
#  623,
#  624,
#  626,
#  627,
#  644,
#  647,
#  652,
#  656,
#  663,
#  698,
#  708,
#  712,
#  716,
#  718,
#  719,
#  732,
#  734,
#  737,
#  738,
#  739,
#  740,
#  742,
#  745,
#  747,
#  787,
#  800,
#  825,
#  827,
#  833,
#  834,
#  855,
#  875,
#  876,
#  892,
#  893,
#  894,
#  899,
#  900,
#  901,
#  903,
#  937,
#  939,
#  942,
#  943,
#  944,
#  945,
#  946,
#  948,
#  968,
#  972,
#  981,
#  995,
#  1002,
#  1010,
#  1013,
#  1034,
#  1037,
#  1038,
#  1042,
#  1052,
#  1054,
#  1063,
#  1065,
#  1069,
#  1070,
#  1078,
#  1080,
#  1081,
#  1082,
#  1083,
#  1088,
#  1104,
# ...

# %%
cacon2=[]
for i in list(coindex):
    if i==32687:
        pass
    elif i==0:
        pass
    else:
        cacon2.append(df['sentence'][i-1]+" "+df['sentence'][i]+" "+df['sentence'][i+1])
bb_sum = pd.DataFrame(cacon2)

# %%
bb_sum.to_csv('sentences/2019cafe_recipe_baby.csv', encoding='utf-8-sig')

# %%
# 집밥 레시피 콘텐츠
home_df = df.loc[df['sentence'].str.contains('밥|아침|저녁|집밥')]
home_df
# Out:
#        index                                           sentence
# 2          2     보통 6개월에 한번 사던쌀이 아들이 같이 밥을 먹기 시작하면서 3개월에 한번 삽니다
# 5          5  그때만해도 대수롭지 않게 골라내고 밥을 했었는데 이제 거진 쌀을 다 먹어갈때쯤 오늘...
# 10        10   **름 에 앞면있는분들이 조금 계셔서 그전에 쥐파먹은김도 그냥 넘어가구 곰팡이핀 ...
# 32        32                              베스 여러분도 행복한 저녁시간 보내세요
# 35        35  오늘 밥먹다보니 사이사이에 숯 조각들이 보여서;; 숯은 그냥 빼야겠다 생각하고 숯조...
# ...      ...                                                ...
# 32646  32646  벼에서 쌀로, 다시 밥과 막걸리로 … 사라진 1500종, 토종 벼의 귀환을 꿈꾸다 ...
# 32648  32648   한반도에서 재배된 토종 벼는 1500종에 달한 것으로 알려졌지만, 지금은 어떻습니...
# 32658  32658                              밥을하면 주위사람들이 맛있다고 한다네요
# 32669  32669   불린쌀로 먼저 찌고 갈으래는데 어른들 해먹으려고 쌀밥 해노은거를 바로 갈아도 상관...
# 32687  32687   쌀튀밥 두개 (유통기한 2020317)어그 130사이즈(사용감 잇네용)검정 운동화...
#
# [2922 rows x 2 columns]

# %%
coindex=home_df.index
list(coindex)
# Out:
# [2,
#  5,
#  10,
#  32,
#  35,
#  44,
#  72,
#  74,
#  75,
#  82,
#  105,
#  109,
#  111,
#  114,
#  115,
#  116,
#  128,
#  136,
#  138,
#  139,
#  148,
#  149,
#  150,
#  151,
#  152,
#  153,
#  155,
#  156,
#  163,
#  164,
#  172,
#  179,
#  243,
#  246,
#  247,
#  264,
#  291,
#  310,
#  311,
#  312,
#  369,
#  396,
#  398,
#  399,
#  400,
#  403,
#  404,
#  410,
#  417,
#  418,
#  421,
#  437,
#  449,
#  455,
#  485,
#  493,
#  508,
#  510,
#  518,
#  524,
#  542,
#  544,
#  558,
#  572,
#  589,
#  606,
#  634,
#  635,
#  638,
#  641,
#  643,
#  720,
#  749,
#  752,
#  783,
#  793,
#  819,
#  821,
#  832,
#  869,
#  874,
#  876,
#  888,
#  913,
#  914,
#  946,
#  951,
#  953,
#  954,
#  955,
#  956,
#  963,
#  969,
#  975,
#  977,
#  978,
#  1004,
#  1008,
#  1021,
#  1023,
#  1024,
#  1057,
#  1083,
#  1089,
#  1090,
#  1097,
#  1103,
#  1130,
#  1150,
#  1169,
#  1175,
#  1181,
#  1220,
#  1225,
#  1260,
#  1273,
#  1275,
#  1278,
#  1284,
#  1299,
#  1307,
#  1310,
#  1311,
# ...

# %%
cacon2=[]
for i in list(coindex):
    if i==32687:
        pass
    elif i==0:
        pass
    else:
        cacon2.append(df['sentence'][i-1]+" "+df['sentence'][i]+" "+df['sentence'][i+1])
hm_sum = pd.DataFrame(cacon2)

# %%
hm_sum.to_csv('sentences/2019cafe_recipe_home.csv', encoding='utf-8-sig')

# %%
# 디저트 레시피 콘텐츠
dessert_df = df.loc[df['sentence'].str.contains('과자|가루|떡|반죽|튀밥|밀가루|설탕|식빵|쿠키|카스테라|우유|빵|케이크|초코|베이킹|반죽|버터|크림|디저트')]
dessert_df
# Out:
#        index                                           sentence
# 23        23      이걸 지금까지 어린 아들에게 먹였다니엄청 오랜만에 베이킹 하는거 같네용버터도...
# 26        26  흑나눔 보내드리기로한거 이번주에 꼭 보내께여)박력분은없고마들렌은 굽고싶고 해서박력쌀...
# 27        27  마들렌도 첨인데쌀가루로 하려니 걱정이 앞섰지만맛없으면 내가먹겠다 하는 마음으로모카,...
# 28        28  반죽해서 휴지시켜놓고작은선물님 나눔으로 받았던실리콘 마들렌틀에 굽굽처음쪽엔 온도 감...
# 30        30  첫째가 엄마 맛있는 냄새가 엄청나요하면서 먹어줘서 그저 또 행복해졌었다는퍽퍽할까봐 ...
# ...      ...                                                ...
# 32675  32675   일단 아시겠지만 그런 과자는 크기가 커서 사 들고 다니기 부담스럽고 여러 이유 때...
# 32676  32676                                      너무 사랑스러운 과자에요
# 32677  32677                     정말쌀과자 냠냠 맛있게 먹으며 열심히 즐겁게 공부해봐요
# 32679  32679                                분유스푼으로 쌀가루 몇그램 나올까요
# 32687  32687   쌀튀밥 두개 (유통기한 2020317)어그 130사이즈(사용감 잇네용)검정 운동화...
#
# [7479 rows x 2 columns]

# %%
coindex=dessert_df.index
list(coindex)
# Out:
# [23,
#  26,
#  27,
#  28,
#  30,
#  31,
#  52,
#  53,
#  54,
#  55,
#  56,
#  57,
#  58,
#  59,
#  61,
#  63,
#  66,
#  68,
#  71,
#  78,
#  79,
#  82,
#  83,
#  84,
#  85,
#  87,
#  88,
#  90,
#  91,
#  106,
#  118,
#  119,
#  120,
#  129,
#  140,
#  141,
#  142,
#  146,
#  163,
#  165,
#  166,
#  167,
#  168,
#  170,
#  171,
#  173,
#  174,
#  176,
#  179,
#  189,
#  190,
#  197,
#  200,
#  202,
#  210,
#  211,
#  212,
#  213,
#  225,
#  229,
#  251,
#  252,
#  254,
#  257,
#  258,
#  269,
#  285,
#  287,
#  289,
#  296,
#  297,
#  299,
#  300,
#  310,
#  313,
#  315,
#  318,
#  319,
#  320,
#  321,
#  334,
#  344,
#  346,
#  348,
#  353,
#  354,
#  355,
#  360,
#  361,
#  362,
#  364,
#  372,
#  374,
#  376,
#  382,
#  384,
#  385,
#  390,
#  391,
#  417,
#  418,
#  421,
#  422,
#  423,
#  431,
#  434,
#  435,
#  438,
#  439,
#  440,
#  441,
#  443,
#  444,
#  445,
#  447,
#  448,
#  459,
#  460,
#  465,
#  466,
#  467,
#  472,
#  476,
#  477,
#  482,
#  489,
#  490,
#  493,
# ...

# %%
cacon2=[]
for i in list(coindex):
    if i==32687:
        pass
    elif i==0:
        pass
    else:
        cacon2.append(df['sentence'][i-1]+" "+df['sentence'][i]+" "+df['sentence'][i+1])
dst_sum = pd.DataFrame(cacon2)

# %%
dst_sum.to_csv('sentences/2019cafe_recipe_dessert.csv', encoding='utf-8-sig')

# %%
# 기타 레시피 콘텐츠
recipe_df = df.loc[df['sentence'].str.contains('치킨|통닭|떡볶이|피자|핫도그|막걸리|간식|수업|만들기|죽|후라이드|파스타|강정|튀김|면|레시피|소금|치즈|음식|소고기|메뉴|야채|고구마|감자|양념|단호박|물')]
recipe_df
# Out:
#        index                                           sentence
# 2          2     보통 6개월에 한번 사던쌀이 아들이 같이 밥을 먹기 시작하면서 3개월에 한번 삽니다
# 10        10   **름 에 앞면있는분들이 조금 계셔서 그전에 쥐파먹은김도 그냥 넘어가구 곰팡이핀 ...
# 13        13                              황당하여라기분이 너무상하면서 화가나더라
# 21        21       왠만하면 아줌마는 진상이다 소리들을까 그동안 참았는데참지말고갈걸짜증나는 밤이에요
# 25        25  오늘까지 아무것도 안하믄제가 너무 피폐해질거같아서보내드려야 할분도 계시구(물속에비친...
# ...      ...                                                ...
# 32669  32669   불린쌀로 먼저 찌고 갈으래는데 어른들 해먹으려고 쌀밥 해노은거를 바로 갈아도 상관...
# 32670  32670     후기 시작하면서 이제 좀 다양하게 먹일려고 하는데어떤 쌀종류 먹일수있는지 알려주세요
# 32675  32675   일단 아시겠지만 그런 과자는 크기가 커서 사 들고 다니기 부담스럽고 여러 이유 때...
# 32685  32685           제품및 배송 문제점에 대해서는 해당 물품 판매사이트에 연락 하셔야 합니다
# 32687  32687   쌀튀밥 두개 (유통기한 2020317)어그 130사이즈(사용감 잇네용)검정 운동화...
#
# [8455 rows x 2 columns]

# %%
coindex=recipe_df.index
list(coindex)

cacon2=[]
for i in list(coindex):
    if i==32687:
        pass
    elif i==0:
        pass
    else:
        cacon2.append(df['sentence'][i-1]+" "+df['sentence'][i]+" "+df['sentence'][i+1])
recipe_sum = pd.DataFrame(cacon2)

# %%
recipe_sum.to_csv('sentences/2019cafe_recipe_others.csv', encoding='utf-8-sig')

# %%
# 보관 콘텐츠
bug_df = df.loc[df['sentence'].str.contains('보관|박스|벌레|곰팡이|벌래|바구미')]
bug_df
# Out:
#        index                                           sentence
# 3          3         늘 같은곳에 보관해도 아무문제 없었고이번문제의 쌀은 2번째 구매해 먹어봤어요
# 6          6  쌀이 쌀봉지 바닥에 어른 손바닥 보다 크게 눌러붙어 곰팡이가 생겨있고 그동안 봐왔던...
# 7          7  이걸 지금까지 먹은거야 싶어**름 에 전화넣으니커스터머 서비스 전화받으신 분이 사과...
# 10        10   **름 에 앞면있는분들이 조금 계셔서 그전에 쥐파먹은김도 그냥 넘어가구 곰팡이핀 ...
# 33        33                                          벌레얘기 죄송해요
# ...      ...                                                ...
# 32603  32603                                          쌀이 벌레먹었어요
# 32636  32636                             너무많이 보내셔서 ;; 보관도 힘들어서요
# 32640  32640                                      벌레먹은쌀 일년반되었구요
# 32653  32653  ’는 이양기와 트렉터 등 4번의 기계 작업으로 마무리되는 현대 농법과 여든여덟 번의...
# 32669  32669   불린쌀로 먼저 찌고 갈으래는데 어른들 해먹으려고 쌀밥 해노은거를 바로 갈아도 상관...
#
# [1737 rows x 2 columns]

# %%
coindex=bug_df.index
list(coindex)
# Out:
# [3,
#  6,
#  7,
#  10,
#  33,
#  34,
#  35,
#  37,
#  38,
#  95,
#  96,
#  101,
#  153,
#  158,
#  245,
#  250,
#  255,
#  256,
#  261,
#  262,
#  400,
#  424,
#  509,
#  512,
#  584,
#  585,
#  586,
#  589,
#  593,
#  607,
#  649,
#  650,
#  676,
#  677,
#  781,
#  782,
#  784,
#  787,
#  799,
#  828,
#  831,
#  851,
#  857,
#  871,
#  872,
#  874,
#  887,
#  965,
#  966,
#  1066,
#  1067,
#  1099,
#  1102,
#  1124,
#  1189,
#  1192,
#  1244,
#  1338,
#  1339,
#  1342,
#  1350,
#  1355,
#  1356,
#  1496,
#  1499,
#  1575,
#  1618,
#  1619,
#  1660,
#  1702,
#  1709,
#  1735,
#  1767,
#  1797,
#  1798,
#  1799,
#  1806,
#  1824,
#  1825,
#  1826,
#  1861,
#  1869,
#  1880,
#  1891,
#  1914,
#  1915,
#  1941,
#  1961,
#  2119,
#  2141,
#  2176,
#  2177,
#  2228,
#  2244,
#  2259,
#  2291,
#  2383,
#  2400,
#  2443,
#  2465,
#  2466,
#  2484,
#  2531,
#  2581,
#  2637,
#  2641,
#  2657,
#  2658,
#  2660,
#  2665,
#  2722,
#  2743,
#  2744,
#  2767,
#  2798,
#  2866,
#  2901,
#  2928,
# ...

# %%
cacon2=[]
for i in list(coindex):
    if i==32687:
        pass
    elif i==0:
        pass
    else:
        cacon2.append(df['sentence'][i-1]+" "+df['sentence'][i]+" "+df['sentence'][i+1])
bug_sum = pd.DataFrame(cacon2)

# %%
bug_sum.to_csv('sentences/2019cafe_bug.csv', encoding='utf-8-sig')

# %%
# 건강 콘텐츠
health_df = df.loc[df['sentence'].str.contains('곤약|유기농|다이어트|건강')]
health_df
# Out:
#        index                                           sentence
# 77        77           저 어제부터 다이어트시작인데ps 혹시 광고성 글인가요 알려주시면 내릴께요
# 97        97  보일러 안트는 선선한 방에 뒀는데두달 좀 넘은 기간에 이렇게 되나요 쌀 옮겨 담을 ...
# 99        99                        사진에서 보시는바와같이유기농 히토메보레 품종이구요
# 295      295                방학때 이렇게 놀면 건강에 좋은 간식도생기고 좋을듯 해서올려봐요
# 449      449  ♡010 6807 7257010 8822 8715070 4155 0202밥 잘 안 ...
# ...      ...                                                ...
# 32569  32569              오아시스에서 2019년 유기농 햅쌀 구매했는데 상태가 너무 안좋아요
# 32571  32571                           애기 이유식 만들 유기농쌀 어디서 구매하세요
# 32577  32577            벌써냄비옆부분은 굳어서 떨어지려하는데올가 유기농 쌀가루 9개 들어있어요
# 32579  32579  항상 햇쌀마루 홍국쌀가루만 사용했었는데 사진에 있는 홍국쌀가루 쓸만한가요 유기농쌀 ...
# 32687  32687   쌀튀밥 두개 (유통기한 2020317)어그 130사이즈(사용감 잇네용)검정 운동화...
#
# [853 rows x 2 columns]

# %%
coindex=health_df.index
list(coindex)
# Out:
# [77,
#  97,
#  99,
#  295,
#  449,
#  454,
#  460,
#  467,
#  517,
#  627,
#  660,
#  661,
#  697,
#  745,
#  782,
#  787,
#  812,
#  851,
#  855,
#  860,
#  948,
#  960,
#  1037,
#  1047,
#  1049,
#  1066,
#  1117,
#  1166,
#  1225,
#  1239,
#  1257,
#  1287,
#  1299,
#  1300,
#  1305,
#  1340,
#  1341,
#  1396,
#  1447,
#  1511,
#  1512,
#  1549,
#  1555,
#  1556,
#  1636,
#  1637,
#  1689,
#  1757,
#  1782,
#  1823,
#  1914,
#  1915,
#  1933,
#  2084,
#  2085,
#  2218,
#  2267,
#  2347,
#  2382,
#  2406,
#  2559,
#  2581,
#  2667,
#  2729,
#  2736,
#  2899,
#  2901,
#  3114,
#  3159,
#  3213,
#  3282,
#  3367,
#  3454,
#  3455,
#  3459,
#  3460,
#  3622,
#  3623,
#  3655,
#  3656,
#  3658,
#  3660,
#  3714,
#  3716,
#  3731,
#  3751,
#  3918,
#  3919,
#  4011,
#  4073,
#  4083,
#  4084,
#  4085,
#  4183,
#  4203,
#  4232,
#  4288,
#  4289,
#  4316,
#  4349,
#  4379,
#  4384,
#  4394,
#  4455,
#  4465,
#  4506,
#  4581,
#  4613,
#  4629,
#  4633,
#  4640,
#  4677,
#  4694,
# ...

# %%
cacon2=[]
for i in list(coindex):
    if i==32687:
        pass
    elif i==0:
        pass
    else:
        cacon2.append(df['sentence'][i-1]+" "+df['sentence'][i]+" "+df['sentence'][i+1])
health_sum = pd.DataFrame(cacon2)

# %%
health_sum.to_csv('sentences/2019cafe_health.csv', encoding='utf-8-sig')

# %%
# 가격 콘텐츠
price_df = df.loc[df['sentence'].str.contains('가격|비싸|싸')]
price_df
# Out:
#        index                                           sentence
# 58        58  ■■쌀식빵 가격■■개당 5,500원■■당일생산 당일판매 하는 쌀식빵■■밀가루를 사용...
# 96        96  이렇게 보관 잘못해서 버린게 몇번째인지 쌀포대에 도정날짜를 보니 10월 25일인데비...
# 217      217                                          가격은 더 착해요
# 239      239                가격 너무 착해서 본의아니게 전쟁난것도 아닌데 사재기 좀 했네요
# 252      252   노른자 많이 써서 좋고쌀가루라 부담없고가격 착해서 바보비슷 하고 빠른시간에 굽기도...
# ...      ...                                                ...
# 32312  32312  근데 일반빵집껀 크거나 비싸서 망설이는데 엉뚱마마님 오믈렛은 착한가격에 좋은재료만쓰...
# 32383  32383  01063996351 연말 불우이웃 돕기로 쌀을 기증하려는데 10kg 가격 아시는분...
# 32399  32399                                         가격은 6만원이구요
# 32680  32680    *오늘의 최저가 정보롯데 백화점 납품 10kg 쌀등급 상두개 구매 개당 2370...
# 32681  32681  다른 사이트에 가격이 더싼게 있을 수도 있고 시간차에 따라서 가격변동이 되기도 하며...
#
# [745 rows x 2 columns]

# %%
coindex=price_df.index
list(coindex)
# Out:
# [58,
#  96,
#  217,
#  239,
#  252,
#  277,
#  290,
#  310,
#  425,
#  449,
#  480,
#  505,
#  557,
#  559,
#  561,
#  573,
#  595,
#  616,
#  617,
#  633,
#  650,
#  657,
#  686,
#  689,
#  690,
#  715,
#  746,
#  782,
#  861,
#  1044,
#  1047,
#  1091,
#  1096,
#  1098,
#  1148,
#  1184,
#  1200,
#  1284,
#  1286,
#  1309,
#  1310,
#  1326,
#  1327,
#  1337,
#  1367,
#  1512,
#  1514,
#  1544,
#  1545,
#  1578,
#  1579,
#  1617,
#  1769,
#  1818,
#  1819,
#  1892,
#  1920,
#  1939,
#  2032,
#  2037,
#  2070,
#  2118,
#  2164,
#  2217,
#  2220,
#  2221,
#  2236,
#  2242,
#  2285,
#  2288,
#  2334,
#  2363,
#  2426,
#  2435,
#  2463,
#  2492,
#  2520,
#  2522,
#  2618,
#  2623,
#  2649,
#  2668,
#  2838,
#  2937,
#  2958,
#  2960,
#  2961,
#  3006,
#  3024,
#  3100,
#  3165,
#  3192,
#  3220,
#  3233,
#  3238,
#  3270,
#  3286,
#  3315,
#  3359,
#  3366,
#  3391,
#  3451,
#  3464,
#  3468,
#  3469,
#  3510,
#  3565,
#  3634,
#  3752,
#  3879,
#  3984,
#  3985,
#  4074,
#  4075,
# ...

# %%
cacon2=[]
for i in list(coindex):
    if i==32687:
        pass
    elif i==0:
        pass
    else:
        cacon2.append(df['sentence'][i-1]+" "+df['sentence'][i]+" "+df['sentence'][i+1])
price_sum = pd.DataFrame(cacon2)

# %%
price_sum.to_csv('sentences/2019cafe_price.csv', encoding='utf-8-sig')

# %%
# 밥맛 콘텐츠
flavor_df = df.loc[df['sentence'].str.contains('느낌|냄새|식감|맛|밥맛|향|양|기한|유통기한|도정')]
flavor_df
# Out:
#        index                                           sentence
# 14        14   제가 거지도아니고 쌀 한포대 얼마나한다고 양아치마냥 빼놓고 그것만 가지고 왔겠습니...
# 27        27  마들렌도 첨인데쌀가루로 하려니 걱정이 앞섰지만맛없으면 내가먹겠다 하는 마음으로모카,...
# 28        28  반죽해서 휴지시켜놓고작은선물님 나눔으로 받았던실리콘 마들렌틀에 굽굽처음쪽엔 온도 감...
# 30        30  첫째가 엄마 맛있는 냄새가 엄청나요하면서 먹어줘서 그저 또 행복해졌었다는퍽퍽할까봐 ...
# 36        36        아주 작고 8자 모양인걸 보아서 먼지다듬이인것 같은데, 얘네 쌀 안에도 있겠죠
# ...      ...                                                ...
# 32673  32673                              평소에 잘 안 먹다 보니까 더 맛있네요
# 32675  32675   일단 아시겠지만 그런 과자는 크기가 커서 사 들고 다니기 부담스럽고 여러 이유 때...
# 32677  32677                     정말쌀과자 냠냠 맛있게 먹으며 열심히 즐겁게 공부해봐요
# 32681  32681  다른 사이트에 가격이 더싼게 있을 수도 있고 시간차에 따라서 가격변동이 되기도 하며...
# 32687  32687   쌀튀밥 두개 (유통기한 2020317)어그 130사이즈(사용감 잇네용)검정 운동화...
#
# [5839 rows x 2 columns]

# %%
coindex=flavor_df.index
list(coindex)
# Out:
# [14,
#  27,
#  28,
#  30,
#  36,
#  48,
#  52,
#  55,
#  62,
#  72,
#  74,
#  79,
#  81,
#  89,
#  90,
#  96,
#  100,
#  110,
#  111,
#  113,
#  115,
#  116,
#  120,
#  131,
#  138,
#  141,
#  142,
#  143,
#  153,
#  167,
#  170,
#  177,
#  227,
#  246,
#  247,
#  269,
#  270,
#  271,
#  292,
#  293,
#  297,
#  308,
#  321,
#  325,
#  326,
#  327,
#  329,
#  330,
#  331,
#  337,
#  355,
#  361,
#  373,
#  381,
#  391,
#  392,
#  393,
#  397,
#  400,
#  404,
#  410,
#  418,
#  424,
#  425,
#  437,
#  438,
#  439,
#  440,
#  447,
#  449,
#  450,
#  455,
#  458,
#  461,
#  463,
#  466,
#  478,
#  485,
#  492,
#  496,
#  499,
#  502,
#  504,
#  507,
#  508,
#  509,
#  510,
#  516,
#  517,
#  524,
#  530,
#  543,
#  544,
#  568,
#  569,
#  572,
#  575,
#  595,
#  596,
#  606,
#  609,
#  611,
#  620,
#  631,
#  634,
#  635,
#  637,
#  643,
#  649,
#  651,
#  657,
#  659,
#  661,
#  672,
#  673,
#  674,
#  688,
#  698,
#  704,
#  705,
#  708,
#  712,
#  713,
#  714,
#  716,
#  717,
#  720,
# ...

# %%
cacon2=[]
for i in list(coindex):
    if i==32687:
        pass
    elif i==0:
        pass
    else:
        cacon2.append(df['sentence'][i-1]+" "+df['sentence'][i]+" "+df['sentence'][i+1])
flavor_sum = pd.DataFrame(cacon2)

# %%
flavor_sum.to_csv('sentences/2019cafe_flavor.csv', encoding='utf-8-sig')

# %%
# 품종/종류 콘텐츠
kind_df = df.loc[df['sentence'].str.contains('잡곡|찹쌀|현미|백미|보리|햅쌀|품종')]
kind_df
# Out:
#        index                                           sentence
# 47        47   처음와서는 일본품종쌀 주문해먹었었고그담엔 한국쌀먹었는데마트에서 한국아주머니께서 현...
# 95        95  찾아보니 이거내요 사진에는 잘 안보이는데 시골에서 보내주신 쌀 두 포대 오늘 뜯어보...
# 99        99                        사진에서 보시는바와같이유기농 히토메보레 품종이구요
# 105      105  (시엄니가 전에 햅쌀 많다고 쌀 떨어짐 가져가라셔서)그런데 주말에 깜빡했다는요이눔 ...
# 125      125  쌀이유식 중단 3일만에 너무 깨끗해져서 이제 어떻게해야하나고민하다 어제부터 미음처럼...
# ...      ...                                                ...
# 32635  32635                             친정해서 보내온 2019 햅쌀  판매해요
# 32655  32655   게다가 이게 가장 큰 품종도 아니래요 ‘북흑조’는 다 크면 180cm나 되지만, ...
# 32669  32669   불린쌀로 먼저 찌고 갈으래는데 어른들 해먹으려고 쌀밥 해노은거를 바로 갈아도 상관...
# 32671  32671                                제가 알고있는건 현미 수수 정도네요
# 32672  32672  백미랑 섞여서 먹이는거 맞나요저번주인가 주말에 할머니 댁 내려갔다가 동생이 쌀과자에...
#
# [2005 rows x 2 columns]

# %%
coindex=kind_df.index
list(coindex)
# Out:
# [47,
#  95,
#  99,
#  105,
#  125,
#  244,
#  246,
#  279,
#  287,
#  291,
#  344,
#  485,
#  486,
#  624,
#  681,
#  732,
#  739,
#  787,
#  789,
#  793,
#  797,
#  832,
#  883,
#  893,
#  943,
#  960,
#  974,
#  1023,
#  1042,
#  1099,
#  1102,
#  1191,
#  1193,
#  1205,
#  1207,
#  1248,
#  1254,
#  1265,
#  1287,
#  1288,
#  1322,
#  1323,
#  1359,
#  1366,
#  1367,
#  1369,
#  1393,
#  1413,
#  1432,
#  1435,
#  1467,
#  1489,
#  1490,
#  1498,
#  1505,
#  1550,
#  1600,
#  1606,
#  1612,
#  1618,
#  1715,
#  1717,
#  1723,
#  1725,
#  1735,
#  1737,
#  1762,
#  1799,
#  1800,
#  1804,
#  1805,
#  1815,
#  1816,
#  1817,
#  1818,
#  1869,
#  1883,
#  1890,
#  1915,
#  2057,
#  2074,
#  2089,
#  2172,
#  2200,
#  2239,
#  2243,
#  2287,
#  2288,
#  2304,
#  2370,
#  2372,
#  2377,
#  2381,
#  2382,
#  2389,
#  2390,
#  2393,
#  2397,
#  2406,
#  2408,
#  2422,
#  2427,
#  2429,
#  2461,
#  2469,
#  2491,
#  2497,
#  2559,
#  2571,
#  2575,
#  2581,
#  2626,
#  2627,
#  2628,
# ...

# %%
cacon2=[]
for i in list(coindex):
    if i==32687:
        pass
    elif i==0:
        pass
    else:
        cacon2.append(df['sentence'][i-1]+" "+df['sentence'][i]+" "+df['sentence'][i+1])
kind_sum = pd.DataFrame(cacon2)

# %%
kind_sum.to_csv('sentences/2019cafe_kindof.csv', encoding='utf-8-sig')

# %%
# 구매경로 콘텐츠
channel_df = df.loc[df['sentence'].str.contains('배송|배달|택배|인터넷|마트|농협|포장')]
channel_df
# Out:
#        index                                           sentence
# 18        18   그래서 제가 쌀 처음 포장때부터 잘못된걸수도 있는데 지금 뭐하시는거냐니까 얼굴 빨...
# 47        47   처음와서는 일본품종쌀 주문해먹었었고그담엔 한국쌀먹었는데마트에서 한국아주머니께서 현...
# 62        62  당일 드시기를 권해드리며택배로 받으실 경우추운 날씨에 영향을 미칠수 있기 때문에전자...
# 64        64                              (매장에서 고르시거나 택배는 랜덤입니다
# 67        67                             (택배는 택배비 별도 3,000원 입니다
# ...      ...                                                ...
# 32669  32669   불린쌀로 먼저 찌고 갈으래는데 어른들 해먹으려고 쌀밥 해노은거를 바로 갈아도 상관...
# 32680  32680    *오늘의 최저가 정보롯데 백화점 납품 10kg 쌀등급 상두개 구매 개당 2370...
# 32681  32681  다른 사이트에 가격이 더싼게 있을 수도 있고 시간차에 따라서 가격변동이 되기도 하며...
# 32683  32683       구매하실분들은 인터넷 쇼핑몰 특성상 감수 또는 주의을 해서 구매 하시기 바랍니다
# 32685  32685           제품및 배송 문제점에 대해서는 해당 물품 판매사이트에 연락 하셔야 합니다
#
# [2023 rows x 2 columns]

# %%
coindex=channel_df.index
list(coindex)
# Out:
# [18,
#  47,
#  62,
#  64,
#  67,
#  69,
#  73,
#  92,
#  93,
#  101,
#  112,
#  119,
#  121,
#  138,
#  143,
#  153,
#  176,
#  225,
#  243,
#  245,
#  287,
#  291,
#  357,
#  365,
#  366,
#  374,
#  393,
#  396,
#  400,
#  437,
#  449,
#  464,
#  477,
#  500,
#  501,
#  510,
#  512,
#  535,
#  542,
#  544,
#  559,
#  567,
#  568,
#  587,
#  595,
#  599,
#  600,
#  635,
#  649,
#  651,
#  699,
#  712,
#  715,
#  799,
#  803,
#  819,
#  825,
#  826,
#  882,
#  890,
#  894,
#  909,
#  985,
#  1020,
#  1104,
#  1118,
#  1130,
#  1132,
#  1134,
#  1165,
#  1192,
#  1248,
#  1250,
#  1251,
#  1256,
#  1270,
#  1271,
#  1274,
#  1284,
#  1285,
#  1287,
#  1319,
#  1320,
#  1322,
#  1376,
#  1413,
#  1415,
#  1416,
#  1430,
#  1431,
#  1436,
#  1445,
#  1452,
#  1460,
#  1461,
#  1481,
#  1483,
#  1485,
#  1489,
#  1512,
#  1549,
#  1567,
#  1569,
#  1570,
#  1575,
#  1578,
#  1583,
#  1606,
#  1616,
#  1623,
#  1640,
#  1641,
#  1692,
#  1693,
#  1740,
#  1743,
#  1764,
#  1804,
#  1806,
# ...

# %%
cacon2=[]
for i in list(coindex):
    if i==32687:
        pass
    elif i==0:
        pass
    else:
        cacon2.append(df['sentence'][i-1]+" "+df['sentence'][i]+" "+df['sentence'][i+1])
channel_sum = pd.DataFrame(cacon2)

# %%
channel_sum.to_csv('sentences/2019cafe_channel.csv', encoding='utf-8-sig')
