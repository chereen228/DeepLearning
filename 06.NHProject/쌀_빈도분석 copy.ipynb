# %%
import konlpy
import pandas as pd
import numpy as np 
import re

# %%
df = pd.read_csv('data/인스타해시태그_쌀.csv')

# %%
df.head()
# Out:
#         dates                                               tags
# 0  2021-03-30  경성미가,쌀,쌀추천,여주쌀,대왕님표여주쌀,진상,자채쌀,가을보석,홈쿡,밥에진심인편,신...
# 1  2021-04-11  오늘은도정일윤기,맛있는쌀,맛있는쌀추천,갓도정쌀,강화쌀,강화도쌀,강화섬쌀,교동쌀,백미...
# 2  2021-03-13  협찬,포프리,체험박스,3차이벤트,포프리체험박스,계란,두부,쌀,콩나물,올리브유,반숙란...
# 3  2021-06-01  톳나물밥,몸을_가볍게,건강한_한끼,쌀,톳,맛간장,참기름,고춧가루,다진마늘,다진대파,...
# 4  2021-07-09                                                NaN

# %%
del df['dates']

# %%
df.head()
# Out:
#                                                 tags
# 0  경성미가,쌀,쌀추천,여주쌀,대왕님표여주쌀,진상,자채쌀,가을보석,홈쿡,밥에진심인편,신...
# 1  오늘은도정일윤기,맛있는쌀,맛있는쌀추천,갓도정쌀,강화쌀,강화도쌀,강화섬쌀,교동쌀,백미...
# 2  협찬,포프리,체험박스,3차이벤트,포프리체험박스,계란,두부,쌀,콩나물,올리브유,반숙란...
# 3  톳나물밥,몸을_가볍게,건강한_한끼,쌀,톳,맛간장,참기름,고춧가루,다진마늘,다진대파,...
# 4                                                NaN

# %%
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') 
    result = hangul.sub(' ', str(text))
    return result

df['ko_text'] = df['tags'].apply(lambda x : text_cleaning(x))
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c52dda9c4ab6> in <module>
#       4     return result
#       5
# ----> 6 df['con_text'] = df['tags'].apply(lambda x : text_cleaning(x))
#       7 df.head(10)
#
# NameError: name 'df' is not defined

# %%
for i in range(len(df['ko_text'])):
    if len(df['ko_text'][i]) == 0:
        df = df.drop(index=i)

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
stopwords = ['그램','스타','팔로워','선팔','팔로우','판매','반사','오늘','소통','맞팔','더','쌀']

def get_nouns(x):
    nouns_tagger = Okt()
    nouns = nouns_tagger.nouns(x)
    #불용어 제거
    nouns = [noun for noun in nouns if noun not in stopwords]
    return nouns

# 'ko_text' 피처에 적용
df['nouns'] = df['ko_text'].apply(lambda x: get_nouns(x))
print(df.shape)
df.head()
# Out:
# (848, 3)
#                                                 tags  \
# 0  경성미가,쌀,쌀추천,여주쌀,대왕님표여주쌀,진상,자채쌀,가을보석,홈쿡,밥에진심인편,신...
# 1  오늘은도정일윤기,맛있는쌀,맛있는쌀추천,갓도정쌀,강화쌀,강화도쌀,강화섬쌀,교동쌀,백미...
# 2  협찬,포프리,체험박스,3차이벤트,포프리체험박스,계란,두부,쌀,콩나물,올리브유,반숙란...
# 3  톳나물밥,몸을_가볍게,건강한_한끼,쌀,톳,맛간장,참기름,고춧가루,다진마늘,다진대파,...
# 4                                                NaN
#
#                                              ko_text  \
# 0  경성미가 쌀 쌀추천 여주쌀 대왕님표여주쌀 진상 자채쌀 가을보석 홈쿡 밥에진심인편 신...
# 1  오늘은도정일윤기 맛있는쌀 맛있는쌀추천 갓도정쌀 강화쌀 강화도쌀 강화섬쌀 교동쌀 백미...
# 2  협찬 포프리 체험박스 차이벤트 포프리체험박스 계란 두부 쌀 콩나물 올리브유 반숙란 ...
# 3  톳나물밥 몸을 가볍게 건강한 한끼 쌀 톳 맛간장 참기름 고춧가루 다진마늘 다진대파 ...
# 4
#
#                                                nouns
# 0  [성미, 추천, 여주, 대왕, 표, 여주, 진상, 자채쌀, 가을, 보석, 홈쿡, 밥...
# 1  [도, 정일, 윤기, 추천, 도정, 강화, 강화도, 강화, 섬쌀, 교동, 백미, 현...
# 2  [협찬, 포프리, 체험, 박스, 차이, 벤트, 포프리, 체험, 박스, 계란, 두부,...
# 3  [톳, 나물, 밥, 몸, 끼, 톳, 맛, 간장, 참기름, 고춧가루, 마늘, 대파, ...
# 4                                                 []

# %%
# 트랜잭션 데이터를 추출합니다.
transactions = df['nouns'].tolist()
transactions = [transaction for transaction in transactions if transaction] # 공백 문자열을 방지합니다.

# %%
ex_list=[]
for i in transactions:
    for j in i:
        ex_list.append(j)

# %%
from collections import Counter

# %%
count = Counter(ex_list)
count
# Out:
# Counter({'성미': 1,
#          '추천': 54,
#          '여주': 12,
#          '대왕': 2,
#          '표': 14,
#          '진상': 1,
#          '자채쌀': 1,
#          '가을': 4,
#          '보석': 2,
#          '홈쿡': 6,
#          '밥': 157,
#          '진심': 1,
#          '인편': 1,
#          '신혼': 3,
#          '밥상': 21,
#          '일기': 19,
#          '솥밥': 1,
#          '식탁': 10,
#          '협찬': 9,
#          '이마트': 4,
#          '백화점': 1,
#          '품관': 1,
#          '신세계': 2,
#          '롯데': 3,
#          '갤러리아': 1,
#          '요리': 41,
#          '봄맞이': 1,
#          '도': 8,
#          '정일': 2,
#          '윤기': 1,
#          '도정': 14,
#          '강화': 14,
#          '강화도': 11,
#          '섬쌀': 9,
#          '교동': 9,
#          '백미': 26,
#          '현미': 54,
#          '참드': 9,
#          '림': 12,
#          '신선': 5,
#          '주': 14,
#          '회도': 6,
#          '정': 6,
#          '미미': 23,
#          '호호': 15,
#          '디자인': 4,
#          '무공': 6,
#          '쌀밥': 20,
#          '밥스': 11,
#          '덕후': 6,
#          '집밥': 44,
#          '포프리': 7,
#          '체험': 24,
#          '박스': 5,
#          '차이': 2,
#          '벤트': 2,
#          '계란': 11,
#          '두부': 3,
#          '콩나물': 2,
#          '올리브유': 3,
#          '숙란': 2,
#          '테이블': 5,
#          '반찬': 26,
#          '톳': 2,
#          '나물': 3,
#          '몸': 3,
#          '끼': 10,
#          '맛': 15,
#          '간장': 5,
#          '참기름': 4,
#          '고춧가루': 3,
#          '마늘': 16,
#          '대파': 3,
#          '청양고추': 2,
#          '통깨': 1,
#          '우리': 24,
#          '농산물': 25,
#          '제품': 7,
#          '쿡': 1,
#          '올리브': 1,
#          '김': 12,
#          '대표': 5,
#          '쿡스': 4,
#          '심스아뜰리': 1,
#          '참사': 1,
#          '뚜껑': 1,
#          '분리': 2,
#          '학창': 1,
#          '포장': 15,
#          '점심': 9,
#          '운동': 22,
#          '푸드': 26,
#          '다이어트': 38,
#          '다이어트식단': 7,
#          '체중감량': 1,
#          '바디': 5,
#          '프로필': 5,
#          '식단': 21,
#          '관리': 6,
#          '몸매': 2,
#          '다이어터': 5,
#          '그릭': 1,
#          '요거트': 4,
#          '치킨': 8,
#          '여자': 4,
#          '웨이': 1,
#          '트': 1,
#          '캘리포니아': 1,
#          '오이': 6,
#          '토마토': 20,
#          '치즈': 13,
#          '시즌': 1,
#          '체지방': 1,
#          '감량': 1,
#          '디엠': 1,
#          '짐': 1,
#          '밥힘': 2,
#          '용인': 16,
#          '빵집': 20,
#          '맛집': 161,
#          '역북': 4,
#          '지구': 6,
#          '역': 11,
#          '북동': 8,
#          '핫': 5,
#          '발효종': 4,
#          '빵': 55,
#          '쌀빵': 16,
#          '맛스타': 20,
#          '순례': 4,
#          '유기농': 31,
#          '맘': 42,
#          '기흥': 4,
#          '광교': 6,
#          '영통': 4,
#          '명지대': 12,
#          '용인대': 8,
#          '일상': 101,
#          '비건': 29,
#          '마늘빵': 1,
#          '러스크': 1,
#          '빠삭빠삭': 1,
#          '꼬소꼬소': 2,
#          '농림축산식품부': 52,
#          '농림': 49,
#          '수산': 49,
#          '식품': 66,
#          '교육': 55,
#          '문화': 51,
#          '정보원': 49,
#          '농정원': 50,
#          '미소': 54,
#          '곡간': 49,
#          '핵인': 8,
#          '트렌드': 5,
#          '대세': 2,
#          '업계': 1,
#          '인': 11,
#          '가구': 2,
#          '친환경': 10,
#          '필': 3,
#          '환경': 1,
#          '소비': 2,
#          '비행': 1,
#          '태': 6,
#          '조사': 1,
#          '정미소': 14,
#          '전문': 9,
#          '매장': 4,
#          '코로나': 17,
#          '정기': 2,
#          '구독': 4,
#          '캠핑': 3,
#          '족': 1,
#          '린': 1,
#          '레시피': 23,
#          '시나몬': 3,
#          '숙성': 1,
#          '스텐드': 2,
#          '글라스': 2,
#          '변신': 2,
#          '그림': 12,
#          '색깔': 4,
#          '미술': 16,
#          '응용': 2,
#          '편': 4,
#          '판': 1,
#          '놀이': 6,
#          '법': 5,
#          '융합': 2,
#          '살': 15,
#          '엄마': 24,
#          '활동': 4,
#          '아동': 2,
#          '아들': 20,
#          '육아': 30,
#          '통해': 2,
#          '산타': 1,
#          '스파르타': 1,
#          '반': 8,
#          '색소': 10,
#          '활용': 2,
#          '부대찌개': 1,
#          '미역': 2,
#          '줄기': 1,
#          '오이소박이': 1,
#          '바나나': 5,
#          '마스크': 5,
#          '사랑': 18,
#          '마루': 7,
#          '나눔': 15,
#          '독거': 5,
#          '노인': 5,
#          '어르신': 5,
#          '배달': 19,
#          '사회': 8,
#          '복지': 19,
#          '취약': 3,
#          '계층': 3,
#          '성남': 4,
#          '기독교': 2,
#          '샘': 2,
#          '교회': 5,
#          '태평': 2,
#          '양평': 8,
#          '서울': 7,
#          '허브': 2,
#          '청주': 10,
#          '약주': 9,
#          '술': 27,
#          '전통주': 14,
#          '와인': 12,
#          '디저트': 181,
#          '맑은': 10,
#          '칵테일': 2,
#          '한국': 9,
#          '아침': 11,
#          '농민': 22,
#          '직접': 23,
#          '전하': 21,
#          '먹거리': 21,
#          '배즙': 43,
#          '사과': 25,
#          '유자': 45,
#          '즙': 43,
#          '과즙': 43,
#          '복숭아': 70,
#          '유기': 42,
#          '보리차': 64,
#          '병조림': 21,
#          '농업': 31,
#          '농사': 41,
#          '약속': 22,
#          '대리': 1,
#          '기사': 1,
#          '여름': 23,
#          '인생': 11,
#          '인생살이': 1,
#          '이천': 15,
#          '쌀제': 1,
#          '조선': 5,
#          '향': 9,
#          '돈': 10,
#          '산': 14,
#          '힐스테이트': 2,
#          '미사': 3,
#          '그': 1,
#          '파사': 1,
#          '쥬': 1,
#          '강변': 2,
#          '도시': 6,
#          '하우스': 1,
#          '홈인': 1,
#          '테리어': 1,
#          '왜관': 2,
#          '옷': 2,
#          '시장': 8,
#          '비조': 1,
#          '간판': 1,
#          '현수막': 1,
#          '상': 2,
#          '모동': 1,
#          '프랜차이즈': 1,
#          '야식': 4,
#          '닭강정': 3,
#          '대구': 4,
#          '행사': 4,
#          '브랜드': 6,
#          '꼭': 2,
#          '한번': 4,
#          '아기': 25,
#          '산책': 7,
#          '개월': 10,
#          '일': 12,
#          '쥐띠': 1,
#          '기록': 8,
#          '도치': 6,
#          '아가': 2,
#          '해': 9,
#          '차': 3,
#          '왜': 3,
#          '알고싶다': 1,
#          '촉감': 10,
#          '이기자': 1,
#          '야구': 1,
#          '치맥': 1,
#          '역시': 1,
#          '햅쌀': 18,
#          '진공': 4,
#          '혼합': 3,
#          '잡곡': 40,
#          '슈퍼': 6,
#          '밥줘': 1,
#          '오버': 1,
#          '파워': 1,
#          '이제': 2,
#          '노': 11,
#          '버터': 11,
#          '밀가루': 25,
#          '레그': 1,
#          '대형': 1,
#          '프라이팬': 1,
#          '인덕션': 1,
#          '야외': 2,
#          '카페': 76,
#          '오븐': 27,
#          '애': 17,
#          '라이스': 93,
#          '베이': 128,
#          '킹': 124,
#          '케이크': 388,
#          '수제': 53,
#          '제청': 14,
#          '우유': 38,
#          '보틀': 15,
#          '파주': 34,
#          '금촌': 28,
#          '금촌역': 14,
#          '유혹': 1,
#          '마곡': 36,
#          '주문': 66,
#          '글루텐': 87,
#          '프리': 87,
#          '기념일': 21,
#          '프리미엄': 17,
#          '동물성': 17,
#          '생크림': 28,
#          '생일케이크': 19,
#          '건강': 113,
#          '축하': 15,
#          '어린이집': 12,
#          '명제': 17,
#          '하이': 14,
#          '슈가': 14,
#          '생일': 17,
#          '파티': 15,
#          '이삭': 3,
#          '된장': 5,
#          '생각': 3,
#          '요': 3,
#          '호두': 15,
#          '파이': 3,
#          '피칸': 3,
#          '홈': 17,
#          '듬뿍': 2,
#          '커피': 8,
#          '순삭': 3,
#          '클레이': 12,
#          '창업': 12,
#          '방': 9,
#          '아트': 4,
#          '앙금': 7,
#          '플라워': 5,
#          '선물': 46,
#          '방과후': 6,
#          '지도사': 4,
#          '수업': 18,
#          '교재': 2,
#          '비대': 2,
#          '아이': 22,
#          '들놀이': 3,
#          '만들기': 21,
#          '협회': 3,
#          '여성': 4,
#          '간식': 63,
#          '집콕': 5,
#          '방콕': 2,
#          '파인애플': 2,
#          '파운드': 6,
#          '콩': 24,
#          '포트': 2,
#          '찹쌀': 33,
#          '찰떡': 6,
#          '단호박': 4,
#          '쁘띠': 1,
#          '츠': 1,
#          '타르트': 2,
#          '부산': 3,
#          '동래구': 2,
#          '명장동': 2,
#          '이화': 2,
#          '울주': 1,
#          '울산': 56,
#          '비': 9,
#          '건빵': 9,
#          '베이커리': 5,
#          '레몬': 8,
#          '청': 4,
#          '피자': 6,
#          '자몽': 1,
#          '콤': 1,
#          '부차': 1,
#          '신도시': 1,
#          '동문': 1,
#          '굿모닝': 1,
#          '힐': 1,
#          '밀싹': 1,
#          '주스': 3,
#          '종': 2,
#          '고민': 4,
#          '집': 28,
#          '일러스트': 9,
#          '음식': 32,
#          '수향': 6,
#          '갑': 13,
#          '농장': 14,
#          '고추': 13,
#          '벼': 34,
#          '철원': 8,
#          '김장': 1,
#          '김치': 8,
#          '시드니': 1,
#          '락다운': 2,
#          '보쌈': 1,
#          '커리': 3,
#          '신입': 1,
#          '신입사원': 1,
#          '공감': 3,
#          '추억': 1,
#          '사진': 8,
#          '일러스트레이터': 1,
#          '대학생': 16,
#          '천원': 142,
#          '아침밥': 182,
#          '효능': 2,
#          '고양이': 34,
#          '야옹이': 5,
#          '바퀴': 2,
#          '보리': 26,
#          '캣': 3,
#          '갯벌': 2,
#          '농부': 56,
#          '새벽이슬': 1,
#          '후계': 7,
#          '농업인': 28,
#          '농협': 14,
#          '조합원': 7,
#          '농가': 10,
#          '하루': 14,
#          '벼농사': 12,
#          '풀': 14,
#          '옥수수': 24,
#          '초당': 7,
#          '반려': 9,
#          '묘': 9,
#          '반려견': 10,
#          '강아지': 9,
#          '집사': 21,
#          '쌀암': 30,
#          '재학': 13,
#          '학교': 13,
#          '이름': 14,
#          '이벤트': 75,
#          '장미': 1,
#          '작약': 1,
#          '백설기': 3,
#          '정리': 3,
#          '떡': 9,
#          '떡케이크': 6,
#          '꼬똥': 3,
#          '꼬똥드툴레': 1,
#          '댕댕': 7,
#          '거리': 2,
#          '캐릭터': 2,
#          '카이': 1,
#          '빙': 1,
#          '낙성대': 1,
#          '새우': 4,
#          '쿠키': 23,
#          '맥주': 4,
#          '짭쪼름': 1,
#          '쿠맥': 1,
#          '습': 2,
#          '사블레': 1,
#          '갈릭': 1,
#          '살레': 1,
#          '차슈': 1,
#          '바베큐': 1,
#          '돼지': 3,
#          '중국음식': 1,
#          '꿀잼': 2,
#          '리브': 2,
#          '스': 2,
#          '경제': 1,
#          '뉴스': 4,
#          '물가': 3,
#          '소비자': 3,
#          '달걀': 4,
#          '돼지고기': 2,
#          '지수': 1,
#          '통계청': 1,
#          '인천대학교': 1,
#          '호': 4,
#          '댕': 2,
#          '핸드': 1,
#          '메이드': 4,
#          '내': 13,
#          '상상': 3,
#          '예찬': 6,
#          '골드': 7,
#          '김제': 2,
#          '공덕': 3,
#          '우렁이': 9,
#          '농법': 4,
#          '하데스': 1,
#          '타운': 1,
#          '최잶': 1,
#          '김수하': 1,
#          '박혜나': 1,
#          '김우형': 1,
#          '모': 3,
#          '그린': 1,
#          '짤': 2,
#          '이토마토': 1,
#          '직거래': 6,
#          '휴가': 11,
#          '란': 1,
#          '인스타그램': 3,
#          '데': 9,
#          '일리': 9,
#          '홍국': 5,
#          '클로렐라': 5,
#          '강황': 4,
#          '협동조합': 2,
#          '연': 4,
#          '키자니아': 3,
#          '식량': 1,
#          '정보': 4,
#          '센터': 6,
#          '어린이': 5,
#          '직업': 5,
#          '관': 1,
#          '꽃': 5,
#          '주먹밥': 10,
#          '명예': 1,
#          '박사': 1,
#          '키즈': 7,
#          '정체': 2,
#          '탈출': 4,
#          '평생': 1,
#          '점': 7,
#          '돌파': 1,
#          '상한': 4,
#          '전주': 6,
#          '주식': 3,
#          '존버': 2,
#          '개미': 2,
#          '승리': 1,
#          '팔면': 1,
#          '가사': 1,
#          '때': 5,
#          '나': 9,
#          '기회': 1,
#          '팟타이': 3,
#          '구미': 4,
#          '쌀국수': 5,
#          '원평동': 2,
#          '금리': 5,
#          '더샾': 1,
#          '가족': 5,
#          '제왕': 1,
#          '조카': 1,
#          '형수': 1,
#          '힐링': 3,
#          '달서구': 1,
#          '진주': 4,
#          '도리': 1,
#          '뷰': 1,
#          '받침': 1,
#          '도련님': 1,
#          '대전': 4,
#          '곧': 1,
#          '소': 3,
#          '환영': 18,
#          '부림': 4,
#          '최고': 5,
#          '비결': 1,
#          '묵은지': 2,
#          '등뼈': 1,
#          '찜': 2,
#          '탕수육': 1,
#          '배추': 1,
#          '된장국': 3,
#          '밖': 1,
#          '남자': 5,
#          '추수': 2,
#          '의심': 2,
#          '바': 1,
#          '국수': 3,
#          '편백나무': 1,
#          '칩': 6,
#          '종셋뚜': 1,
#          '정도': 1,
#          '심바': 2,
#          '품종': 25,
#          '소개': 4,
#          '모음': 3,
#          '미호': 6,
#          '충북': 4,
#          '충청북도': 1,
#          '모내기': 7,
#          '아밀로스': 2,
#          '메벼': 1,
#          '사이': 1,
#          '가공': 1,
#          '급식': 2,
#          '용': 2,
#          '최근': 3,
#          '전라북도': 3,
#          '익산': 3,
#          '신동진': 11,
#          '단일': 9,
#          '서리': 3,
#          '백태': 3,
#          '팥': 3,
#          '도매': 15,
#          '소매': 4,
#          '국내': 7,
#          '중신': 9,
#          '영호': 4,
#          '진미': 6,
#          '밥솥': 2,
#          '수상한': 8,
#          '마돈': 3,
#          '마마': 3,
#          '크라이': 3,
#          '조형': 5,
#          '균': 5,
#          '쌀븨': 2,
#          '고훈정': 1,
#          '훈백': 1,
#          '쌀훈': 1,
#          '페어': 2,
#          '년생': 4,
#          '고': 2,
#          '특성화고': 2,
#          '제과제빵': 2,
#          '제과': 3,
#          '기능사': 2,
#          '스콘': 4,
#          '자': 7,
#          '녹차': 3,
#          '말차': 3,
#          '휘': 7,
#          '낭시': 12,
#          '도전': 2,
#          '실험실': 2,
#          '개발': 5,
#          '마들렌': 35,
#          '초코': 10,
#          '코': 2,
#          '오피': 1,
#          '앤': 1,
#          '코미': 1,
#          '작업': 3,
#          '배민': 2,
#          '강북구': 3,
#          '성북구': 1,
#          '가요': 1,
#          '회사': 1,
#          '주니어': 1,
#          '알': 4,
#          '잠시': 4,
#          '만': 3,
#          '탕종': 1,
#          '경주': 9,
#          '로드': 3,
#          '남': 3,
#          '펜션': 2,
#          '야채': 7,
#          '자재': 5,
#          '배송': 27,
#          '업체': 4,
#          '쌀카': 4,
#          '출발': 8,
#          '농산': 9,
#          '곳': 5,
#          '지역': 12,
#          '떡집': 4,
#          '방앗간': 9,
#          '납품': 8,
#          '식당': 10,
#          '매상': 4,
#          '영업': 9,
#          '청춘': 4,
#          '이야기': 14,
#          '대자': 4,
#          '장사': 6,
#          '대가': 4,
#          '스윗': 1,
#          '애교': 2,
#          '개': 10,
#          '냥': 17,
#          '곡물': 12,
#          '복직': 1,
#          '전날': 1,
#          '년반': 1,
#          '휴직': 1,
#          '마지막': 2,
#          '날': 4,
#          '잠': 1,
#          '안온': 1,
#          '널': 4,
#          '가나': 3,
#          '위해': 1,
#          '조절': 1,
#          '낱말': 1,
#          '카드': 3,
#          '피클': 1,
#          '소고기': 9,
#          '맘마': 1,
#          '엄': 1,
#          '항상': 1,
#          '맘속': 1,
#          '아빠': 5,
#          '겸': 1,
#          '혀': 1,
#          '거': 1,
#          '사람': 7,
#          '관계': 1,
#          '자신감': 1,
#          '가지': 5,
#          '년': 3,
#          '차관': 1,
#          '제사': 1,
#          '아닝': 1,
#          '자신': 1,
#          '이': 2,
#          '시간': 5,
#          '꾸러미': 2,
#          '쌈': 2,
#          '채소': 7,
#          '호박': 3,
#          '버섯': 3,
#          '방울토마토': 8,
#          '가정': 5,
#          '보육': 4,
#          '유치원': 8,
#          '방학': 8,
#          '별일': 1,
#          '전분': 2,
#          '집안일': 4,
#          '청소': 1,
#          '응암': 1,
#          '본가': 1,
#          '한정식': 4,
#          '게장': 4,
#          '딸기': 5,
#          '산딸기': 1,
#          '색': 8,
#          '우중': 1,
#          '시골': 13,
#          '전원': 1,
#          '생활': 17,
#          '생강': 2,
#          '국순당': 4,
#          '장수': 3,
#          '막걸리': 31,
#          '국산': 3,
#          '도시락': 34,
#          '크림': 4,
#          '치즈케이크': 2,
#          '드라이': 3,
#          '절임': 1,
#          '해표': 1,
#          '공유': 7,
#          '평택': 4,
#          '평택시': 1,
#          '문화원': 1,
#          '진위면': 1,
#          '안중': 1,
#          '이앙기': 1,
#          '콤바인': 1,
#          '닝': 2,
#          '고시히카리': 7,
#          '밥심': 4,
#          '부탁': 1,
#          '유튜브': 2,
#          '스페인': 7,
#          '미식': 2,
#          '재료': 13,
#          '사프란': 1,
#          '올리브오일': 1,
#          '눈': 43,
#          '크게': 43,
#          '찾기': 7,
#          '국민': 23,
#          '당첨': 2,
#          '발표': 1,
#          '채식': 1,
#          '보루': 1,
#          '쫀득쫀득': 2,
#          '카스': 1,
#          '고기': 7,
#          '스팸': 2,
#          '과자': 15,
#          '구': 1,
#          '양송이버섯': 1,
#          '다우니': 1,
#          '퍼퓸': 1,
#          '페브리쯔': 1,
#          '쓰레기봉투': 1,
#          '배냇밀': 1,
#          '이유식': 4,
#          '무료': 11,
#          '무': 5,
#          '항생제': 1,
#          '한우': 4,
#          '발효': 8,
#          '밀': 11,
#          '엠': 6,
#          '브레드': 7,
#          '이편': 5,
#          '알레르기': 5,
#          '장': 6,
#          '트러블': 5,
#          '설탕': 5,
#          '방부제': 5,
#          '당일': 23,
#          '생산': 6,
#          '당뇨': 15,
#          '위': 7,
#          '신안': 1,
#          '매일': 1,
#          '후기': 3,
#          '리다': 2,
#          '검정': 1,
#          '한국인': 7,
#          '신혼부부': 1,
#          '부부': 3,
#          '팔': 6,
#          '먹방': 13,
#          '테러': 6,
#          '순천': 1,
#          '여수': 1,
#          '광주': 2,
#          '뭐': 2,
#          '양조장': 2,
#          '연희': 2,
#          '연희동': 2,
#          '홍차': 1,
#          '민트': 2,
#          '팔각': 1,
#          '매화': 1,
#          '페퍼': 1,
#          '탁주': 2,
#          '맷돌': 1,
#          '라플레르': 1,
#          '뉴저지': 2,
#          '뉴욕': 2,
#          '플러싱': 1,
#          '리': 2,
#          '팰팍': 1,
#          '정성': 1,
#          '감사': 7,
#          '모가디슈': 3,
#          '영화': 3,
#          '류승완': 2,
#          '총기': 2,
#          '팀': 2,
#          '전술': 1,
#          '자문': 3,
#          '에코': 3,
#          '나이': 2,
#          '너': 2,
#          '군사': 2,
#          '정만식': 3,
#          '배우': 2,
#          '민영': 1,
#          '베가': 1,
#          '본드': 1,
#          '기관': 2,
#          '동네': 3,
#          '캔쌀': 1,
#          '토종': 3,
#          '볍씨': 1,
#          '와디': 1,
#          '클라우드': 1,
#          '펀딩': 2,
#          '계림': 2,
#          '규동': 3,
#          '마리': 2,
#          '대만': 6,
#          '여행': 11,
#          '레저': 1,
#          '타이완': 2,
#          '농촌': 15,
#          '투어': 4,
#          '체험학습': 1,
#          '조리퐁': 1,
#          '저녁': 11,
#          '것': 3,
#          '리조토': 2,
#          '리소토': 2,
#          '취미': 12,
#          '쿠킹': 1,
#          '람': 2,
#          '망원': 2,
#          '당': 6,
#          '젤라또': 22,
#          '아이스크림': 10,
#          '바질': 7,
#          '패션': 1,
#          '소금': 5,
#          '로투스': 2,
#          '경기도': 3,
#          '여보': 1,
#          '차돌': 1,
#          '찌게': 1,
#          '메인': 1,
#          '조개': 1,
#          '견': 1,
#          '둥이': 2,
#          '홈밥': 1,
#          '애호박': 2,
#          '찌개': 1,
#          '김치전': 1,
#          '기름': 2,
#          '볶음밥': 3,
#          '복': 1,
#          '거의': 1,
#          '시댁': 3,
#          '다둥맘': 1,
#          '남매': 4,
#          '용돈': 1,
#          '생화': 9,
#          '반전': 2,
#          '토퍼': 1,
#          '졸귀': 1,
#          '왕': 3,
#          '의자': 1,
#          '러버': 3,
#          '베개': 1,
#          '마동': 1,
#          '티': 8,
#          '왕티': 1,
#          '반려동물': 2,
#          '말티즈': 3,
#          '렉': 4,
#          '말라카이트': 2,
#          '운': 3,
#          '피스타치오': 2,
#          '계': 3,
#          '병원': 2,
#          '비빔밥': 1,
#          '봉평': 1,
#          '메밀': 2,
#          '블렌딩': 1,
#          '밥믈리에킴': 1,
#          '혁신도시': 3,
#          '대소': 1,
#          '덕산': 2,
#          '전국': 9,
#          '택배': 4,
#          '상사': 2,
#          '서비스': 2,
#          '월요일': 2,
#          '진천': 1,
#          '음성': 1,
#          '물감': 2,
#          '나비': 2,
#          '데칼코마니': 2,
#          '손': 3,
#          '뒷정리': 1,
#          '몫': 1,
#          '체육관': 1,
#          '커플': 3,
#          '샷': 3,
#          '자매': 6,
#          '주말': 9,
#          '서향': 1,
#          '리향': 1,
#          '남양주': 1,
#          '식빵': 7,
#          '유월': 1,
#          '별미': 1,
#          '임곡': 1,
#          '요양원': 1,
#          '임': 1,
#          '곡주': 1,
#          ...})

# %%
words = dict(count.most_common())
words
# Out:
# {'케이크': 388,
#  '아침밥': 182,
#  '디저트': 181,
#  '맛집': 161,
#  '밥': 157,
#  '천원': 142,
#  '베이': 128,
#  '킹': 124,
#  '건강': 113,
#  '일상': 101,
#  '라이스': 93,
#  '글루텐': 87,
#  '프리': 87,
#  '카페': 76,
#  '이벤트': 75,
#  '복숭아': 70,
#  '식품': 66,
#  '주문': 66,
#  '보리차': 64,
#  '간식': 63,
#  '울산': 56,
#  '농부': 56,
#  '빵': 55,
#  '교육': 55,
#  '추천': 54,
#  '현미': 54,
#  '미소': 54,
#  '수제': 53,
#  '농림축산식품부': 52,
#  '문화': 51,
#  '농정원': 50,
#  '농림': 49,
#  '수산': 49,
#  '정보원': 49,
#  '곡간': 49,
#  '선물': 46,
#  '유자': 45,
#  '답례': 45,
#  '집밥': 44,
#  '배즙': 43,
#  '즙': 43,
#  '과즙': 43,
#  '눈': 43,
#  '크게': 43,
#  '맘': 42,
#  '유기': 42,
#  '망원동': 42,
#  '요리': 41,
#  '농사': 41,
#  '잡곡': 40,
#  '다이어트': 38,
#  '우유': 38,
#  '마곡': 36,
#  '마들렌': 35,
#  '파주': 34,
#  '벼': 34,
#  '고양이': 34,
#  '도시락': 34,
#  '찹쌀': 33,
#  '음식': 32,
#  '클래스': 32,
#  '유기농': 31,
#  '농업': 31,
#  '막걸리': 31,
#  '육아': 30,
#  '쌀암': 30,
#  '비건': 29,
#  '합정동': 29,
#  '금촌': 28,
#  '생크림': 28,
#  '집': 28,
#  '농업인': 28,
#  '술': 27,
#  '오븐': 27,
#  '배송': 27,
#  '백미': 26,
#  '반찬': 26,
#  '푸드': 26,
#  '보리': 26,
#  '농산물': 25,
#  '사과': 25,
#  '아기': 25,
#  '밀가루': 25,
#  '품종': 25,
#  '마포구': 25,
#  '과일': 25,
#  '체험': 24,
#  '우리': 24,
#  '엄마': 24,
#  '콩': 24,
#  '옥수수': 24,
#  '미미': 23,
#  '레시피': 23,
#  '직접': 23,
#  '여름': 23,
#  '쿠키': 23,
#  '국민': 23,
#  '당일': 23,
#  '왕십리': 23,
#  '성동구': 23,
#  '운동': 22,
#  '농민': 22,
#  '약속': 22,
#  '아이': 22,
#  '젤라또': 22,
#  '제작': 22,
#  '밥상': 21,
#  '식단': 21,
#  '전하': 21,
#  '먹거리': 21,
#  '병조림': 21,
#  '기념일': 21,
#  '만들기': 21,
#  '집사': 21,
#  '쌀밥': 20,
#  '토마토': 20,
#  '빵집': 20,
#  '맛스타': 20,
#  '아들': 20,
#  '성산동': 20,
#  '일기': 19,
#  '배달': 19,
#  '복지': 19,
#  '생일케이크': 19,
#  '사랑': 18,
#  '햅쌀': 18,
#  '수업': 18,
#  '환영': 18,
#  '청년': 18,
#  '모집': 18,
#  '코로나': 17,
#  '애': 17,
#  '프리미엄': 17,
#  '동물성': 17,
#  '명제': 17,
#  '생일': 17,
#  '홈': 17,
#  '냥': 17,
#  '생활': 17,
#  '서교동': 17,
#  '살림': 17,
#  '마늘': 16,
#  '용인': 16,
#  '쌀빵': 16,
#  '미술': 16,
#  '대학생': 16,
#  '초등학교': 16,
#  '호호': 15,
#  '맛': 15,
#  '포장': 15,
#  '살': 15,
#  '나눔': 15,
#  '이천': 15,
#  '보틀': 15,
#  '축하': 15,
#  '파티': 15,
#  '호두': 15,
#  '도매': 15,
#  '과자': 15,
#  '당뇨': 15,
#  '농촌': 15,
#  '미니': 15,
#  '원데이': 15,
#  '성산': 15,
#  '나린': 15,
#  '표': 14,
#  '도정': 14,
#  '강화': 14,
#  '주': 14,
#  '정미소': 14,
#  '전통주': 14,
#  '산': 14,
#  '제청': 14,
#  '금촌역': 14,
#  '하이': 14,
#  '슈가': 14,
#  '농장': 14,
#  '농협': 14,
#  '하루': 14,
#  '풀': 14,
#  '이름': 14,
#  '이야기': 14,
#  '가루': 14,
#  '후문': 14,
#  '수박': 14,
#  '홍대': 14,
#  '치즈': 13,
#  '갑': 13,
#  '고추': 13,
#  '재학': 13,
#  '학교': 13,
#  '내': 13,
#  '시골': 13,
#  '재료': 13,
#  '먹방': 13,
#  '레터': 13,
#  '링': 13,
#  '보관': 13,
#  '쇼핑몰': 13,
#  '네이버': 13,
#  '놀토': 13,
#  '한식': 13,
#  '정미': 13,
#  '여주': 12,
#  '림': 12,
#  '김': 12,
#  '명지대': 12,
#  '그림': 12,
#  '와인': 12,
#  '일': 12,
#  '어린이집': 12,
#  '클레이': 12,
#  '창업': 12,
#  '벼농사': 12,
#  '낭시': 12,
#  '지역': 12,
#  '곡물': 12,
#  '취미': 12,
#  '농': 12,
#  '영양': 12,
#  '분류': 12,
#  '강화도': 11,
#  '밥스': 11,
#  '계란': 11,
#  '역': 11,
#  '인': 11,
#  '아침': 11,
#  '인생': 11,
#  '노': 11,
#  '버터': 11,
#  '휴가': 11,
#  '신동진': 11,
#  '무료': 11,
#  '밀': 11,
#  '여행': 11,
#  '저녁': 11,
#  '할인': 11,
#  '물': 11,
#  '논': 11,
#  '식': 11,
#  '온라인': 11,
#  '누룩': 11,
#  '성수': 11,
#  '식탁': 10,
#  '끼': 10,
#  '친환경': 10,
#  '색소': 10,
#  '청주': 10,
#  '맑은': 10,
#  '돈': 10,
#  '개월': 10,
#  '촉감': 10,
#  '농가': 10,
#  '반려견': 10,
#  '주먹밥': 10,
#  '초코': 10,
#  '식당': 10,
#  '개': 10,
#  '아이스크림': 10,
#  '꿀': 10,
#  '메뉴': 10,
#  '품': 10,
#  '설기': 10,
#  '협찬': 9,
#  '섬쌀': 9,
#  '교동': 9,
#  '참드': 9,
#  '점심': 9,
#  '전문': 9,
#  '약주': 9,
#  '한국': 9,
#  '향': 9,
#  '해': 9,
#  '방': 9,
#  '비': 9,
#  '건빵': 9,
#  '일러스트': 9,
#  '반려': 9,
#  '묘': 9,
#  '강아지': 9,
#  '떡': 9,
#  '우렁이': 9,
#  '데': 9,
#  '일리': 9,
#  '나': 9,
#  '단일': 9,
#  '중신': 9,
#  '경주': 9,
#  '농산': 9,
#  '방앗간': 9,
#  '영업': 9,
#  '소고기': 9,
#  '생화': 9,
#  '전국': 9,
#  '주말': 9,
#  '라이브': 9,
#  '비료': 9,
#  '양파': 9,
#  '강남': 9,
#  '쌀통': 9,
#  '도': 8,
#  '치킨': 8,
#  '북동': 8,
#  '용인대': 8,
#  '핵인': 8,
#  '반': 8,
#  '사회': 8,
#  '양평': 8,
#  '시장': 8,
#  '기록': 8,
#  '커피': 8,
#  '레몬': 8,
#  '철원': 8,
#  '김치': 8,
#  '사진': 8,
#  '수상한': 8,
#  '출발': 8,
#  '납품': 8,
#  '방울토마토': 8,
#  '유치원': 8,
#  '방학': 8,
#  '색': 8,
#  '발효': 8,
#  '티': 8,
#  '딸': 8,
#  '행복': 8,
#  '쇼핑': 8,
#  '더위': 8,
#  '돌': 8,
#  '감각': 8,
#  '수원': 8,
#  '김포': 8,
#  '포프리': 7,
#  '제품': 7,
#  '다이어트식단': 7,
#  '마루': 7,
#  '서울': 7,
#  '산책': 7,
#  '앙금': 7,
#  '후계': 7,
#  '조합원': 7,
#  '초당': 7,
#  '댕댕': 7,
#  '골드': 7,
#  '키즈': 7,
#  '점': 7,
#  '모내기': 7,
#  '국내': 7,
#  '자': 7,
#  '휘': 7,
#  '야채': 7,
#  '사람': 7,
#  '채소': 7,
#  '공유': 7,
#  '고시히카리': 7,
#  '스페인': 7,
#  '찾기': 7,
#  '고기': 7,
#  '브레드': 7,
#  '위': 7,
#  '한국인': 7,
#  '감사': 7,
#  '바질': 7,
#  '식빵': 7,
#  '인증': 7,
#  '쑥': 7,
#  '움': 7,
#  '대추': 7,
#  '컵': 7,
#  '키위': 7,
#  '주부': 7,
#  '가게': 7,
#  '충남': 7,
#  '건대': 7,
#  '어른': 7,
#  '유머': 7,
#  '기부': 7,
#  '몬테소리': 7,
#  '곡': 7,
#  '즉석': 7,
#  '홈쿡': 6,
#  '회도': 6,
#  '정': 6,
#  '무공': 6,
#  '덕후': 6,
#  '관리': 6,
#  '오이': 6,
#  '지구': 6,
#  '광교': 6,
#  '태': 6,
#  '놀이': 6,
#  '도시': 6,
#  '브랜드': 6,
#  '도치': 6,
#  '슈퍼': 6,
#  '방과후': 6,
#  '파운드': 6,
#  '찰떡': 6,
#  '피자': 6,
#  '수향': 6,
#  '떡케이크': 6,
#  '예찬': 6,
#  '직거래': 6,
#  '센터': 6,
#  '전주': 6,
#  '칩': 6,
#  '미호': 6,
#  '진미': 6,
#  '장사': 6,
#  '엠': 6,
#  '장': 6,
#  '생산': 6,
#  '팔': 6,
#  '테러': 6,
#  '대만': 6,
#  '당': 6,
#  '자매': 6,
#  '샐러드': 6,
#  '통': 6,
#  '꿀팁': 6,
#  '식혜': 6,
#  '홍보': 6,
#  '일식': 6,
#  '참치': 6,
#  '박': 6,
#  '발송': 6,
#  '도둑': 6,
#  '찰보리': 6,
#  '청천': 6,
#  '감자': 6,
#  '인삼': 6,
#  '김밥': 6,
#  '추': 6,
#  '결혼': 6,
#  '승진': 6,
#  '시보': 6,
#  '해제': 6,
#  '백일': 6,
#  '무화과': 6,
#  '우수': 6,
#  '세': 6,
#  '밸런스': 6,
#  '공': 6,
#  '빨간색': 6,
#  '파란색': 6,
#  '노란색': 6,
#  '풍선': 6,
#  '좁쌀': 6,
#  '숟가락': 6,
#  '국자': 6,
#  '집게': 6,
#  '오톨도톨': 6,
#  '에이': 6,
#  '다시마': 6,
#  '스마트': 6,
#  '스토어': 6,
#  '폴란드': 6,
#  '신선': 5,
#  '박스': 5,
#  '테이블': 5,
#  '간장': 5,
#  '대표': 5,
#  '바디': 5,
#  '프로필': 5,
#  '다이어터': 5,
#  '핫': 5,
#  '트렌드': 5,
#  '법': 5,
#  '바나나': 5,
#  '마스크': 5,
#  '독거': 5,
#  '노인': 5,
#  '어르신': 5,
#  '교회': 5,
#  '조선': 5,
#  '된장': 5,
#  '플라워': 5,
#  '집콕': 5,
#  '베이커리': 5,
#  '야옹이': 5,
#  '홍국': 5,
#  '클로렐라': 5,
#  '어린이': 5,
#  '직업': 5,
#  '꽃': 5,
#  '때': 5,
#  '쌀국수': 5,
#  '금리': 5,
#  '가족': 5,
#  '최고': 5,
#  '남자': 5,
#  '조형': 5,
#  '균': 5,
#  '개발': 5,
#  '자재': 5,
#  '곳': 5,
#  '아빠': 5,
#  '가지': 5,
#  '시간': 5,
#  '가정': 5,
#  '딸기': 5,
#  '무': 5,
#  '이편': 5,
#  '알레르기': 5,
#  '트러블': 5,
#  '설탕': 5,
#  '방부제': 5,
#  '소금': 5,
#  '마을': 5,
#  '레': 5,
#  '냉장고': 5,
#  '요즘': 5,
#  '찰': 5,
#  '작가': 5,
#  '쇼': 5,
#  '순이': 5,
#  '식사': 5,
#  '제철': 5,
#  '머스크멜론': 5,
#  '아보카도': 5,
#  '어플': 5,
#  '입맛': 5,
#  '자두': 5,
#  '남가좌동': 5,
#  '안주': 5,
#  '기술': 5,
#  '터': 5,
#  '공원': 5,
#  '감': 5,
#  '날씨': 5,
#  '햇살': 5,
#  '품질': 5,
#  '브라우니': 5,
#  '웹툰': 5,
#  '인스타': 5,
#  '대한민국': 5,
#  '귀농': 5,
#  '주방용품': 5,
#  '용기': 5,
#  '공장': 5,
#  '장애인': 5,
#  '이유': 5,
#  '골목': 5,
#  '처리': 5,
#  '머핀': 5,
#  '의미': 5,
#  '봉사': 5,
#  '바다': 5,
#  '맑음': 5,
#  '가을': 4,
#  '이마트': 4,
#  '디자인': 4,
#  '참기름': 4,
#  '쿡스': 4,
#  '요거트': 4,
#  '여자': 4,
#  '역북': 4,
#  '발효종': 4,
#  '순례': 4,
#  '기흥': 4,
#  '영통': 4,
#  '매장': 4,
#  '구독': 4,
#  '색깔': 4,
#  '편': 4,
#  '활동': 4,
#  '성남': 4,
#  '야식': 4,
#  '대구': 4,
#  '행사': 4,
#  '한번': 4,
#  '진공': 4,
#  '아트': 4,
#  '지도사': 4,
#  '여성': 4,
#  '단호박': 4,
#  '청': 4,
#  '고민': 4,
#  '새우': 4,
#  '맥주': 4,
#  '뉴스': 4,
#  '달걀': 4,
#  '호': 4,
#  '메이드': 4,
#  '농법': 4,
#  '강황': 4,
#  '연': 4,
#  '정보': 4,
#  '탈출': 4,
#  '상한': 4,
#  '구미': 4,
#  '진주': 4,
#  '대전': 4,
#  '부림': 4,
#  '소개': 4,
#  '충북': 4,
#  '소매': 4,
#  '영호': 4,
#  '년생': 4,
#  '스콘': 4,
#  '알': 4,
#  '잠시': 4,
#  '업체': 4,
#  '쌀카': 4,
#  '떡집': 4,
#  '매상': 4,
#  '청춘': 4,
#  '대자': 4,
#  '대가': 4,
#  '날': 4,
#  '널': 4,
#  '보육': 4,
#  '집안일': 4,
#  '한정식': 4,
#  '게장': 4,
#  '국순당': 4,
#  '크림': 4,
#  '평택': 4,
#  '밥심': 4,
#  '이유식': 4,
#  '한우': 4,
#  '투어': 4,
#  '남매': 4,
#  '렉': 4,
#  '택배': 4,
#  '후원': 4,
#  '일본': 4,
#  '카스테라': 4,
#  '혼자': 4,
#  '응원': 4,
#  '일차': 4,
#  '가능': 4,
#  '소르베': 4,
#  '퇴직': 4,
#  '초': 4,
#  '마트': 4,
#  '흑수': 4,
#  '녹': 4,
#  '인친': 4,
#  '호스트': 4,
#  '양곡': 4,
#  '월': 4,
#  '영농': 4,
#  '백년': 4,
#  '혈당': 4,
#  '들기름': 4,
#  '생': 4,
#  '세상': 4,
#  '킹스': 4,
#  '곡식': 4,
#  '금산': 4,
#  '자연': 4,
#  '두유': 4,
#  '폭염': 4,
#  '싸리': 4,
#  '단': 4,
#  '페이퍼': 4,
#  '고구마': 4,
#  '전통': 4,
#  '볶음': 4,
#  '강하': 4,
#  '참외': 4,
#  '복지관': 4,
#  '상품': 4,
#  '탄수화물': 4,
#  '캐나다': 4,
#  '토요일': 4,
#  '강': 4,
#  '삼계탕': 4,
#  '후추': 4,
#  '비단': 4,
#  '촬영': 4,
#  '육류': 4,
#  '금쌀': 4,
#  '딸내미': 4,
#  '압도': 4,
#  '유목민': 4,
#  '정착': 4,
#  '청미': 4,
#  '아끼바레': 4,
#  '바리': 4,
#  '년산': 4,
#  '하늘': 4,
#  '유지': 4,
#  '백종원': 4,
#  '라선': 4,
#  '재': 4,
#  '파': 4,
#  '신': 4,
#  '노을': 4,
#  '체리': 4,
#  '울프': 4,
#  '신혼': 3,
#  '롯데': 3,
#  '두부': 3,
#  '올리브유': 3,
#  '나물': 3,
#  '몸': 3,
#  '고춧가루': 3,
#  '대파': 3,
#  '필': 3,
#  '캠핑': 3,
#  '시나몬': 3,
#  '취약': 3,
#  '계층': 3,
#  '미사': 3,
#  '닭강정': 3,
#  '차': 3,
#  '왜': 3,
#  '혼합': 3,
#  '이삭': 3,
#  '생각': 3,
#  '요': 3,
#  '파이': 3,
#  '피칸': 3,
#  '순삭': 3,
#  '들놀이': 3,
#  '협회': 3,
#  '부산': 3,
#  '주스': 3,
#  '커리': 3,
#  '공감': 3,
#  '캣': 3,
#  '백설기': 3,
#  '정리': 3,
#  '꼬똥': 3,
#  '돼지': 3,
#  '물가': 3,
#  '소비자': 3,
#  '상상': 3,
#  '공덕': 3,
#  '모': 3,
#  '인스타그램': 3,
#  '키자니아': 3,
#  '주식': 3,
#  '팟타이': 3,
#  '힐링': 3,
#  '소': 3,
#  '된장국': 3,
#  '국수': 3,
#  '모음': 3,
#  '최근': 3,
#  '전라북도': 3,
#  '익산': 3,
#  '서리': 3,
#  '백태': 3,
#  '팥': 3,
#  '마돈': 3,
#  '마마': 3,
#  '크라이': 3,
#  '제과': 3,
#  '녹차': 3,
#  '말차': 3,
#  '작업': 3,
#  '강북구': 3,
#  '만': 3,
#  '로드': 3,
#  '남': 3,
#  '가나': 3,
#  '카드': 3,
#  '년': 3,
#  '호박': 3,
#  '버섯': 3,
#  '장수': 3,
#  '국산': 3,
#  '드라이': 3,
#  '후기': 3,
#  '부부': 3,
#  '모가디슈': 3,
#  '영화': 3,
#  '자문': 3,
#  '에코': 3,
#  '정만식': 3,
#  '동네': 3,
#  '토종': 3,
#  '규동': 3,
#  '것': 3,
#  '경기도': 3,
#  '볶음밥': 3,
#  '시댁': 3,
#  '왕': 3,
#  '러버': 3,
#  '말티즈': 3,
#  '운': 3,
#  '계': 3,
#  '혁신도시': 3,
#  '손': 3,
#  '커플': 3,
#  '샷': 3,
#  '초록': 3,
#  '북': 3,
#  '불고기': 3,
#  '강원도': 3,
#  '마켓': 3,
#  '슈': 3,
#  '카레': 3,
#  '새벽': 3,
#  '부모님': 3,
#  '기계': 3,
#  '모찌': 3,
#  '케익': 3,
#  '일몰': 3,
#  '처음': 3,
#  '베이컨': 3,
#  '생후': 3,
#  '올레': 3,
#  '업자': 3,
#  '광고': 3,
#  '마음': 3,
#  '햄': 3,
#  '좀': 3,
#  '무더위': 3,
#  '금주': 3,
#  '케어': 3,
#  '기미': 3,
#  '다음': 3,
#  '토미': 3,
#  '생선': 3,
#  '서교': 3,
#  '동생': 3,
#  '핑크': 3,
#  '휴무': 3,
#  '머드': 3,
#  '째보': 3,
#  '령쌀': 3,
#  '보령시': 3,
#  '합법': 3,
#  '문의': 3,
#  '혼밥': 3,
#  '스파': 3,
#  '초밥': 3,
#  '단백질': 3,
#  '밥맛': 3,
#  '칼슘': 3,
#  '줄': 3,
#  '호수': 3,
#  '시': 3,
#  '하나로': 3,
#  '나무': 3,
#  '태양': 3,
#  '피': 3,
#  '풍경': 3,
#  '기': 3,
#  '자색': 3,
#  '밤': 3,
#  '달': 3,
#  '친정': 3,
#  '누룽지': 3,
#  '예능': 3,
#  '레전드': 3,
#  '찬스': 3,
#  '떡뻥': 3,
#  '구이': 3,
#  '글': 3,
#  '농약': 3,
#  '종합': 3,
#  '예정': 3,
#  '산업': 3,
#  '세계': 3,
#  '아스타': 3,
#  '두메': 3,
#  '궁합': 3,
#  '드로잉': 3,
#  '장바구니': 3,
#  '회': 3,
#  '템': 3,
#  '주방': 3,
#  '준비': 3,
#  '능곡동': 3,
#  '기탁': 3,
#  '오타와': 3,
#  '로': 3,
#  '나농': 3,
#  '데이': 3,
#  '플래닛': 3,
#  '은행나무': 3,
#  '홍천': 3,
#  '퀴노아': 3,
#  '발아': 3,
#  '음료': 3,
#  '떡볶이': 3,
#  '번': 3,
#  '다쿠아즈': 3,
#  '세척': 3,
#  '헬스': 3,
#  '체육': 3,
#  '개그맨': 3,
#  '청풍명월': 3,
#  '뫼쌀': 3,
#  '혜택': 3,
#  '카팅온': 3,
#  '소셜커머스': 3,
#  '이커머스': 3,
#  '번개': 3,
#  '할인특': 3,
#  '입점': 3,
#  '초보': 3,
#  '수원시': 3,
#  '자원봉사': 3,
#  '동수': 3,
#  '구름': 3,
#  '땅': 3,
#  '효듀': 3,
#  '효또': 3,
#  '효또빵': 3,
#  '병아리': 3,
#  '집들이': 3,
#  '랙돌': 3,
#  '렉돌': 3,
#  '최준영': 3,
#  '비상': 3,
#  '상차림': 3,
#  '식비': 3,
#  '가후': 3,
#  '덜덜': 3,
#  '재희': 3,
#  '잘먹고잘사는법': 3,
#  '며느리': 3,
#  '마당': 3,
#  '리스트': 3,
#  '하이웨이': 3,
#  '당감동': 3,
#  '송': 3,
#  '입덧': 3,
#  '대왕': 2,
#  '보석': 2,
#  '신세계': 2,
#  '정일': 2,
#  '차이': 2,
#  '벤트': 2,
#  '콩나물': 2,
#  '숙란': 2,
#  '톳': 2,
#  '청양고추': 2,
#  '분리': 2,
#  '몸매': 2,
#  '밥힘': 2,
#  '꼬소꼬소': 2,
#  '대세': 2,
#  '가구': 2,
#  '소비': 2,
#  '정기': 2,
#  '스텐드': 2,
#  '글라스': 2,
#  '변신': 2,
#  '응용': 2,
#  '융합': 2,
#  '아동': 2,
#  '통해': 2,
#  '활용': 2,
#  '미역': 2,
#  '기독교': 2,
#  '샘': 2,
#  '태평': 2,
#  '허브': 2,
#  '칵테일': 2,
#  '힐스테이트': 2,
#  '강변': 2,
#  '왜관': 2,
#  '옷': 2,
#  '상': 2,
#  '꼭': 2,
#  '아가': 2,
#  '이제': 2,
#  '야외': 2,
#  '듬뿍': 2,
#  '교재': 2,
#  '비대': 2,
#  '방콕': 2,
#  '파인애플': 2,
#  '포트': 2,
#  '타르트': 2,
#  '동래구': 2,
#  '명장동': 2,
#  '이화': 2,
#  '종': 2,
#  '락다운': 2,
#  '효능': 2,
#  '바퀴': 2,
#  '갯벌': 2,
#  '거리': 2,
#  '캐릭터': 2,
#  '습': 2,
#  '꿀잼': 2,
#  '리브': 2,
#  '스': 2,
#  '돼지고기': 2,
#  '댕': 2,
#  '김제': 2,
#  '짤': 2,
#  '협동조합': 2,
#  '정체': 2,
#  '존버': 2,
#  '개미': 2,
#  '원평동': 2,
#  '묵은지': 2,
#  '찜': 2,
#  '추수': 2,
#  '의심': 2,
#  '심바': 2,
#  ...}

# %%
import matplotlib as mpl 
import matplotlib.pyplot as plt 
# %matplotlib inline
# 한글폰트 사용
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %%
import nltk

# %%
bab = nltk.Text(ex_list)
plt.figure()
plt.title('인스타 해시태그_쌀')
bab.plot(30)
plt.show()

# %% [markdown]
# ### 워드클라우드

# %%
import wordcloud

#이미지 불러와서 사용할 것
from PIL import Image  

# 시각화시 글자 선명하게 출력하기 위함
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
# 특정이미지1 이용 워드클라우드 생성
img = np.array(Image.open('image/잘살아보세.png'))
image_color = wordcloud.ImageColorGenerator(img) #이미지의 color 이용
cloud_image = wordcloud.WordCloud(font_path='c:/Windows/Fonts/malgun.ttf',
                                    background_color="white", mask=img).generate_from_frequencies(words)

plt.figure(figsize=(10, 10))
plt.imshow(cloud_image.recolor(color_func=image_color),
           interpolation="bilinear")
plt.axis("off") #축설정 off
plt.show()
plt.savefig("인스타_쌀_워드클라우드.png") #이미지 파일로 저장
