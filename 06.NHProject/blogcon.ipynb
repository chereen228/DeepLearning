# %%
import pandas as pd

# %%
data1=pd.read_excel("2020_1_blog.xlsx")
data2=pd.read_excel("2020_2_blog.xlsx")
data3=pd.read_excel("2020_3_blog.xlsx")
data4=pd.read_excel("2020_4_blog.xlsx")
data5=pd.read_excel("2020_5_blog.xlsx")
data6 = pd.read_excel("2020_6_blog.xlsx")

data7=pd.read_excel("2020_7_blog.xlsx")
data8=pd.read_excel("2020_8_blog.xlsx")
data9=pd.read_excel("2020_9_blog.xlsx")
data10=pd.read_excel("2020_10_blog.xlsx")
data11=pd.read_excel("2020_11_blog.xlsx")
data12 = pd.read_excel("2020_12_blog.xlsx")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1049 entries, 0 to 1048
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    1049 non-null   object
#  1   date     1049 non-null   object
#  2   chat     426 non-null    object
#  3   content  1023 non-null   object
#  4   id       1026 non-null   object
# dtypes: object(5)
# memory usage: 41.1+ KB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    1050 non-null   object
#  1   date     1050 non-null   object
#  2   chat     487 non-null    object
#  3   content  1033 non-null   object
#  4   id       1037 non-null   object
# dtypes: object(5)
# memory usage: 41.1+ KB

# %%
total=pd.concat([data1, data2, data3, data4, data5,
           data6, data7, data8, data9, data10, data11, data12], axis=0)

# %%
total.to_excel("2020blog.xlsx")

# %%
total["id"].value_counts()
# Out:
# (junghee_byunggwa)    100
# (loveme4488)           76
# (noorookflower)        51
# (ssuny1207)            47
# (ikkkejw)              46
#                      ...
# (kkiae956)              1
# (789789789123)          1
# (rationally)            1
# (froch)                 1
# (gana9269)              1
# Name: id, Length: 6546, dtype: int64

# %%
total
# Out:
#                                     title         date  \
# 0                 초기이유식 : 소고기미음 (올가쌀가루이용)  2020.01.20.
# 1                재료의 산책 | 건강한 단맛, 한살림 쌀조청  2020.01.16.
# 2        [3-1]누룩과 효모를 사용 쌀 막걸리 집에서 직접 만들기  2020.01.17.
# 3                        59쌀피자 반미터피자 1타4피  2020.01.17.
# 4                      아기떡뻥 지후쌀과자 이것만 먹어요  2020.01.02.
# ...                                   ...          ...
# 1045  [안양맛집] 지나가다 들러본 삼막사 찐빵 안양 맛집 민준식쌀찐빵  2020.12.07.
# 1046        강화도 [교동] 나들이- 팥옹심이, 뚱이호떡, 쌀찐빵  2020.12.19.
# 1047                  [곤약면후기] 도담쌀곤약면 구매후기  2020.12.29.
# 1048                          무지개쌀케이크클래스❤  2020.12.12.
# 1049  마켓컬리 후기(호떡당 꿀호떡,사미헌 갈비탕,경주미정당 쌀떡...  2020.12.03.
#
#                                                    chat  \
# 0                                       공감가는 내용이네요 >.<
# 1     한살림님 글 잘 보고 가요~^^\n오늘도 행복한 하루 보내세요~ 포스팅 구경왔습니다...
# 2     막걸리 공장 채렸나봐 ^^ 전통주 양조장 공장장입니다 ㅋㅋㅋ 워매🤭 ㅎㅎㅎ 형님 막...
# 3     우왓!!!! 이런 피자가 있었군요~!!! 저도 먹어보고 싶네요~ 저 고구마무스피자는...
# ...

# %%
total["id"].value_counts().head(20)
# Out:
# (junghee_byunggwa)    100
# (loveme4488)           76
# (noorookflower)        51
# (ssuny1207)            47
# (ikkkejw)              46
# (jane2296)             38
# (hhj4514)              37
# (cakejoy1)             37
# (sj2157)               33
# (shinhaw03)            33
# (mycojake2)            32
# (white_witch7)         31
# (ricemuseum1)          30
# (showoo3)              30
# (kaylays)              29
# (wanis_handmade)       28
# (rongg831)             27
# (263709)               26
# (boo1025)              26
# (jiyongblue)           26
# Name: id, dtype: int64

# %%
idto=pd.DataFrame(total["id"].value_counts().head(44))
idto.to_csv("id.csv")

# %%
idva=total["id"].value_counts()
idvali=idva[idva >= 15].index.tolist()
idvali
# Out:
# ['(junghee_byunggwa)',
#  '(loveme4488)',
#  '(noorookflower)',
#  '(ssuny1207)',
#  '(ikkkejw)',
#  '(jane2296)',
#  '(hhj4514)',
#  '(cakejoy1)',
#  '(sj2157)',
#  '(shinhaw03)',
#  '(mycojake2)',
#  '(white_witch7)',
#  '(ricemuseum1)',
#  '(showoo3)',
#  '(kaylays)',
#  '(wanis_handmade)',
#  '(rongg831)',
#  '(263709)',
#  '(boo1025)',
#  '(jiyongblue)',
#  '(alelsl1004)',
#  '(saintyum)',
#  '(yuhwa200)',
#  '(repo0530)',
#  '(essal9070)',
#  '(jaempa)',
#  '(krfa_blog)',
#  '(queenofbank)',
#  '(77nayeon)',
#  '(cmcsong)',
#  '(ash6537)',
#  '(lovehye0522)',
#  '(mkl3858)',
#  '(000714riwon)',
#  '(xofuss7)',
#  '(ji2759)',
#  '(loveufany84)',
#  '(bbcompany00)',
#  '(luckylip23)',
#  '(headxxl)',
#  '(kohj007)',
#  '(bboddek)',
#  '(ek35)',
#  '(seolgien)']

# %%
total2=total
for i in idvali:
    total2 = total2[total2["id"] != i]
total2 = total2.iloc[:, :5]
total2
# Out:
#                                     title         date  \
# 0                 초기이유식 : 소고기미음 (올가쌀가루이용)  2020.01.20.
# 1                재료의 산책 | 건강한 단맛, 한살림 쌀조청  2020.01.16.
# 2        [3-1]누룩과 효모를 사용 쌀 막걸리 집에서 직접 만들기  2020.01.17.
# 3                        59쌀피자 반미터피자 1타4피  2020.01.17.
# 4                      아기떡뻥 지후쌀과자 이것만 먹어요  2020.01.02.
# ...                                   ...          ...
# 1045  [안양맛집] 지나가다 들러본 삼막사 찐빵 안양 맛집 민준식쌀찐빵  2020.12.07.
# 1046        강화도 [교동] 나들이- 팥옹심이, 뚱이호떡, 쌀찐빵  2020.12.19.
# 1047                  [곤약면후기] 도담쌀곤약면 구매후기  2020.12.29.
# 1048                          무지개쌀케이크클래스❤  2020.12.12.
# 1049  마켓컬리 후기(호떡당 꿀호떡,사미헌 갈비탕,경주미정당 쌀떡...  2020.12.03.
#
#                                                    chat  \
# 0                                       공감가는 내용이네요 >.<
# 1     한살림님 글 잘 보고 가요~^^\n오늘도 행복한 하루 보내세요~ 포스팅 구경왔습니다...
# 2     막걸리 공장 채렸나봐 ^^ 전통주 양조장 공장장입니다 ㅋㅋㅋ 워매🤭 ㅎㅎㅎ 형님 막...
# 3     우왓!!!! 이런 피자가 있었군요~!!! 저도 먹어보고 싶네요~ 저 고구마무스피자는...
# ...

# %%
total2[total2['content'].str.contains("가방") == True]
# Out:
#                                   title         date  \
# 131       아이간식으로 딱인 아기떡뻥, 지후쌀과자에서 준비했어요  2020.01.07.
# 552  [영아뜰리에] 쌀조청 도라지정과 창원 마산 진해 명절선물...  2020.01.13.
# 560                해외여행 짐 쌀 때 확인하고 가세요~  2020.01.11.
# 685                               쌀바나나빵  2020.01.08.
# 698         100% 쌀로만 만든 임남한과 선물세트로 딱 좋네  2020.01.20.
# ..                                  ...          ...
# 263     울산키즈쿠킹 율아케이크에서 쌀쿠키만들기 원데이클레스...  2020.12.02.
# 606          대구 성서홈플러스 송사부수제쌀고로케 역시 맛있네  2020.12.22.
# 780         마이쁘띠디저트: 눈꽃 쌀 브라우니로 간식선물하세요  2020.12.22.
# 877               전주 신시가지 쌀로 만든 디저트 미과당  2020.12.16.
# 994    수제쿠키 캐릭터쿠키 온새미로야 수제쌀디저트 건강한간식 추천  2020.12.28.
#
#                                                   chat  \
# 131                                                NaN
# 552                                                NaN
# 560  이번 주말은 미세먼지땜시\n꼼짝없이 방콕해야할듯하네요.\n건강 유의하시고 알찬 휴일...
# 685                                                NaN
# ...

# %%
total2["id"].value_counts()
# Out:
# (rudal0070)      14
# (rda2448)        13
# (yedi_yd)        13
# (flowerscake)    13
# (jkmiii89)       13
#                  ..
# (curel)           1
# (alltoowell)      1
# (cuteelfs)        1
# (since121215)     1
# (skckzo83)        1
# Name: id, Length: 6502, dtype: int64

# %%
norice=["가방",  "짐", " 똥", "오줌",  "도시락", "59쌀피자", "지이팜", "리퀘", "Resoruce", "쌀흥하는", "색쌀", "쌀스럽다", "우리쌀님", "닭모이용", "카인", "힐더", "소환권",  "마리쌀"]

for i in norice:
    total2=total2[total2['content'].str.contains(i) != True]
total2
# Out:
#                                     title         date  \
# 0                 초기이유식 : 소고기미음 (올가쌀가루이용)  2020.01.20.
# 1                재료의 산책 | 건강한 단맛, 한살림 쌀조청  2020.01.16.
# 2        [3-1]누룩과 효모를 사용 쌀 막걸리 집에서 직접 만들기  2020.01.17.
# 4                      아기떡뻥 지후쌀과자 이것만 먹어요  2020.01.02.
# 5              비건음료 라이스 밀크 U 토종쌀로 만드는 건강식  2020.01.20.
# ...                                   ...          ...
# 1044          가자미 구이와 참치전 만들기_푸드림스 현미 쌀가루  2020.12.13.
# 1046        강화도 [교동] 나들이- 팥옹심이, 뚱이호떡, 쌀찐빵  2020.12.19.
# 1047                  [곤약면후기] 도담쌀곤약면 구매후기  2020.12.29.
# 1048                          무지개쌀케이크클래스❤  2020.12.12.
# 1049  마켓컬리 후기(호떡당 꿀호떡,사미헌 갈비탕,경주미정당 쌀떡...  2020.12.03.
#
#                                                    chat  \
# 0                                       공감가는 내용이네요 >.<
# 1     한살림님 글 잘 보고 가요~^^\n오늘도 행복한 하루 보내세요~ 포스팅 구경왔습니다...
# 2     막걸리 공장 채렸나봐 ^^ 전통주 양조장 공장장입니다 ㅋㅋㅋ 워매🤭 ㅎㅎㅎ 형님 막...
# 4     ㅋㅋㅋㅋㅋㅋ우리현이 진짜\n지후꺼 너무나 조아했는데 ㅋㅋ\n그립다. ㅋ ㅋ저때가 지...
# ...

# %%
nnorice = ["판매", "드림", "유학", "청정원", "배달직원",
          "알바", "이벤트", "팝니다", "한율", "거래", "공지"]

for i in nnorice:
    total2 = total2[total2['content'].str.contains(i) != True]
total2
# Out:
#                                     title         date  \
# 0                 초기이유식 : 소고기미음 (올가쌀가루이용)  2020.01.20.
# 1                재료의 산책 | 건강한 단맛, 한살림 쌀조청  2020.01.16.
# 2        [3-1]누룩과 효모를 사용 쌀 막걸리 집에서 직접 만들기  2020.01.17.
# 4                      아기떡뻥 지후쌀과자 이것만 먹어요  2020.01.02.
# 5              비건음료 라이스 밀크 U 토종쌀로 만드는 건강식  2020.01.20.
# ...                                   ...          ...
# 1042                햅쌀 맛있는 밥맛 명월농장 쌀 10kg  2020.12.26.
# 1046        강화도 [교동] 나들이- 팥옹심이, 뚱이호떡, 쌀찐빵  2020.12.19.
# 1047                  [곤약면후기] 도담쌀곤약면 구매후기  2020.12.29.
# 1048                          무지개쌀케이크클래스❤  2020.12.12.
# 1049  마켓컬리 후기(호떡당 꿀호떡,사미헌 갈비탕,경주미정당 쌀떡...  2020.12.03.
#
#                                                    chat  \
# 0                                       공감가는 내용이네요 >.<
# 1     한살림님 글 잘 보고 가요~^^\n오늘도 행복한 하루 보내세요~ 포스팅 구경왔습니다...
# 2     막걸리 공장 채렸나봐 ^^ 전통주 양조장 공장장입니다 ㅋㅋㅋ 워매🤭 ㅎㅎㅎ 형님 막...
# 4     ㅋㅋㅋㅋㅋㅋ우리현이 진짜\n지후꺼 너무나 조아했는데 ㅋㅋ\n그립다. ㅋ ㅋ저때가 지...
# ...

# %%
6404/10748
# Out:
# 0.5958317826572386

# %%
2/100
# Out:
# 0.02

# %%
nnorice = ["판매", "드림", "유학", "청정원", "배달직원",
           "알바", "이벤트", "팝니다", "한율", "거래", "공지"]

for i in nnorice:
    total2 = total2[total2['content'].str.contains(i) != True]
total2

# %%
nnnorice = ["쌀화환", "쌀레에빼배", "쌀박물관", "쌀쌀한 날씨", "쌀뗴냐", "쌀 부가세", "그래프",
'북한', "항쟁", '의원',"닭모이",
"골동품", '민속품','놀이', "빨대",'스킨', "토너", "에센스", "한율","조성", '시범', '분배', "공양"]

# %%
for i in nnnorice:
    total2 = total2[total2['content'].str.contains(i) != True]
total2
# Out:
#                                     title         date  \
# 0                 초기이유식 : 소고기미음 (올가쌀가루이용)  2020.01.20.
# 1                재료의 산책 | 건강한 단맛, 한살림 쌀조청  2020.01.16.
# 2        [3-1]누룩과 효모를 사용 쌀 막걸리 집에서 직접 만들기  2020.01.17.
# 4                      아기떡뻥 지후쌀과자 이것만 먹어요  2020.01.02.
# 5              비건음료 라이스 밀크 U 토종쌀로 만드는 건강식  2020.01.20.
# ...                                   ...          ...
# 1041             글루텐 걱정없는 건강간식 - 채운푸드 쌀쿠키  2020.12.26.
# 1042                햅쌀 맛있는 밥맛 명월농장 쌀 10kg  2020.12.26.
# 1047                  [곤약면후기] 도담쌀곤약면 구매후기  2020.12.29.
# 1048                          무지개쌀케이크클래스❤  2020.12.12.
# 1049  마켓컬리 후기(호떡당 꿀호떡,사미헌 갈비탕,경주미정당 쌀떡...  2020.12.03.
#
#                                                    chat  \
# 0                                       공감가는 내용이네요 >.<
# 1     한살림님 글 잘 보고 가요~^^\n오늘도 행복한 하루 보내세요~ 포스팅 구경왔습니다...
# 2     막걸리 공장 채렸나봐 ^^ 전통주 양조장 공장장입니다 ㅋㅋㅋ 워매🤭 ㅎㅎㅎ 형님 막...
# 4     ㅋㅋㅋㅋㅋㅋ우리현이 진짜\n지후꺼 너무나 조아했는데 ㅋㅋ\n그립다. ㅋ ㅋ저때가 지...
# ...

# %%
import hangul_font
import warnings
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import time
import numpy as np
import pandas as pd
from selenium.webdriver.common.keys import Keys
import urllib.request as req
import urllib.parse as par
from konlpy.tag import Okt
from collections import Counter
import wordcloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

warnings.filterwarnings(action='ignore')

# %%
total2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5876 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    5876 non-null   object
#  1   date     5876 non-null   object
#  2   chat     2845 non-null   object
#  3   content  5625 non-null   object
#  4   id       5660 non-null   object
# dtypes: object(5)
# memory usage: 275.4+ KB

# %%
total2 = total2.dropna(axis=0, how='any', subset=['content'])
total2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5625 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    5625 non-null   object
#  1   date     5625 non-null   object
#  2   chat     2820 non-null   object
#  3   content  5625 non-null   object
#  4   id       5607 non-null   object
# dtypes: object(5)
# memory usage: 263.7+ KB

# %%
total2 = total2.reset_index()
total2
# Out:
#       level_0  index                                title         date  \
# 0           0      0              초기이유식 : 소고기미음 (올가쌀가루이용)  2020.01.20.
# 1           1      1             재료의 산책 | 건강한 단맛, 한살림 쌀조청  2020.01.16.
# 2           2      2     [3-1]누룩과 효모를 사용 쌀 막걸리 집에서 직접 만들기  2020.01.17.
# 3           3      4                   아기떡뻥 지후쌀과자 이것만 먹어요  2020.01.02.
# 4           4      5           비건음료 라이스 밀크 U 토종쌀로 만드는 건강식  2020.01.20.
# ...       ...    ...                                  ...          ...
# 5620     5620   1041             글루텐 걱정없는 건강간식 - 채운푸드 쌀쿠키  2020.12.26.
# 5621     5621   1042                햅쌀 맛있는 밥맛 명월농장 쌀 10kg  2020.12.26.
# 5622     5622   1047                  [곤약면후기] 도담쌀곤약면 구매후기  2020.12.29.
# 5623     5623   1048                          무지개쌀케이크클래스❤  2020.12.12.
# 5624     5624   1049  마켓컬리 후기(호떡당 꿀호떡,사미헌 갈비탕,경주미정당 쌀떡...  2020.12.03.
#
#                                                    chat  \
# 0                                       공감가는 내용이네요 >.<
# ...

# %%
total2.iloc[:,2:]
# Out:
#                                     title         date  \
# 0                 초기이유식 : 소고기미음 (올가쌀가루이용)  2020.01.20.
# 1                재료의 산책 | 건강한 단맛, 한살림 쌀조청  2020.01.16.
# 2        [3-1]누룩과 효모를 사용 쌀 막걸리 집에서 직접 만들기  2020.01.17.
# 3                      아기떡뻥 지후쌀과자 이것만 먹어요  2020.01.02.
# 4              비건음료 라이스 밀크 U 토종쌀로 만드는 건강식  2020.01.20.
# ...                                   ...          ...
# 5620             글루텐 걱정없는 건강간식 - 채운푸드 쌀쿠키  2020.12.26.
# 5621                햅쌀 맛있는 밥맛 명월농장 쌀 10kg  2020.12.26.
# 5622                  [곤약면후기] 도담쌀곤약면 구매후기  2020.12.29.
# 5623                          무지개쌀케이크클래스❤  2020.12.12.
# 5624  마켓컬리 후기(호떡당 꿀호떡,사미헌 갈비탕,경주미정당 쌀떡...  2020.12.03.
#
#                                                    chat  \
# 0                                       공감가는 내용이네요 >.<
# 1     한살림님 글 잘 보고 가요~^^\n오늘도 행복한 하루 보내세요~ 포스팅 구경왔습니다...
# 2     막걸리 공장 채렸나봐 ^^ 전통주 양조장 공장장입니다 ㅋㅋㅋ 워매🤭 ㅎㅎㅎ 형님 막...
# 3     ㅋㅋㅋㅋㅋㅋ우리현이 진짜\n지후꺼 너무나 조아했는데 ㅋㅋ\n그립다. ㅋ ㅋ저때가 지...
# ...

# %%
q = " "
for i in range(5625):
    try:
     q += total2['content'][i]
    except:
     pass

# %%
nouns_tagger = Okt()

nouns = nouns_tagger.nouns(q)

count = Counter(nouns)

count
# Out:
# Counter({'초기': 2396,
#          '이유식': 7893,
#          '단계': 1027,
#          '소고기': 2017,
#          '미음': 4294,
#          '차례': 95,
#          '나': 2148,
#          '책': 460,
#          '보고': 1017,
#          '사두': 26,
#          '그냥': 2042,
#          '인터넷': 222,
#          '중': 1822,
#          '큐브': 365,
#          '무': 992,
#          '엄마': 1725,
#          '때': 6883,
#          '참고': 708,
#          '블로그': 382,
#          '도서관': 30,
#          '개': 3003,
#          '쌀': 43072,
#          '다음': 1733,
#          '순서': 74,
#          '하나': 2410,
#          '야채': 835,
#          '철분': 114,
#          '위해': 1551,
#          '완분임': 1,
#          '포스팅': 687,
#          '지난': 351,
#          '백화점': 83,
#          '아기': 2510,
#          '이유': 665,
#          '식용': 76,
#          '한우': 62,
#          '고기': 556,
#          '총': 533,
#          '최대한': 209,
#          '지방': 173,
#          '는걸': 151,
#          '달라': 417,
#          '분해': 300,
#          '포장': 1864,
# ...

# %%
remove_char_counter = Counter({x: count[x] for x in count if len(x) > 1})
# remove_char_counter = Counter(
#     {x: remove_char_counter[x] for x in count if x not in stopwords})

print(remove_char_counter)
# Out:
# Counter({'가루': 8635, '이유식': 7893, '미음': 4294, '정도': 4084, '사용': 3843, '우리': 3821, '아이': 3316, '보관': 3276, '생각': 3253, '과자': 3233, '재료': 3077, '시작': 2950, '선택': 2878, '케이크': 2787, '정말': 2650, '오늘': 2613, '주문': 2589, '만들기': 2570, '현미': 2565, '아기': 2510, '때문': 2480, '하나': 2410, '초기': 2396, '반죽': 2356, '준비': 2355, '시간': 2322, '간식': 2296, '곤약': 2196, '조금': 2194, '옵션': 2138, '바로': 2138, '화질': 2110, '처음': 2084, '떡볶이': 2080, '유기농': 2047, '그냥': 2042, '소고기': 2017, '완성': 1928, '밀가루': 1911, '한번': 1869, '포장': 1864, '요즘': 1742, '다음': 1733, '느낌': 1729, '엄마': 1725, '가지': 1717, '설탕': 1664, '베이': 1659, '제품': 1606, '쿠키': 1605, '사진': 1576, '식빵': 1573, '방법': 1569, '먹기': 1567, '위해': 1551, '이제': 1544, '추천': 1527, '진짜': 1497, '백미': 1454, '찹쌀': 1439, '구매': 1433, '다른': 1428, '이번': 1425, '발효': 1422, '아주': 1414, '누룩': 1393, '이용': 1353, '버터': 1349, '우유': 1307, '가격': 1286, '건강': 1283, '치즈': 1276, '소금': 1273, '마음': 1267, '선물': 1252, '도정': 1250, '살짝': 1243, '식감': 1228, '사람': 1210, '레시피': 1204, '다시': 1183, '크림': 118
# ...

# %%
import nltk
from nltk.corpus import webtext
from nltk.probability import FreqDist
fregra = nltk.FreqDist(remove_char_counter)


fregra.plot(35)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
