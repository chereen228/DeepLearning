# %%
import numpy as np
import pandas as pd
import MeCab
import re
import networkx as nx
import matplotlib.pyplot as plt
plt.rc('font',family='AppleGothic')

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
data1=pd.read_excel("data/se/preprocessing_2015_cafe_ssal.xlsx")
data2=pd.read_excel("data/se/naver_cafe_ssal_contents_2019_전처리완.xlsx")
data3=pd.read_excel("data/se/2020cafere.xlsx")

# %%
data1.info()
data2.info()
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9653 entries, 0 to 9652
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9653 non-null   int64
#  1   title       9653 non-null   object
#  2   nickname    9653 non-null   object
#  3   date        9653 non-null   object
#  4   content     9607 non-null   object
#  5   comments    8912 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 452.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9554 entries, 0 to 9553
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     9554 non-null   object
#  1   nickname  9554 non-null   object
#  2   date      9554 non-null   object
#  3   content   9549 non-null   object
#  4   comments  9036 non-null   object
# dtypes: object(5)
# memory usage: 373.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10050 entries, 0 to 10049
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10050 non-null  int64
#  1   title       10050 non-null  object
#  2   nickname    10047 non-null  object
#  3   date        10050 non-null  object
#  4   content     10023 non-null  object
#  5   comments    9703 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 471.2+ KB

# %%
d1=pd.concat([data1,data2])
d1=d1[["date","content"]]
d1
# Out:
#             date                                            content
# 0     2015.01.27  세종시로 올해 1월 10일 이사했습니다.어제 쌀이 똑 떨어졌는데 마침 까페에 쌀공구...
# 1     2015.01.04  저희 큰아버지께서 쌀도매를 하세요^^빨간쌀 이예요.저도 작녁부터 계속 먹고있는데요^...
# 2     2015.01.13                                제가 변비가 심해서 현미쌀100%를
# 3     2015.01.12  그동안 계속 공구후기며 공구게시판에서 보던 쌀찐빵을 구입했어요 아기간식도 요즘 고민...
# 4     2015.01.11  심심한 일요일 오후.당근쌀머핀 만들어 보았어요~당근이랑 우유는 휘리릭 갈아주고밀가루...
# ...          ...                                                ...
# 9549  2019.12.17                     쌀과자 냠냠 맛있게 먹으며 열심히 즐겁게 공부해봐요~💕
# 9550  2019.12.13           저울은 준비를 안했어요분유스푼으로 쌀가루 몇그램 나올까요?초기이유식입니다
# 9551  2019.12.24    *오늘의 최저가 정보롯데 백화점 납품 10kg 쌀등급 상두개 구매 개당 23.7...
# 9552  2019.12.15  쌀튀밥 두개 (유통기한 2020.3.17)어그 130사이즈(사용감 잇네용)검정 운동...
# 9553  2019.12.01  맘마밀 안심이유식 단호박과 소고기 5개사과와 고구마 퓨레 4개 (20년 5월까지)요...
#
# [19207 rows x 2 columns]

# %%
d2=data3[["date","content"]]
d2
# Out:
#               date                                            content
# 0       2020.07.06  #RICEBAKING#쌀구움과자→←장여진, 채미희 지음경향미디어메마른 쌀베이킹계의단...
# 1       2020.07.28  먹던게있어서 식탁밑에 보관만하다가 개봉햇더니만ᆢ쌀이 눈에 보이게 딱 구분되어있는거 ...
# 2       2020.07.22        어제 쌀이 똑 떨어져서 ...한인마트 가기는 너무 멀고 동네 수퍼 스토어...
# 3       2020.07.22  가와지쌀 쌕깔이 원래 이렇개누리끼리한가요?살짝 푸루딩긴힌것같기도하고.. 쌀냄새도 쫌...
# 4       2020.07.30  해원고 쌀꾸러미 한두달전에 받은듯해요얼마전 남은 쌀다먹고 5키로짜리 쌀 맛나게 잘먹...
# ...            ...                                                ...
# 10045  2020.08.07.  친정에서 지난주에 쌀을가져왔는데 \n저희먹을거빼고 10키로짜리 2만원에판매합니다\n...
# 10046  2020.08.20.  세상에 오대쌀 산지 이주된거같은데..ㅠ\n지퍼백보관했고요\n10키로 반반해서 하나는...
# 10047  2020.08.16.  인터넷검색하니\n\n20배라해서\n\n쌀가루 20그람에 물400넣고 이유식 돌리니ㅠ...
# 10048  2020.08.18.   일반쌀 20kg, 찹쌀 20kg 미개봉 상태인데 좀 오래되어서 가축 사료용으로 쓰...
# 10049  2020.08.19.  [싱싱채소] 햇고구마, 감자,당근,호박,대파,쌀 배달해드려요~\n~~~~~~텃밭지키...
#
# [10050 rows x 2 columns]

# %%
d3=pd.concat([d1,d2])
d3
# Out:
#               date                                            content
# 0       2015.01.27  세종시로 올해 1월 10일 이사했습니다.어제 쌀이 똑 떨어졌는데 마침 까페에 쌀공구...
# 1       2015.01.04  저희 큰아버지께서 쌀도매를 하세요^^빨간쌀 이예요.저도 작녁부터 계속 먹고있는데요^...
# 2       2015.01.13                                제가 변비가 심해서 현미쌀100%를
# 3       2015.01.12  그동안 계속 공구후기며 공구게시판에서 보던 쌀찐빵을 구입했어요 아기간식도 요즘 고민...
# 4       2015.01.11  심심한 일요일 오후.당근쌀머핀 만들어 보았어요~당근이랑 우유는 휘리릭 갈아주고밀가루...
# ...            ...                                                ...
# 10045  2020.08.07.  친정에서 지난주에 쌀을가져왔는데 \n저희먹을거빼고 10키로짜리 2만원에판매합니다\n...
# 10046  2020.08.20.  세상에 오대쌀 산지 이주된거같은데..ㅠ\n지퍼백보관했고요\n10키로 반반해서 하나는...
# 10047  2020.08.16.  인터넷검색하니\n\n20배라해서\n\n쌀가루 20그람에 물400넣고 이유식 돌리니ㅠ...
# 10048  2020.08.18.   일반쌀 20kg, 찹쌀 20kg 미개봉 상태인데 좀 오래되어서 가축 사료용으로 쓰...
# 10049  2020.08.19.  [싱싱채소] 햇고구마, 감자,당근,호박,대파,쌀 배달해드려요~\n~~~~~~텃밭지키...
#
# [29257 rows x 2 columns]

# %%
data=d3.dropna(axis=0, how='any', subset = ["content"]) 
data=data.reset_index()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29179 entries, 0 to 29178
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    29179 non-null  int64
#  1   date     29179 non-null  object
#  2   content  29179 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 684.0+ KB

# %% [markdown]
# ## 키워드 문장 뽑기

# %%
from collections import Counter
import warnings
warnings.filterwarnings(action='ignore')

# %%
data2 = data.copy()

# %%
for i in range(len(data2)):
    data2["content"][i]=str(data2["content"][i]).replace('네요','네요||-||').replace('하죠','하죠||-||').replace('데요','데요||-||').replace('이네요','이네요||-||').replace('네요.','네요||-||').replace('되죠','되죠||-||').replace('대요','대요||-||').replace('이요','이요||-||').replace('돼요.','돼요||-||').replace('되요','되요||-||').replace('다닙니다','다닙니다||-||').replace('입니다','입니다||-||').replace('입니다.','입니다||-||').replace('니다','니다||-||').replace('중입니다','중입니다||-||').replace('입니다','입니다||-||').replace('나요.','나요||-||').replace('어요','어요||-||').replace('까요','까요||-||').replace('에요','에요||-||').replace('이에요','이에요||-||').replace('봐요','봐요||-||').replace('아요.','아요||-||').replace('해요','해요||-||').replace('려요','려요||-||').replace('구요','구요||-||').replace('고요','고요||-||').replace('죠','죠||-||').replace(':)','').replace('더라','더라||-||').replace('게요','게요||-||').replace('께요','께요||-||').replace('세요','세요||-||').replace('든요','든요||-||').replace('예요','예요||-||').replace('서요','서요||-||').replace('않았다','않았다||-||').replace('었다','었다||-||').replace('있다','있다||-||').replace('이다','이다||-||').replace('싶다','싶다||-||').replace('않다','않다||-||').replace('되었다','되었다||-||').replace('아니다','아니다||-||').replace('하자','하자||-||').replace('는다','는다||-||').replace('했다','했다||-||').replace('한다','한다||-||').replace('혔다','혔다||-||').replace('난다','난다||-||')

# %%
for i in range(len(data2)):
    data2["content"][i]=str(data2["content"][i]).replace('.','').replace('?','').replace('~','').replace('!','').replace('^','').replace('#','').replace('★','').replace('ㅋ','').replace('ㅜ','').replace('ㅠ','').replace('ㅎ','').replace('ㅏ','').replace('ㅡ','')

# %%
data2
# Out:
#        index         date                                            content
# 0          0   2015.01.27  세종시로 올해 1월 10일 이사했습니다||-||어제 쌀이 똑 떨어졌는데 마침 까페에...
# 1          1   2015.01.04  저희 큰아버지께서 쌀도매를 하세요||-||빨간쌀 이예요||-||저도 작녁부터 계속 ...
# 2          2   2015.01.13                                제가 변비가 심해서 현미쌀100%를
# 3          3   2015.01.12  그동안 계속 공구후기며 공구게시판에서 보던 쌀찐빵을 구입했어요||-|| 아기간식도 ...
# 4          4   2015.01.11  심심한 일요일 오후당근쌀머핀 만들어 보았어요||-||당근이랑 우유는 휘리릭 갈아주고...
# ...      ...          ...                                                ...
# 29174  10045  2020.08.07.  친정에서 지난주에 쌀을가져왔는데 \n저희먹을거빼고 10키로짜리 2만원에판매합니다||...
# 29175  10046  2020.08.20.  세상에 오대쌀 산지 이주된거같은데\n지퍼백보관했고요||-||\n10키로 반반해서 하...
# 29176  10047  2020.08.16.  인터넷검색하니\n\n20배라해서\n\n쌀가루 20그람에 물400넣고 이유식 돌리니\...
# 29177  10048  2020.08.18.   일반쌀 20kg, 찹쌀 20kg 미개봉 상태인데 좀 오래되어서 가축 사료용으로 쓰...
# 29178  10049  2020.08.19.  [싱싱채소] 햇고구마, 감자,당근,호박,대파,쌀 배달해드려요||-||\n텃밭지키미 ...
#
# [29179 rows x 3 columns]

# %%
conlist=[]
for i in range(len(data2)):

    a=[]
    a.append(data2["content"][i].split("||-||"))
    
    d=pd.DataFrame(a).T
    d=d[d[0]!=""].reset_index()
    d=d[d[0]!="구요"].reset_index()
    conca1=d[d[0].str.contains("빵|케이크|케익|쿠키|머핀|카스테라|식빵|다쿠아즈|마카롱|버터|초코|크림|오븐|생크림|앙금|반죽|설탕|박력분",na=False)]
    conidex=conca1.index
    list(conidex)


    for i in list(conidex):
        conlist.append(str(d[0][i]))
        #try:
            #conlist.append(+str(d[0][i]))
        #except:
            #pass

# %%
aaaa=pd.DataFrame(conlist)
aaaa
# Out:
#                                                       0
# 0                    그동안 계속 공구후기며 공구게시판에서 보던 쌀찐빵을 구입했어요
# 1           아기간식도 요즘 고민하고 있던 차에 백프로 쌀로 만든 찐빵이니 이거다 싶었어요
# 2                                     쌀찐빵을 구워봐야겠다 생각했어요
# 3            그랫더니 찜기와 후라이팬에서의 두가지가 고루 섞인 더 맛있는 찐빵이 되었어요
# 4           겉은 바삭하고 속은 포근 촉촉넘넘 맛나요 올겨울 착한마을 쌀찐빵과 함께
# ...                                                 ...
# 9334                                 없어가\n\n오늘은 맨빵만 먹어요
# 9335  이번 주, 방앗간 휴가에, 택배 배송 휴가로 난감했는데\n월요일 중요한 백일떡+케이...
# 9336  제주 쑥으로 쌀로만든 \n\n쑥파시통통쌀식빵  저희 부모님께 드리고 싶어\n\n레시...
# 9337        쌀식빵 매번실패해서\n반죽기사고싶어져요\n반죽이잘안되서 잘안부풀어서 그런걸까요
# 9338          종종 박력쌀가루로 쿠키만드는데 박력분보다 식감이 파삭거리고 쿠키가 연약해요
#
# [9339 rows x 1 columns]

# %%
for i in range(len(aaaa)):
    aaaa[0][i]=aaaa[0][i].lstrip()
    aaaa[0][i]=aaaa[0][i].rstrip()

# %%
qw=aaaa.drop_duplicates([0],keep = 'first')
qw.to_excel("cafe_bk.xlsx")
qw
# Out:
#                                                       0
# 0                    그동안 계속 공구후기며 공구게시판에서 보던 쌀찐빵을 구입했어요
# 1           아기간식도 요즘 고민하고 있던 차에 백프로 쌀로 만든 찐빵이니 이거다 싶었어요
# 2                                     쌀찐빵을 구워봐야겠다 생각했어요
# 3            그랫더니 찜기와 후라이팬에서의 두가지가 고루 섞인 더 맛있는 찐빵이 되었어요
# 4               겉은 바삭하고 속은 포근 촉촉넘넘 맛나요 올겨울 착한마을 쌀찐빵과 함께
# ...                                                 ...
# 9334                                 없어가\n\n오늘은 맨빵만 먹어요
# 9335  이번 주, 방앗간 휴가에, 택배 배송 휴가로 난감했는데\n월요일 중요한 백일떡+케이...
# 9336  제주 쑥으로 쌀로만든 \n\n쑥파시통통쌀식빵  저희 부모님께 드리고 싶어\n\n레시...
# 9337        쌀식빵 매번실패해서\n반죽기사고싶어져요\n반죽이잘안되서 잘안부풀어서 그런걸까요
# 9338          종종 박력쌀가루로 쿠키만드는데 박력분보다 식감이 파삭거리고 쿠키가 연약해요
#
# [9221 rows x 1 columns]

# %%
data = pd.read_excel('cafe_bk.xlsx')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9221 entries, 0 to 9220
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9221 non-null   int64
#  1   content     9216 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 144.2+ KB

# %%
data=data.dropna(axis=0, how='any', subset = ["content"]) 
data=data.reset_index()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9216 entries, 0 to 9215
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       9216 non-null   int64
#  1   Unnamed: 0  9216 non-null   int64
#  2   content     9216 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 216.1+ KB

# %%
del data['Unnamed: 0']

# %% [markdown]
# ## 형태소 분석

# %%
data = pd.read_excel('cafe_bk.xlsx')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9221 entries, 0 to 9220
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  9221 non-null   int64
#  1   content     9216 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 144.2+ KB

# %%
data=data.dropna(axis=0, how='any', subset = ["content"]) 
data=data.reset_index()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9216 entries, 0 to 9215
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       9216 non-null   int64
#  1   Unnamed: 0  9216 non-null   int64
#  2   content     9216 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 216.1+ KB

# %%
stopwords = ['천원', '꼭걸', '먹이', '그날', '삭제', '키', '정말', '입', '만', '포스팅', '약간', '정보', '말', '어제', '옵션', '아래', '분', '처음', '개', '년', '혹시', '사람', '시', '추천', '쌀', '애', '저희', '로', '이용', '판매', '체', '가요', '사', '번호', '이제', '나', '을', '경우', '오늘', '아주', '진짜', '모두', '자동', '날', '시골', '는', '손', '생각', '질문', '연락', '살', '역시', '센치', '구입', '끼', '용', '사실', '것', '배', '위', '요즘', '다른', '지금', '불', '시작', '다시', '우리', '은', '사랑', '거', '킹', '제품', '등', '조금', '내', '이후', '앞', '줄', '단계', '이번', '직접', '이', '재생', '좀', '미니', '봉', '가', '맘', '월', '듯', '중', '저', '신분', '첫', '미리', '더', '사용', '여기', '농사', '요', '한번', '작성', '게시', '주문', '어디', '농', '산', '개월', '거의', '안', '를', '완전', '제', '및', '실', '글', '원', '다음', '위해', '곳', '그냥', '구매', '초기', '준비', '도', '계속', '때', '유통', '살짝', '먹기', '후', '나눔', '때모두', '댓글', '알', '규정', '정도', '점', '스푼', '얼마', '화질', '일', '못', '마을', '만원', '아시', '하루', '걸', '전', '바로', '수', '또', '중기', '번', '먼저', '달', '기', '건', '반', '구', '숟가락', '사진', '선택', '사서', '호', '완성', '가지', '뭐', '가장', '내일', '공지', '때문', '방법', '보고', '이상', '끝', '하나', '해', '사항', '한국', '그', '습', '꼭', '왜', '떡뻥']

# %%
def getNVM_lemma(text):
    tokenizer = MeCab.Tagger()
    parsed = tokenizer.parse(text)
    #print(parsed)
    word_tag = [w for w in parsed.split("\n")] 
    pos = []
    tags = ["NNG", "NNP","VV","VA","VCP",'VCN','XR']
   
    for word_ in word_tag[:-2]:
        word = word_.split('\t') #['아버지', 'NNG,*,F,아버지,*,*,*,*']
        tag = word[1].split(",")  #['EC', '*', 'F', '는다', '*', '*', '*', '*']
        if('+' in tag[0]): #단어가 여러 형태소로 구성된 경우
            if ('VV' in tag[0] or 'VA' in tag[0] or 'VX' in tag[0]):
                t = tag[-1].split('/')[0]
                if t not in stopwords:
                    pos.append(t)
        elif ((tag[0] in tags) and (word[0] not in stopwords)):
            pos.append(word[0])
    return pos

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

tf = CountVectorizer(tokenizer=getNVM_lemma, preprocessor=None, lowercase=False)
tdm = tf.fit_transform(data['content'])

# %%
words = tf.get_feature_names()
words
# Out:
# ['ㄱ',
#  'ㄴ',
#  'ㄷ',
#  'ㄹ',
#  'ㅁ',
#  'ㅂ',
#  'ㅅ',
#  'ㅈ',
#  'ㅓ',
#  'ㅣ',
#  '單糖',
#  '外',
#  '愛',
#  '有',
#  '疏',
#  '米',
#  '가감',
#  '가게',
#  '가격',
#  '가격대',
#  '가공',
#  '가공품',
#  '가구',
#  '가까우',
#  '가깝',
#  '가나',
#  '가난',
#  '가능',
#  '가닉',
#  '가동',
#  '가득',
#  '가득차',
#  '가든',
#  '가라앉',
#  '가라앉히',
#  '가람',
#  '가래',
#  '가래떡',
#  '가량',
#  '가렵',
#  '가로',
#  '가루',
#  '가루다',
#  '가루라',
#  '가루소금',
#  '가루아',
#  '가루체',
#  '가르',
#  '가르치',
#  '가르키',
#  '가리',
#  '가리키',
#  '가마솥',
#  '가망',
#  '가물',
#  '가뭄',
#  '가미',
#  '가방',
#  '가베',
#  '가벼우',
#  '가볍',
#  '가보세요',
#  '가성',
#  '가수',
#  '가스',
#  '가스레인지',
#  '가슴',
#  '가슴살',
#  '가습',
#  '가시',
#  '가심',
#  '가아',
#  '가열',
#  '가염',
#  '가요제',
#  '가용',
#  '가운',
#  '가운데',
#  '가위',
#  '가을',
#  '가이드',
#  '가입',
#  '가자미',
#  '가전제품',
#  '가정',
#  '가져가',
#  '가져다주',
#  '가져오',
#  '가족',
#  '가좌리',
#  '가즈',
#  '가토',
#  '가평',
#  '가현',
#  '각각',
#  '각광',
#  '각봉',
#  '각설탕',
#  '각자',
#  '각종',
#  '각지',
#  '각질',
#  '간',
#  '간격',
#  '간단',
#  '간략',
#  '간만',
#  '간소',
#  '간식',
#  '간식거리',
#  '간장',
#  '간증',
#  '간지럽',
#  '간판',
#  '간편',
#  '간하',
#  '갈',
#  '갈게',
#  '갈라',
#  '갈라지',
#  '갈리',
#  '갈릭',
#  '갈비탕',
#  '갈색',
#  '갈아주',
#  '갈아타',
#  '갈일',
#  '감',
#  '감각',
#  '감격',
#  '감고',
#  '감기',
#  '감도',
#  '감동',
#  '감동이',
#  '감로',
#  '감미료',
#  '감바',
#  '감사',
#  '감성',
#  '감소',
#  '감싸',
#  '감안',
#  '감이',
#  '감인',
#  '감자',
#  '감자전',
#  '감자튀김',
#  '감점',
#  '감지',
#  '감질나',
#  '감초',
#  '감칠맛',
#  '감탄',
#  '감탄사',
#  '감태',
#  '감회',
#  '감흥',
#  '갑',
#  '값',
#  '값어치',
#  '값지',
#  '갓',
#  '갔다오',
#  '강',
#  '강남',
#  '강남역',
#  '강남콩',
#  '강냉이',
#  '강도',
#  '강등',
#  '강력',
#  '강력밀가루',
#  '강력분',
#  '강렬',
#  '강변',
#  '강변역',
#  '강북',
#  '강북구',
#  '강사',
#  '강서구',
#  '강습',
#  '강원도',
#  '강의',
#  '강인원',
#  '강정',
#  '강정원',
#  '강좌',
#  '강청',
#  '강추',
#  '강타',
#  '강판',
#  '강하',
#  '강호동',
#  '강화',
#  '갖',
#  '갖추',
#  '같',
#  '갚',
#  '개고생',
#  '개금',
#  '개념',
#  '개당',
#  '개떡',
#  '개량',
#  '개맛',
#  '개모',
#  '개미허리',
#  '개발',
#  '개별',
#  '개봉',
#  '개분',
#  '개선',
#  '개성',
#  '개시',
#  '개양',
#  '개업',
#  '개운',
#  '개인',
#  '개인차',
#  '개청',
#  '개체',
#  '개취',
#  '개합',
#  '객',
#  '갠',
#  '갤러',
#  '갤러리',
#  '갯',
#  '갯벌',
#  '갱',
#  '갱신',
#  '갱엿',
#  '거구',
#  '거다리',
#  '거들',
#  '거들뜨',
#  '거려',
#  '거르',
#  '거리',
#  '거무죽죽',
#  '거미줄',
#  '거부',
#  '거북',
#  '거슬리',
#  '거실',
#  '거주',
#  '거진',
#  '거첨',
#  '거치',
#  '거칠',
#  '거트',
#  '거품',
#  '거품기',
#  '거피',
#  '거하',
#  '걱정',
#  '걱정하지마',
#  '건강',
#  '건강미',
#  '건강식',
#  '건과',
#  '건너',
#  '건너가',
#  '건너편',
#  '건네',
#  '건대',
#  '건도',
#  '건드리',
#  '건무',
#  '건물',
#  '건백',
#  '건빵',
#  '건살구',
#  '건새',
#  '건성',
#  '건식',
#  '건식품',
#  '건어물',
#  '건자',
#  '건전',
#  '건조',
#  '건조기',
#  '건지',
#  '건포도',
#  '건호',
#  '걷',
#  '걸리',
#  '걸어가',
#  '걸어오',
#  '걸음',
#  '걸이',
#  '걸죽',
#  '걸죽하',
#  '걸쭉',
#  '걸치',
#  '검',
#  '검사',
#  '검색',
#  '검은깨',
#  '검은콩',
#  '검정',
#  '검정깨',
#  '검정콩',
#  '검증',
#  '검지',
#  '겁나',
#  '겁내',
#  '겉',
#  '겉도',
#  '겉면',
#  '겉절이',
#  '겉피',
#  '게',
#  '게다',
#  '게시물',
#  '게시판',
#  '게으르',
#  '게으름',
#  '게이블',
#  '게이트',
#  '게임',
#  '겐츠',
#  '겔',
#  '겔러',
#  '겟',
#  '겨',
#  '겨울',
#  '겨울철',
#  '격',
#  '격리',
#  '겪',
#  '견',
#  '견과',
#  '견디',
#  '견해',
#  '결',
#  '결결',
#  '결과',
#  '결과물',
#  '결국',
#  '결론',
#  '결심',
#  '결정',
#  '결제',
#  '결혼',
#  '결혼기념일',
#  '결혼식',
#  '겸용',
#  '겹',
#  '겹치',
#  '겻',
#  '경기',
#  '경기도',
#  '경남',
#  '경단',
#  '경력',
#  '경미',
#  '경복궁',
#  '경부',
#  '경비실',
#  '경산',
#  '경상남도',
#  '경수진',
#  '경전철',
#  '경제',
#  '경주',
#  '경주로',
#  '경치',
#  '경품',
#  '경향',
#  '경험',
#  '경화',
#  '경화동',
#  '경황',
#  '곁',
#  '곁들',
#  '곁들이',
#  '계',
#  '계기',
#  '계단',
#  '계동',
#  '계란',
#  '계란밥',
#  '계란빵',
#  '계량',
#  '계량스푼',
#  '계량컵',
#  '계룡',
#  '계발',
#  '계산',
#  '계서',
#  '계석',
#  '계시',
#  '계심',
#  '계약자',
#  '계열',
#  '계절',
#  '계피',
#  '계획',
#  '고',
#  '고감',
#  '고객',
#  '고고',
#  '고구마',
#  '고급',
#  '고기',
#  '고기만두',
#  '고기야채죽',
#  '고다',
#  '고당',
#  '고대',
#  '고도',
#  '고되',
#  '고두밥',
#  '고등어',
#  '고래',
#  '고려',
#  '고로',
#  '고로케',
#  '고르',
#  '고르드',
#  '고만하',
#  '고맙',
#  '고명',
#  '고모님',
#  '고무',
#  '고무신',
#  '고문',
#  '고물',
#  '고민',
#  '고방',
#  '고배',
#  '고상',
#  '고생',
#  '고선',
#  '고성',
#  '고소',
#  '고속',
#  '고수',
#  '고시히카리',
#  '고아',
#  '고앙',
#  '고열',
#  '고염',
#  '고와',
#  '고요',
#  '고용',
#  '고우',
#  '고운',
#  '고유',
#  '고이',
#  '고자',
#  '고장',
#  '고장나',
#  '고정',
#  '고즈넉',
#  '고지',
#  '고지서',
#  '고집',
#  '고창',
#  '고첨',
#  '고체',
#  '고촌읍',
#  '고추',
#  '고추밭',
#  '고추장',
#  '고춧가루',
#  '고치',
#  '고품질',
#  '고프',
#  '고하',
#  '고한',
#  '고현',
#  '고혜진',
#  '곡물',
#  '곡성',
#  '곡식',
#  '곤란',
#  '곤약',
#  '곤지암',
#  '골',
#  '골드',
#  '골든벨',
#  '곰',
#  '곰돌이',
#  '곰보',
#  '곰팡이',
#  '곱',
#  '곳곳',
#  '공',
#  '공간',
#  '공갈빵',
#  '공개',
#  '공구',
#  '공급',
#  '공기',
#  '공기주머니',
#  '공덕',
#  '공략',
#  '공룡',
#  '공립',
#  '공방',
#  '공부',
#  '공부방',
#  '공산품',
#  '공수',
#  '공식',
#  '공신',
#  '공업',
#  '공연',
#  '공영주',
#  '공예',
#  '공원',
#  '공유',
#  '공임',
#  '공작',
#  '공장',
#  '공정',
#  '공존',
#  '공주',
#  '공통',
#  '공판',
#  '공포',
#  '곶감',
#  '과',
#  '과감',
#  '과당',
#  '과도',
#  '과류',
#  '과목',
#  '과일',
#  '과자',
#  '과자점',
#  '과장',
#  '과정',
#  '과제',
#  '과채류',
#  '과천',
#  '과하',
#  '관건',
#  '관계',
#  '관계없',
#  '관광',
#  '관련',
#  '관리',
#  '관심',
#  '관심사',
#  '관악구',
#  '관용',
#  '관하',
#  '광명',
#  '광명시',
#  '광주',
#  '광진구',
#  '광택',
#  '광파',
#  '괜찮',
#  '괴',
#  '괴롭히',
#  '교',
#  '교동',
#  '교실',
#  '교육',
#  '교육청',
#  '교체',
#  '교환',
#  '교환원',
#  '교회',
#  '구경',
#  '구교',
#  '구기자',
#  '구나',
#  '구대',
#  '구두',
#  '구라',
#  '구래',
#  '구로',
#  '구르',
#  '구름',
#  '구리',
#  '구마',
#  '구매처',
#  '구멍',
#  '구묘',
#  '구민',
#  '구방',
#  '구분',
#  '구비',
#  '구성',
#  '구성역',
#  '구세트',
#  '구수',
#  '구슬',
#  '구어',
#  '구여',
#  '구연산',
#  '구용',
#  '구우',
#  '구월동',
#  '구음',
#  '구이',
#  '구정',
#  '구제',
#  '구조',
#  '구지',
#  '구찮',
#  '구체',
#  '구토증',
#  '구포',
#  '구하',
#  '구황',
#  '국',
#  '국가',
#  '국간',
#  '국내',
#  '국내산',
#  '국물',
#  '국민',
#  '국산',
#  '국수',
#  '국제',
#  '군',
#  '군것질',
#  '군고구마',
#  '군더더기',
#  '군데군데',
#  '군사',
#  '군산',
#  '군수',
#  '군요',
#  '군침',
#  '군포',
#  '굳',
#  '굳히',
#  '굳히기',
#  '굴',
#  '굴뚝같',
#  '굴러다니',
#  '굴리',
#  '굴림',
#  '굵',
#  '굵기',
#  '굽',
#  '굽지',
#  '굿',
#  '굿바이',
#  '궁',
#  '궁굼',
#  '궁금',
#  '궁금증',
#  '궁중',
#  '궁합',
#  '궈',
#  '권',
#  '권장',
#  '권하',
#  '권해',
#  '귀',
#  '귀가',
#  '귀국',
#  '귀리',
#  '귀염',
#  '귀염둥이',
#  '귀엽',
#  '귀요',
#  '귀요미',
#  '귀욤',
#  '귀족',
#  '귀찮',
#  '귀채',
#  '귀하',
#  '규',
#  '규칙',
#  '균',
#  '균등',
#  '균일',
#  '균형',
#  '귤정과',
#  '그간',
#  '그동안',
#  '그때',
#  '그라',
#  '그람',
#  '그램',
#  '그러',
#  '그럴싸',
#  '그럴싸하',
#  '그렇',
#  '그레',
#  '그레이',
#  '그레인',
#  '그르',
#  '그릇',
#  '그리',
#  '그리니',
#  '그리워지',
#  '그릭',
#  '그릴',
#  '그림',
#  '그립',
#  '그만',
#  '그만두',
#  '그물',
#  '그어주',
#  '그으르',
#  '그윽',
#  '그을리',
#  '그저께',
#  '그중',
#  '극',
#  '극대',
#  '극동',
#  '극복',
#  '극소량',
#  '극장',
#  '극찬',
#  '근',
#  '근교',
#  '근디',
#  '근래',
#  '근무',
#  '근방',
#  '근원',
#  '근육',
#  '근전',
#  '근처',
#  '근황',
#  '글구',
#  '글라스',
#  '글레이즈',
#  '글루텐',
#  '글리',
#  '글쓰기',
#  '긁',
#  '긁어모으',
#  '금',
#  '금가루',
#  '금값',
#  '금강',
#  '금고',
#  '금과',
#  '금귤',
#  '금단',
#  '금딱지',
#  '금라',
#  '금물',
#  '금산',
#  '금새',
#  '금색',
#  '금식',
#  '금싸라기',
#  '금액',
#  '금양',
#  '금영',
#  '금요일',
#  '금음',
#  '금지',
#  '금지령',
#  '금체',
#  '금촌',
#  '급',
#  '급격',
#  '급급',
#  '급식',
#  '급증',
#  '급초',
#  '급하',
#  '기간',
#  '기검',
#  '기겁',
#  '기계',
#  '기계식',
#  '기공',
#  '기관',
#  '기기',
#  '기네스',
#  '기념',
#  '기념일',
#  '기능',
#  '기능사',
#  '기다',
#  '기다리',
#  '기대',
#  '기대감',
#  '기도',
#  '기두',
#  '기똥차',
#  '기로',
#  '기록',
#  '기르',
#  '기름',
#  '기름기',
#  '기름지',
#  '기름칠',
#  '기막히',
#  '기모',
#  '기본',
#  '기부',
#  '기분',
#  '기쁘',
#  '기쁨',
#  '기사',
#  '기상',
#  '기세',
#  '기숙사',
#  '기술',
#  '기술자',
#  '기스',
#  '기야마',
#  '기약',
#  '기억',
#  '기억나',
#  '기업',
#  '기여',
#  '기예',
#  '기운',
#  '기울어지',
#  '기웃거리',
#  '기원',
#  '기유',
#  '기입',
#  '기재',
#  '기저귀',
#  '기전',
#  '기정떡',
#  '기존',
#  '기준',
#  '기질',
#  '기차',
#  '기철',
#  '기청',
#  '기초',
#  '기침',
#  '기타',
#  '기특',
#  '기포',
#  '기피',
#  '기한',
#  '기호',
#  '기회',
#  '기흥',
#  '긴장',
#  '긷',
#  '길',
#  '길거리',
#  '길다랗',
#  '길들이',
#  '길목',
#  '길이',
#  '길쭉',
#  '김',
#  '김경진',
#  '김밥',
#  '김성훈',
#  '김식',
#  '김영모',
#  '김장',
#  '김재민',
#  '김제',
#  '김진환',
#  '김치',
#  '김치전',
#  '김치찌개',
#  '김태하',
#  '김포',
#  '김포시',
#  '김해',
#  '김해시',
#  '깁',
#  '깃',
#  '깊',
#  '깊이',
#  '까',
#  '까까',
#  '까끼',
#  '까다롭',
#  '까르푸',
#  '까맣',
#  '까먹',
#  '까묵',
#  '까스',
#  '까슬까슬',
#  '까지',
#  '까페',
#  '깍둑썰기',
#  '깍뚝',
#  '깍지',
#  '깎',
#  '깐깐',
#  '깔',
#  '깔끔',
#  '깔때기',
#  '깔리',
#  '깜',
#  '깜놀',
#  '깜빡하',
#  '깜장',
#  '깨',
#  '깨끗',
#  '깨달',
#  '깨닳',
#  '깨물',
#  '깨소금',
#  '깨알',
#  '깨우',
#  '깨우치',
#  '깨지',
#  '깻잎',
#  '꺼',
#  '꺼내',
#  '꺼리',
#  '꺼분',
#  '꺼지',
#  '꺽',
#  '꺾이',
#  '껄',
#  '껍닥',
#  '껍질',
#  '께',
#  '꼬',
#  '꼬깔콘',
#  '꼬꼬',
#  '꼬꼬마',
#  '꼬끄',
#  '꼬리',
#  '꼬마',
#  '꼬맹이',
#  '꼬미',
#  '꼬우',
#  '꼬지',
#  '꼬집',
#  '꼬치',
#  '꼭다리',
#  '꼭대기',
#  '꼴',
#  '꼴배',
#  '꼼꼼',
#  '꼽',
#  '꼽히',
#  '꼿',
#  '꽁',
#  '꽂',
#  '꽂히',
#  '꽃',
#  '꽃가위',
#  '꽃게',
#  '꽃단장',
#  '꽃담',
#  '꽃말',
#  '꽃밭',
#  '꽃샘추위',
#  '꽃잎',
#  '꽃장식',
#  '꽃차',
#  '꽃피',
#  '꽈배기',
#  '꽝',
#  '꾀돌이',
#  '꾸',
#  '꾸리',
#  '꾸미',
#  '꾸준',
#  '꿀',
#  '꿀떡',
#  '꿀맛',
#  '꿈',
#  '꿈꾸',
#  '꿉',
#  '꿰',
#  '끄',
#  '끈',
#  '끈기',
#  '끈끈',
#  '끊',
#  '끊기',
#  '끌',
#  '끌레르',
#  '끌레어',
#  '끌리',
#  '끓',
#  '끓이',
#  '끗',
#  '끝나',
#  '끝내',
#  '끝전',
#  '끼니',
#  '끼식',
#  '끼양',
#  '끼얹',
#  '끼우',
#  '낌',
#  '낌새',
#  '나가',
#  '나가사키',
#  '나기',
#  '나누',
#  '나뉘',
#  '나당',
#  '나두',
#  ...]

# %%
c = Counter(words)

# %%
c
# Out:
# Counter({'ㄱ': 1,
#          'ㄴ': 1,
#          'ㄷ': 1,
#          'ㄹ': 1,
#          'ㅁ': 1,
#          'ㅂ': 1,
#          'ㅅ': 1,
#          'ㅈ': 1,
#          'ㅓ': 1,
#          'ㅣ': 1,
#          '單糖': 1,
#          '外': 1,
#          '愛': 1,
#          '有': 1,
#          '疏': 1,
#          '米': 1,
#          '가감': 1,
#          '가게': 1,
#          '가격': 1,
#          '가격대': 1,
#          '가공': 1,
#          '가공품': 1,
#          '가구': 1,
#          '가까우': 1,
#          '가깝': 1,
#          '가나': 1,
#          '가난': 1,
#          '가능': 1,
#          '가닉': 1,
#          '가동': 1,
#          '가득': 1,
#          '가득차': 1,
#          '가든': 1,
#          '가라앉': 1,
#          '가라앉히': 1,
#          '가람': 1,
#          '가래': 1,
#          '가래떡': 1,
#          '가량': 1,
#          '가렵': 1,
#          '가로': 1,
#          '가루': 1,
#          '가루다': 1,
#          '가루라': 1,
#          '가루소금': 1,
#          '가루아': 1,
#          '가루체': 1,
#          '가르': 1,
#          '가르치': 1,
#          '가르키': 1,
#          '가리': 1,
#          '가리키': 1,
#          '가마솥': 1,
#          '가망': 1,
#          '가물': 1,
#          '가뭄': 1,
#          '가미': 1,
#          '가방': 1,
#          '가베': 1,
#          '가벼우': 1,
#          '가볍': 1,
#          '가보세요': 1,
#          '가성': 1,
#          '가수': 1,
#          '가스': 1,
#          '가스레인지': 1,
#          '가슴': 1,
#          '가슴살': 1,
#          '가습': 1,
#          '가시': 1,
#          '가심': 1,
#          '가아': 1,
#          '가열': 1,
#          '가염': 1,
#          '가요제': 1,
#          '가용': 1,
#          '가운': 1,
#          '가운데': 1,
#          '가위': 1,
#          '가을': 1,
#          '가이드': 1,
#          '가입': 1,
#          '가자미': 1,
#          '가전제품': 1,
#          '가정': 1,
#          '가져가': 1,
#          '가져다주': 1,
#          '가져오': 1,
#          '가족': 1,
#          '가좌리': 1,
#          '가즈': 1,
#          '가토': 1,
#          '가평': 1,
#          '가현': 1,
#          '각각': 1,
#          '각광': 1,
#          '각봉': 1,
#          '각설탕': 1,
#          '각자': 1,
#          '각종': 1,
#          '각지': 1,
#          '각질': 1,
#          '간': 1,
#          '간격': 1,
#          '간단': 1,
#          '간략': 1,
#          '간만': 1,
#          '간소': 1,
#          '간식': 1,
#          '간식거리': 1,
#          '간장': 1,
#          '간증': 1,
#          '간지럽': 1,
#          '간판': 1,
#          '간편': 1,
#          '간하': 1,
#          '갈': 1,
#          '갈게': 1,
#          '갈라': 1,
#          '갈라지': 1,
#          '갈리': 1,
#          '갈릭': 1,
#          '갈비탕': 1,
#          '갈색': 1,
#          '갈아주': 1,
#          '갈아타': 1,
#          '갈일': 1,
#          '감': 1,
#          '감각': 1,
#          '감격': 1,
#          '감고': 1,
#          '감기': 1,
#          '감도': 1,
#          '감동': 1,
#          '감동이': 1,
#          '감로': 1,
#          '감미료': 1,
#          '감바': 1,
#          '감사': 1,
#          '감성': 1,
#          '감소': 1,
#          '감싸': 1,
#          '감안': 1,
#          '감이': 1,
#          '감인': 1,
#          '감자': 1,
#          '감자전': 1,
#          '감자튀김': 1,
#          '감점': 1,
#          '감지': 1,
#          '감질나': 1,
#          '감초': 1,
#          '감칠맛': 1,
#          '감탄': 1,
#          '감탄사': 1,
#          '감태': 1,
#          '감회': 1,
#          '감흥': 1,
#          '갑': 1,
#          '값': 1,
#          '값어치': 1,
#          '값지': 1,
#          '갓': 1,
#          '갔다오': 1,
#          '강': 1,
#          '강남': 1,
#          '강남역': 1,
#          '강남콩': 1,
#          '강냉이': 1,
#          '강도': 1,
#          '강등': 1,
#          '강력': 1,
#          '강력밀가루': 1,
#          '강력분': 1,
#          '강렬': 1,
#          '강변': 1,
#          '강변역': 1,
#          '강북': 1,
#          '강북구': 1,
#          '강사': 1,
#          '강서구': 1,
#          '강습': 1,
#          '강원도': 1,
#          '강의': 1,
#          '강인원': 1,
#          '강정': 1,
#          '강정원': 1,
#          '강좌': 1,
#          '강청': 1,
#          '강추': 1,
#          '강타': 1,
#          '강판': 1,
#          '강하': 1,
#          '강호동': 1,
#          '강화': 1,
#          '갖': 1,
#          '갖추': 1,
#          '같': 1,
#          '갚': 1,
#          '개고생': 1,
#          '개금': 1,
#          '개념': 1,
#          '개당': 1,
#          '개떡': 1,
#          '개량': 1,
#          '개맛': 1,
#          '개모': 1,
#          '개미허리': 1,
#          '개발': 1,
#          '개별': 1,
#          '개봉': 1,
#          '개분': 1,
#          '개선': 1,
#          '개성': 1,
#          '개시': 1,
#          '개양': 1,
#          '개업': 1,
#          '개운': 1,
#          '개인': 1,
#          '개인차': 1,
#          '개청': 1,
#          '개체': 1,
#          '개취': 1,
#          '개합': 1,
#          '객': 1,
#          '갠': 1,
#          '갤러': 1,
#          '갤러리': 1,
#          '갯': 1,
#          '갯벌': 1,
#          '갱': 1,
#          '갱신': 1,
#          '갱엿': 1,
#          '거구': 1,
#          '거다리': 1,
#          '거들': 1,
#          '거들뜨': 1,
#          '거려': 1,
#          '거르': 1,
#          '거리': 1,
#          '거무죽죽': 1,
#          '거미줄': 1,
#          '거부': 1,
#          '거북': 1,
#          '거슬리': 1,
#          '거실': 1,
#          '거주': 1,
#          '거진': 1,
#          '거첨': 1,
#          '거치': 1,
#          '거칠': 1,
#          '거트': 1,
#          '거품': 1,
#          '거품기': 1,
#          '거피': 1,
#          '거하': 1,
#          '걱정': 1,
#          '걱정하지마': 1,
#          '건강': 1,
#          '건강미': 1,
#          '건강식': 1,
#          '건과': 1,
#          '건너': 1,
#          '건너가': 1,
#          '건너편': 1,
#          '건네': 1,
#          '건대': 1,
#          '건도': 1,
#          '건드리': 1,
#          '건무': 1,
#          '건물': 1,
#          '건백': 1,
#          '건빵': 1,
#          '건살구': 1,
#          '건새': 1,
#          '건성': 1,
#          '건식': 1,
#          '건식품': 1,
#          '건어물': 1,
#          '건자': 1,
#          '건전': 1,
#          '건조': 1,
#          '건조기': 1,
#          '건지': 1,
#          '건포도': 1,
#          '건호': 1,
#          '걷': 1,
#          '걸리': 1,
#          '걸어가': 1,
#          '걸어오': 1,
#          '걸음': 1,
#          '걸이': 1,
#          '걸죽': 1,
#          '걸죽하': 1,
#          '걸쭉': 1,
#          '걸치': 1,
#          '검': 1,
#          '검사': 1,
#          '검색': 1,
#          '검은깨': 1,
#          '검은콩': 1,
#          '검정': 1,
#          '검정깨': 1,
#          '검정콩': 1,
#          '검증': 1,
#          '검지': 1,
#          '겁나': 1,
#          '겁내': 1,
#          '겉': 1,
#          '겉도': 1,
#          '겉면': 1,
#          '겉절이': 1,
#          '겉피': 1,
#          '게': 1,
#          '게다': 1,
#          '게시물': 1,
#          '게시판': 1,
#          '게으르': 1,
#          '게으름': 1,
#          '게이블': 1,
#          '게이트': 1,
#          '게임': 1,
#          '겐츠': 1,
#          '겔': 1,
#          '겔러': 1,
#          '겟': 1,
#          '겨': 1,
#          '겨울': 1,
#          '겨울철': 1,
#          '격': 1,
#          '격리': 1,
#          '겪': 1,
#          '견': 1,
#          '견과': 1,
#          '견디': 1,
#          '견해': 1,
#          '결': 1,
#          '결결': 1,
#          '결과': 1,
#          '결과물': 1,
#          '결국': 1,
#          '결론': 1,
#          '결심': 1,
#          '결정': 1,
#          '결제': 1,
#          '결혼': 1,
#          '결혼기념일': 1,
#          '결혼식': 1,
#          '겸용': 1,
#          '겹': 1,
#          '겹치': 1,
#          '겻': 1,
#          '경기': 1,
#          '경기도': 1,
#          '경남': 1,
#          '경단': 1,
#          '경력': 1,
#          '경미': 1,
#          '경복궁': 1,
#          '경부': 1,
#          '경비실': 1,
#          '경산': 1,
#          '경상남도': 1,
#          '경수진': 1,
#          '경전철': 1,
#          '경제': 1,
#          '경주': 1,
#          '경주로': 1,
#          '경치': 1,
#          '경품': 1,
#          '경향': 1,
#          '경험': 1,
#          '경화': 1,
#          '경화동': 1,
#          '경황': 1,
#          '곁': 1,
#          '곁들': 1,
#          '곁들이': 1,
#          '계': 1,
#          '계기': 1,
#          '계단': 1,
#          '계동': 1,
#          '계란': 1,
#          '계란밥': 1,
#          '계란빵': 1,
#          '계량': 1,
#          '계량스푼': 1,
#          '계량컵': 1,
#          '계룡': 1,
#          '계발': 1,
#          '계산': 1,
#          '계서': 1,
#          '계석': 1,
#          '계시': 1,
#          '계심': 1,
#          '계약자': 1,
#          '계열': 1,
#          '계절': 1,
#          '계피': 1,
#          '계획': 1,
#          '고': 1,
#          '고감': 1,
#          '고객': 1,
#          '고고': 1,
#          '고구마': 1,
#          '고급': 1,
#          '고기': 1,
#          '고기만두': 1,
#          '고기야채죽': 1,
#          '고다': 1,
#          '고당': 1,
#          '고대': 1,
#          '고도': 1,
#          '고되': 1,
#          '고두밥': 1,
#          '고등어': 1,
#          '고래': 1,
#          '고려': 1,
#          '고로': 1,
#          '고로케': 1,
#          '고르': 1,
#          '고르드': 1,
#          '고만하': 1,
#          '고맙': 1,
#          '고명': 1,
#          '고모님': 1,
#          '고무': 1,
#          '고무신': 1,
#          '고문': 1,
#          '고물': 1,
#          '고민': 1,
#          '고방': 1,
#          '고배': 1,
#          '고상': 1,
#          '고생': 1,
#          '고선': 1,
#          '고성': 1,
#          '고소': 1,
#          '고속': 1,
#          '고수': 1,
#          '고시히카리': 1,
#          '고아': 1,
#          '고앙': 1,
#          '고열': 1,
#          '고염': 1,
#          '고와': 1,
#          '고요': 1,
#          '고용': 1,
#          '고우': 1,
#          '고운': 1,
#          '고유': 1,
#          '고이': 1,
#          '고자': 1,
#          '고장': 1,
#          '고장나': 1,
#          '고정': 1,
#          '고즈넉': 1,
#          '고지': 1,
#          '고지서': 1,
#          '고집': 1,
#          '고창': 1,
#          '고첨': 1,
#          '고체': 1,
#          '고촌읍': 1,
#          '고추': 1,
#          '고추밭': 1,
#          '고추장': 1,
#          '고춧가루': 1,
#          '고치': 1,
#          '고품질': 1,
#          '고프': 1,
#          '고하': 1,
#          '고한': 1,
#          '고현': 1,
#          '고혜진': 1,
#          '곡물': 1,
#          '곡성': 1,
#          '곡식': 1,
#          '곤란': 1,
#          '곤약': 1,
#          '곤지암': 1,
#          '골': 1,
#          '골드': 1,
#          '골든벨': 1,
#          '곰': 1,
#          '곰돌이': 1,
#          '곰보': 1,
#          '곰팡이': 1,
#          '곱': 1,
#          '곳곳': 1,
#          '공': 1,
#          '공간': 1,
#          '공갈빵': 1,
#          '공개': 1,
#          '공구': 1,
#          '공급': 1,
#          '공기': 1,
#          '공기주머니': 1,
#          '공덕': 1,
#          '공략': 1,
#          '공룡': 1,
#          '공립': 1,
#          '공방': 1,
#          '공부': 1,
#          '공부방': 1,
#          '공산품': 1,
#          '공수': 1,
#          '공식': 1,
#          '공신': 1,
#          '공업': 1,
#          '공연': 1,
#          '공영주': 1,
#          '공예': 1,
#          '공원': 1,
#          '공유': 1,
#          '공임': 1,
#          '공작': 1,
#          '공장': 1,
#          '공정': 1,
#          '공존': 1,
#          '공주': 1,
#          '공통': 1,
#          '공판': 1,
#          '공포': 1,
#          '곶감': 1,
#          '과': 1,
#          '과감': 1,
#          '과당': 1,
#          '과도': 1,
#          '과류': 1,
#          '과목': 1,
#          '과일': 1,
#          '과자': 1,
#          '과자점': 1,
#          '과장': 1,
#          '과정': 1,
#          '과제': 1,
#          '과채류': 1,
#          '과천': 1,
#          '과하': 1,
#          '관건': 1,
#          '관계': 1,
#          '관계없': 1,
#          '관광': 1,
#          '관련': 1,
#          '관리': 1,
#          '관심': 1,
#          '관심사': 1,
#          '관악구': 1,
#          '관용': 1,
#          '관하': 1,
#          '광명': 1,
#          '광명시': 1,
#          '광주': 1,
#          '광진구': 1,
#          '광택': 1,
#          '광파': 1,
#          '괜찮': 1,
#          '괴': 1,
#          '괴롭히': 1,
#          '교': 1,
#          '교동': 1,
#          '교실': 1,
#          '교육': 1,
#          '교육청': 1,
#          '교체': 1,
#          '교환': 1,
#          '교환원': 1,
#          '교회': 1,
#          '구경': 1,
#          '구교': 1,
#          '구기자': 1,
#          '구나': 1,
#          '구대': 1,
#          '구두': 1,
#          '구라': 1,
#          '구래': 1,
#          '구로': 1,
#          '구르': 1,
#          '구름': 1,
#          '구리': 1,
#          '구마': 1,
#          '구매처': 1,
#          '구멍': 1,
#          '구묘': 1,
#          '구민': 1,
#          '구방': 1,
#          '구분': 1,
#          '구비': 1,
#          '구성': 1,
#          '구성역': 1,
#          '구세트': 1,
#          '구수': 1,
#          '구슬': 1,
#          '구어': 1,
#          '구여': 1,
#          '구연산': 1,
#          '구용': 1,
#          '구우': 1,
#          '구월동': 1,
#          '구음': 1,
#          '구이': 1,
#          '구정': 1,
#          '구제': 1,
#          '구조': 1,
#          '구지': 1,
#          '구찮': 1,
#          '구체': 1,
#          '구토증': 1,
#          '구포': 1,
#          '구하': 1,
#          '구황': 1,
#          '국': 1,
#          '국가': 1,
#          '국간': 1,
#          '국내': 1,
#          '국내산': 1,
#          '국물': 1,
#          '국민': 1,
#          '국산': 1,
#          '국수': 1,
#          '국제': 1,
#          '군': 1,
#          '군것질': 1,
#          '군고구마': 1,
#          '군더더기': 1,
#          '군데군데': 1,
#          '군사': 1,
#          '군산': 1,
#          '군수': 1,
#          '군요': 1,
#          '군침': 1,
#          '군포': 1,
#          '굳': 1,
#          '굳히': 1,
#          '굳히기': 1,
#          '굴': 1,
#          '굴뚝같': 1,
#          '굴러다니': 1,
#          '굴리': 1,
#          '굴림': 1,
#          '굵': 1,
#          '굵기': 1,
#          '굽': 1,
#          '굽지': 1,
#          '굿': 1,
#          '굿바이': 1,
#          '궁': 1,
#          '궁굼': 1,
#          '궁금': 1,
#          '궁금증': 1,
#          '궁중': 1,
#          '궁합': 1,
#          '궈': 1,
#          '권': 1,
#          '권장': 1,
#          '권하': 1,
#          '권해': 1,
#          '귀': 1,
#          '귀가': 1,
#          '귀국': 1,
#          '귀리': 1,
#          '귀염': 1,
#          '귀염둥이': 1,
#          '귀엽': 1,
#          '귀요': 1,
#          '귀요미': 1,
#          '귀욤': 1,
#          '귀족': 1,
#          '귀찮': 1,
#          '귀채': 1,
#          '귀하': 1,
#          '규': 1,
#          '규칙': 1,
#          '균': 1,
#          '균등': 1,
#          '균일': 1,
#          '균형': 1,
#          '귤정과': 1,
#          '그간': 1,
#          '그동안': 1,
#          '그때': 1,
#          '그라': 1,
#          '그람': 1,
#          '그램': 1,
#          '그러': 1,
#          '그럴싸': 1,
#          '그럴싸하': 1,
#          '그렇': 1,
#          '그레': 1,
#          '그레이': 1,
#          '그레인': 1,
#          '그르': 1,
#          '그릇': 1,
#          '그리': 1,
#          '그리니': 1,
#          '그리워지': 1,
#          '그릭': 1,
#          '그릴': 1,
#          '그림': 1,
#          '그립': 1,
#          '그만': 1,
#          '그만두': 1,
#          '그물': 1,
#          '그어주': 1,
#          '그으르': 1,
#          '그윽': 1,
#          '그을리': 1,
#          '그저께': 1,
#          '그중': 1,
#          '극': 1,
#          '극대': 1,
#          '극동': 1,
#          '극복': 1,
#          '극소량': 1,
#          '극장': 1,
#          '극찬': 1,
#          '근': 1,
#          '근교': 1,
#          '근디': 1,
#          '근래': 1,
#          '근무': 1,
#          '근방': 1,
#          '근원': 1,
#          '근육': 1,
#          '근전': 1,
#          '근처': 1,
#          '근황': 1,
#          '글구': 1,
#          '글라스': 1,
#          '글레이즈': 1,
#          '글루텐': 1,
#          '글리': 1,
#          '글쓰기': 1,
#          '긁': 1,
#          '긁어모으': 1,
#          '금': 1,
#          '금가루': 1,
#          '금값': 1,
#          '금강': 1,
#          '금고': 1,
#          '금과': 1,
#          '금귤': 1,
#          '금단': 1,
#          '금딱지': 1,
#          '금라': 1,
#          '금물': 1,
#          '금산': 1,
#          '금새': 1,
#          '금색': 1,
#          '금식': 1,
#          '금싸라기': 1,
#          '금액': 1,
#          '금양': 1,
#          '금영': 1,
#          '금요일': 1,
#          '금음': 1,
#          '금지': 1,
#          '금지령': 1,
#          '금체': 1,
#          '금촌': 1,
#          '급': 1,
#          '급격': 1,
#          '급급': 1,
#          '급식': 1,
#          '급증': 1,
#          '급초': 1,
#          '급하': 1,
#          '기간': 1,
#          '기검': 1,
#          '기겁': 1,
#          '기계': 1,
#          '기계식': 1,
#          '기공': 1,
#          '기관': 1,
#          '기기': 1,
#          '기네스': 1,
#          '기념': 1,
#          '기념일': 1,
#          '기능': 1,
#          '기능사': 1,
#          '기다': 1,
#          '기다리': 1,
#          '기대': 1,
#          '기대감': 1,
#          '기도': 1,
#          '기두': 1,
#          '기똥차': 1,
#          '기로': 1,
#          '기록': 1,
#          '기르': 1,
#          '기름': 1,
#          '기름기': 1,
#          '기름지': 1,
#          '기름칠': 1,
#          '기막히': 1,
#          '기모': 1,
#          '기본': 1,
#          '기부': 1,
#          '기분': 1,
#          '기쁘': 1,
#          '기쁨': 1,
#          '기사': 1,
#          '기상': 1,
#          '기세': 1,
#          '기숙사': 1,
#          '기술': 1,
#          '기술자': 1,
#          '기스': 1,
#          '기야마': 1,
#          '기약': 1,
#          '기억': 1,
#          '기억나': 1,
#          '기업': 1,
#          '기여': 1,
#          '기예': 1,
#          '기운': 1,
#          '기울어지': 1,
#          '기웃거리': 1,
#          '기원': 1,
#          '기유': 1,
#          '기입': 1,
#          '기재': 1,
#          '기저귀': 1,
#          '기전': 1,
#          '기정떡': 1,
#          '기존': 1,
#          '기준': 1,
#          '기질': 1,
#          '기차': 1,
#          '기철': 1,
#          '기청': 1,
#          '기초': 1,
#          '기침': 1,
#          '기타': 1,
#          '기특': 1,
#          '기포': 1,
#          '기피': 1,
#          '기한': 1,
#          '기호': 1,
#          '기회': 1,
#          '기흥': 1,
#          '긴장': 1,
#          '긷': 1,
#          '길': 1,
#          '길거리': 1,
#          '길다랗': 1,
#          '길들이': 1,
#          '길목': 1,
#          '길이': 1,
#          '길쭉': 1,
#          '김': 1,
#          '김경진': 1,
#          '김밥': 1,
#          '김성훈': 1,
#          '김식': 1,
#          '김영모': 1,
#          '김장': 1,
#          '김재민': 1,
#          '김제': 1,
#          '김진환': 1,
#          '김치': 1,
#          '김치전': 1,
#          '김치찌개': 1,
#          '김태하': 1,
#          '김포': 1,
#          '김포시': 1,
#          '김해': 1,
#          '김해시': 1,
#          '깁': 1,
#          '깃': 1,
#          '깊': 1,
#          '깊이': 1,
#          '까': 1,
#          '까까': 1,
#          '까끼': 1,
#          '까다롭': 1,
#          '까르푸': 1,
#          '까맣': 1,
#          '까먹': 1,
#          '까묵': 1,
#          '까스': 1,
#          '까슬까슬': 1,
#          '까지': 1,
#          '까페': 1,
#          '깍둑썰기': 1,
#          '깍뚝': 1,
#          '깍지': 1,
#          '깎': 1,
#          '깐깐': 1,
#          '깔': 1,
#          '깔끔': 1,
#          '깔때기': 1,
#          '깔리': 1,
#          '깜': 1,
#          '깜놀': 1,
#          '깜빡하': 1,
#          '깜장': 1,
#          '깨': 1,
#          '깨끗': 1,
#          '깨달': 1,
#          '깨닳': 1,
#          '깨물': 1,
#          '깨소금': 1,
#          '깨알': 1,
#          '깨우': 1,
#          '깨우치': 1,
#          '깨지': 1,
#          '깻잎': 1,
#          '꺼': 1,
#          '꺼내': 1,
#          '꺼리': 1,
#          '꺼분': 1,
#          '꺼지': 1,
#          '꺽': 1,
#          '꺾이': 1,
#          '껄': 1,
#          '껍닥': 1,
#          '껍질': 1,
#          '께': 1,
#          '꼬': 1,
#          '꼬깔콘': 1,
#          '꼬꼬': 1,
#          '꼬꼬마': 1,
#          '꼬끄': 1,
#          '꼬리': 1,
#          '꼬마': 1,
#          '꼬맹이': 1,
#          '꼬미': 1,
#          '꼬우': 1,
#          '꼬지': 1,
#          '꼬집': 1,
#          '꼬치': 1,
#          '꼭다리': 1,
#          '꼭대기': 1,
#          '꼴': 1,
#          '꼴배': 1,
#          '꼼꼼': 1,
#          '꼽': 1,
#          '꼽히': 1,
#          '꼿': 1,
#          '꽁': 1,
#          '꽂': 1,
#          '꽂히': 1,
#          '꽃': 1,
#          '꽃가위': 1,
#          '꽃게': 1,
#          '꽃단장': 1,
#          '꽃담': 1,
#          '꽃말': 1,
#          '꽃밭': 1,
#          '꽃샘추위': 1,
#          '꽃잎': 1,
#          '꽃장식': 1,
#          '꽃차': 1,
#          '꽃피': 1,
#          '꽈배기': 1,
#          '꽝': 1,
#          '꾀돌이': 1,
#          '꾸': 1,
#          '꾸리': 1,
#          '꾸미': 1,
#          '꾸준': 1,
#          '꿀': 1,
#          '꿀떡': 1,
#          '꿀맛': 1,
#          '꿈': 1,
#          '꿈꾸': 1,
#          '꿉': 1,
#          '꿰': 1,
#          '끄': 1,
#          '끈': 1,
#          '끈기': 1,
#          '끈끈': 1,
#          '끊': 1,
#          '끊기': 1,
#          '끌': 1,
#          '끌레르': 1,
#          '끌레어': 1,
#          '끌리': 1,
#          '끓': 1,
#          '끓이': 1,
#          '끗': 1,
#          '끝나': 1,
#          '끝내': 1,
#          '끝전': 1,
#          '끼니': 1,
#          '끼식': 1,
#          '끼양': 1,
#          '끼얹': 1,
#          '끼우': 1,
#          '낌': 1,
#          '낌새': 1,
#          '나가': 1,
#          '나가사키': 1,
#          '나기': 1,
#          '나누': 1,
#          '나뉘': 1,
#          '나당': 1,
#          '나두': 1,
#          ...})

# %%
print(c.most_common(100))
# Out:
# [('ㄱ', 1), ('ㄴ', 1), ('ㄷ', 1), ('ㄹ', 1), ('ㅁ', 1), ('ㅂ', 1), ('ㅅ', 1), ('ㅈ', 1), ('ㅓ', 1), ('ㅣ', 1), ('單糖', 1), ('外', 1), ('愛', 1), ('有', 1), ('疏', 1), ('米', 1), ('가감', 1), ('가게', 1), ('가격', 1), ('가격대', 1), ('가공', 1), ('가공품', 1), ('가구', 1), ('가까우', 1), ('가깝', 1), ('가나', 1), ('가난', 1), ('가능', 1), ('가닉', 1), ('가동', 1), ('가득', 1), ('가득차', 1), ('가든', 1), ('가라앉', 1), ('가라앉히', 1), ('가람', 1), ('가래', 1), ('가래떡', 1), ('가량', 1), ('가렵', 1), ('가로', 1), ('가루', 1), ('가루다', 1), ('가루라', 1), ('가루소금', 1), ('가루아', 1), ('가루체', 1), ('가르', 1), ('가르치', 1), ('가르키', 1), ('가리', 1), ('가리키', 1), ('가마솥', 1), ('가망', 1), ('가물', 1), ('가뭄', 1), ('가미', 1), ('가방', 1), ('가베', 1), ('가벼우', 1), ('가볍', 1), ('가보세요', 1), ('가성', 1), ('가수', 1), ('가스', 1), ('가스레인지', 1), ('가슴', 1), ('가슴살', 1), ('가습', 1), ('가시', 1), ('가심', 1), ('가아', 1), ('가열', 1), ('가염', 1), ('가요제', 1), ('가용', 1), ('가운', 1), ('가운데', 1), ('가위', 1), ('가을', 1), ('가이드', 1), ('가입', 1), ('가자미', 1), ('가전제품', 1), ('가정', 1), ('가져가', 1), ('가져다주', 1), ('가져오', 1), ('가족', 1), ('가좌리', 1), ('가즈', 1), ('가토', 1), ('가평', 1), ('가현', 1), ('각각', 1), ('각광', 1), ('각봉', 1), ('각설탕', 1), ('각자', 1), ('각종', 1)]
