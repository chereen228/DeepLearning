# %% [markdown]
# # 원, 삼각형, 사각형 구분하기
# - 어려운 테스트 문제를 데이터 부풀리기를 이용한 경우

# %%
import numpy as np 
import tensorflow as tf 
seed = 2021 
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ### 데이터셋 부풀리기

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1/255.0,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.5,
    zoom_range=[0.8, 2.0],      # [하한선, 상한선]
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# %%
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
img = load_img('hard_handwriting_shape/train/triangle/triangle001.png')
x = img_to_array(img)               # 이미지를 array로 변경
x = x.reshape((1,) + x.shape)       # img를 4차원으로

# %%
아래 .flow() 함수는 임의 변환된 이미지를 배치 단위로 생성해서
# 지정된 `preview/` 폴더에 저장합니다.
i = 0
for batch in train_datagen.flow(x, batch_size=1, save_to_dir='preview', 
                                save_prefix='tri', save_format='png'):
    i += 1
    if i > 20:
        break

# %%
train_generator = train_datagen.flow_from_directory(
    'hard_handwriting_shape/train',
    target_size=(24,24), 
    batch_size=3,
    class_mode='categorical'
)
# Out:
# Found 45 images belonging to 3 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1/255.)
test_generator = test_datagen.flow_from_directory(
    'hard_handwriting_shape/test',
    target_size=(24,24),
    batch_size=3,
    class_mode='categorical'
)
# Out:
# Found 15 images belonging to 3 classes.

# %% [markdown]
# ### 모델 정의/설정/학습

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
model = Sequential([
    Conv2D(32, (3,3), input_shape=(24,24,3), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 22, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               819328
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 839,107
# Trainable params: 839,107
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']
)

# %% [markdown]
# ### 모델 학습
# - 첫번째 인자 : 훈련데이터셋을 제공할 제네레이터를 지정. 본 예제에서는 앞서 생성한 train_generator으로 지정.
# - steps_per_epoch : 한 epoch에 사용한 스텝 수를 지정. 총 45개의 훈련 샘플이 있고 배치사이즈가 3이므로 15 스텝으로 지정. 데이터 부풀리기를 이용하여 100개씩 사용
# - epochs : 전체 훈련 데이터셋에 대해 학습 반복 횟수를 지정. 50번을 반복적으로 학습.
# - validation_data : 검증데이터셋을 제공할 제네레이터를 지정. 본 예제에서는 앞서 생성한 test_generator으로 지정.
# - validation_steps : 한 epoch 종료 시 마다 검증할 때 사용되는 검증 스텝 수를 지정. 총 15개의 검증 샘플이 있고 배치사이즈가 3이므로 5 스텝으로 지정.

# %%
model.fit(
        train_generator,
        steps_per_epoch=15,
        epochs=200,
        validation_data=test_generator,
        validation_steps=5,
        verbose=2
)
# Out:
# 5/15 - 0s - loss: 1.0859 - accuracy: 0.3556 - val_loss: 1.0826 - val_accuracy: 0.6667
# Epoch 3/200
# 15/15 - 0s - loss: 1.0373 - accuracy: 0.5333 - val_loss: 1.0637 - val_accuracy: 0.6667
# Epoch 4/200
# 15/15 - 0s - loss: 0.9285 - accuracy: 0.5778 - val_loss: 1.1412 - val_accuracy: 0.4000
# Epoch 5/200
# 15/15 - 0s - loss: 0.8487 - accuracy: 0.5111 - val_loss: 1.1248 - val_accuracy: 0.5333
# Epoch 6/200
# 15/15 - 0s - loss: 0.6448 - accuracy: 0.6889 - val_loss: 1.5534 - val_accuracy: 0.6000
# Epoch 7/200
# 15/15 - 0s - loss: 0.5578 - accuracy: 0.7333 - val_loss: 1.6218 - val_accuracy: 0.5333
# Epoch 8/200
# 15/15 - 0s - loss: 0.5738 - accuracy: 0.7556 - val_loss: 1.0350 - val_accuracy: 0.6000
# Epoch 9/200
# 15/15 - 0s - loss: 0.4904 - accuracy: 0.7333 - val_loss: 1.6793 - val_accuracy: 0.5333
# Epoch 10/200
# 15/15 - 0s - loss: 0.4579 - accuracy: 0.8444 - val_loss: 1.7563 - val_accuracy: 0.5333
# Epoch 11/200
# 15/15 - 0s - loss: 0.3622 - accuracy: 0.8667 - val_loss: 1.1146 - val_accuracy: 0.6667
# Epoch 12/200
# 15/15 - 0s - loss: 0.3873 - accuracy: 0.8667 - val_loss: 1.0242 - val_accuracy: 0.6000
# Epoch 13/200
# 15/15 - 0s - loss: 0.2124 - accuracy: 0.9556 - val_loss: 1.6023 - val_accuracy: 0.4667
# Epoch 14/200
# 15/15 - 0s - loss: 0.1241 - accuracy: 1.0000 - val_loss: 1.5405 - val_accuracy: 0.6667
# Epoch 15/200
# 15/15 - 0s - loss: 0.4796 - accuracy: 0.8667 - val_loss: 1.3051 - val_accuracy: 0.6667
# Epoch 16/200
# 15/15 - 0s - loss: 0.1848 - accuracy: 0.9556 - val_loss: 1.4351 - val_accuracy: 0.6000
# Epoch 17/200
# 15/15 - 0s - loss: 0.1072 - accuracy: 0.9778 - val_loss: 1.3953 - val_accuracy: 0.6000
# Epoch 18/200
# 15/15 - 0s - loss: 0.2774 - accuracy: 0.8889 - val_loss: 1.5455 - val_accuracy: 0.5333
# Epoch 19/200
# 15/15 - 0s - loss: 0.1696 - accuracy: 0.9778 - val_loss: 1.8655 - val_accuracy: 0.6000
# Epoch 20/200
# 15/15 - 0s - loss: 0.0404 - accuracy: 1.0000 - val_loss: 2.1308 - val_accuracy: 0.5333
# Epoch 21/200
# 15/15 - 0s - loss: 0.1647 - accuracy: 0.9111 - val_loss: 2.0529 - val_accuracy: 0.5333
# Epoch 22/200
# 15/15 - 0s - loss: 0.1202 - accuracy: 0.9556 - val_loss: 1.7437 - val_accuracy: 0.6667
# Epoch 23/200
# 15/15 - 0s - loss: 0.0534 - accuracy: 1.0000 - val_loss: 2.4278 - val_accuracy: 0.6000
# Epoch 24/200
# 15/15 - 0s - loss: 0.0327 - accuracy: 1.0000 - val_loss: 2.7849 - val_accuracy: 0.4667
# Epoch 25/200
# 15/15 - 0s - loss: 0.1161 - accuracy: 0.9778 - val_loss: 2.8517 - val_accuracy: 0.5333
# Epoch 26/200
# 15/15 - 0s - loss: 0.1074 - accuracy: 0.9556 - val_loss: 2.7134 - val_accuracy: 0.5333
# Epoch 27/200
# 15/15 - 0s - loss: 0.1253 - accuracy: 0.9556 - val_loss: 2.3617 - val_accuracy: 0.5333
# Epoch 28/200
# 15/15 - 0s - loss: 0.0921 - accuracy: 0.9778 - val_loss: 2.6312 - val_accuracy: 0.5333
# Epoch 29/200
# 15/15 - 0s - loss: 0.1724 - accuracy: 0.9778 - val_loss: 3.4692 - val_accuracy: 0.6000
# Epoch 30/200
# 15/15 - 0s - loss: 0.0589 - accuracy: 0.9778 - val_loss: 2.0676 - val_accuracy: 0.6667
# Epoch 31/200
# 15/15 - 0s - loss: 0.2525 - accuracy: 0.9333 - val_loss: 1.9129 - val_accuracy: 0.7333
# Epoch 32/200
# 15/15 - 0s - loss: 0.1596 - accuracy: 0.9778 - val_loss: 2.0376 - val_accuracy: 0.6000
# Epoch 33/200
# 15/15 - 0s - loss: 0.0871 - accuracy: 0.9556 - val_loss: 1.8937 - val_accuracy: 0.6667
# Epoch 34/200
# 15/15 - 0s - loss: 0.1077 - accuracy: 0.9333 - val_loss: 1.8848 - val_accuracy: 0.7333
# Epoch 35/200
# 15/15 - 0s - loss: 0.1231 - accuracy: 0.9556 - val_loss: 1.6241 - val_accuracy: 0.7333
# Epoch 36/200
# 15/15 - 0s - loss: 0.0534 - accuracy: 1.0000 - val_loss: 2.0875 - val_accuracy: 0.6000
# Epoch 37/200
# 15/15 - 0s - loss: 0.1696 - accuracy: 0.9556 - val_loss: 2.1115 - val_accuracy: 0.6667
# Epoch 38/200
# 15/15 - 0s - loss: 0.1287 - accuracy: 0.9333 - val_loss: 2.4736 - val_accuracy: 0.6667
# Epoch 39/200
# 15/15 - 0s - loss: 0.0590 - accuracy: 0.9778 - val_loss: 2.4782 - val_accuracy: 0.6667
# Epoch 40/200
# 15/15 - 0s - loss: 0.0731 - accuracy: 0.9778 - val_loss: 2.3117 - val_accuracy: 0.6667
# Epoch 41/200
# 15/15 - 0s - loss: 0.1330 - accuracy: 0.9556 - val_loss: 2.1042 - val_accuracy: 0.6667
# Epoch 42/200
# 15/15 - 0s - loss: 0.1186 - accuracy: 0.9556 - val_loss: 2.1234 - val_accuracy: 0.6667
# Epoch 43/200
# 15/15 - 0s - loss: 0.1576 - accuracy: 0.9333 - val_loss: 2.1385 - val_accuracy: 0.6000
# Epoch 44/200
# 15/15 - 0s - loss: 0.0997 - accuracy: 0.9111 - val_loss: 2.0897 - val_accuracy: 0.6000
# Epoch 45/200
# 15/15 - 0s - loss: 0.2618 - accuracy: 0.9111 - val_loss: 1.3973 - val_accuracy: 0.6667
# Epoch 46/200
# 15/15 - 0s - loss: 0.0280 - accuracy: 1.0000 - val_loss: 1.5073 - val_accuracy: 0.6667
# Epoch 47/200
# 15/15 - 0s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 1.7793 - val_accuracy: 0.6667
# Epoch 48/200
# 15/15 - 0s - loss: 0.0483 - accuracy: 0.9778 - val_loss: 1.7156 - val_accuracy: 0.6667
# Epoch 49/200
# 15/15 - 0s - loss: 0.0613 - accuracy: 0.9778 - val_loss: 1.5187 - val_accuracy: 0.7333
# Epoch 50/200
# 15/15 - 0s - loss: 0.0244 - accuracy: 1.0000 - val_loss: 1.6287 - val_accuracy: 0.7333
# Epoch 51/200
# 15/15 - 0s - loss: 0.0412 - accuracy: 0.9778 - val_loss: 1.6613 - val_accuracy: 0.7333
# Epoch 52/200
# 15/15 - 0s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 1.6412 - val_accuracy: 0.7333
# Epoch 53/200
# 15/15 - 0s - loss: 0.0129 - accuracy: 1.0000 - val_loss: 1.7146 - val_accuracy: 0.7333
# Epoch 54/200
# 15/15 - 0s - loss: 0.0169 - accuracy: 1.0000 - val_loss: 1.6905 - val_accuracy: 0.7333
# Epoch 55/200
# 15/15 - 0s - loss: 0.0963 - accuracy: 0.9778 - val_loss: 2.5645 - val_accuracy: 0.7333
# Epoch 56/200
# 15/15 - 0s - loss: 0.0471 - accuracy: 0.9778 - val_loss: 2.4758 - val_accuracy: 0.6000
# Epoch 57/200
# 15/15 - 0s - loss: 0.0837 - accuracy: 0.9778 - val_loss: 1.6557 - val_accuracy: 0.6667
# Epoch 58/200
# 15/15 - 0s - loss: 0.1002 - accuracy: 0.9333 - val_loss: 1.4790 - val_accuracy: 0.7333
# Epoch 59/200
# 15/15 - 0s - loss: 0.0464 - accuracy: 0.9778 - val_loss: 2.1231 - val_accuracy: 0.6667
# Epoch 60/200
# 15/15 - 0s - loss: 0.2819 - accuracy: 0.8889 - val_loss: 1.5782 - val_accuracy: 0.7333
# Epoch 61/200
# 15/15 - 0s - loss: 0.0801 - accuracy: 0.9778 - val_loss: 3.4948 - val_accuracy: 0.4000
# Epoch 62/200
# 15/15 - 0s - loss: 0.0498 - accuracy: 0.9778 - val_loss: 3.1146 - val_accuracy: 0.6000
# Epoch 63/200
# 15/15 - 0s - loss: 0.0350 - accuracy: 1.0000 - val_loss: 2.9196 - val_accuracy: 0.5333
# Epoch 64/200
# 15/15 - 0s - loss: 0.0843 - accuracy: 0.9778 - val_loss: 2.4094 - val_accuracy: 0.7333
# Epoch 65/200
# 15/15 - 0s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 3.6254 - val_accuracy: 0.5333
# Epoch 66/200
# 15/15 - 0s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 3.5729 - val_accuracy: 0.5333
# Epoch 67/200
# 15/15 - 0s - loss: 0.0438 - accuracy: 0.9778 - val_loss: 1.9179 - val_accuracy: 0.7333
# Epoch 68/200
# 15/15 - 0s - loss: 0.0564 - accuracy: 0.9556 - val_loss: 2.2857 - val_accuracy: 0.6667
# Epoch 69/200
# 15/15 - 0s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 2.7749 - val_accuracy: 0.6000
# Epoch 70/200
# 15/15 - 0s - loss: 0.1333 - accuracy: 0.9333 - val_loss: 2.8986 - val_accuracy: 0.6000
# Epoch 71/200
# 15/15 - 0s - loss: 0.1196 - accuracy: 0.9556 - val_loss: 2.1450 - val_accuracy: 0.7333
# Epoch 72/200
# 15/15 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.2369 - val_accuracy: 0.8000
# Epoch 73/200
# 15/15 - 0s - loss: 0.0254 - accuracy: 1.0000 - val_loss: 1.3513 - val_accuracy: 0.8000
# Epoch 74/200
# 15/15 - 0s - loss: 0.0343 - accuracy: 0.9778 - val_loss: 1.9181 - val_accuracy: 0.7333
# Epoch 75/200
# 15/15 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.9982 - val_accuracy: 0.7333
# Epoch 76/200
# 15/15 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.8035 - val_accuracy: 0.7333
# Epoch 77/200
# 15/15 - 0s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 1.7494 - val_accuracy: 0.7333
# Epoch 78/200
# 15/15 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 2.0068 - val_accuracy: 0.7333
# Epoch 79/200
# 15/15 - 0s - loss: 0.1099 - accuracy: 0.9778 - val_loss: 1.8595 - val_accuracy: 0.7333
# Epoch 80/200
# 15/15 - 0s - loss: 0.0657 - accuracy: 0.9778 - val_loss: 1.6456 - val_accuracy: 0.7333
# Epoch 81/200
# 15/15 - 0s - loss: 0.0211 - accuracy: 1.0000 - val_loss: 1.8867 - val_accuracy: 0.7333
# Epoch 82/200
# 15/15 - 0s - loss: 0.0207 - accuracy: 1.0000 - val_loss: 3.2568 - val_accuracy: 0.6000
# Epoch 83/200
# 15/15 - 0s - loss: 0.0649 - accuracy: 0.9778 - val_loss: 3.2030 - val_accuracy: 0.6000
# Epoch 84/200
# 15/15 - 0s - loss: 0.1284 - accuracy: 0.9556 - val_loss: 2.3258 - val_accuracy: 0.6000
# Epoch 85/200
# 15/15 - 0s - loss: 0.0425 - accuracy: 0.9778 - val_loss: 1.9407 - val_accuracy: 0.7333
# Epoch 86/200
# 15/15 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 2.1542 - val_accuracy: 0.7333
# Epoch 87/200
# 15/15 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 2.4412 - val_accuracy: 0.7333
# Epoch 88/200
# 15/15 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 3.0231 - val_accuracy: 0.6000
# Epoch 89/200
# 15/15 - 0s - loss: 0.0530 - accuracy: 0.9778 - val_loss: 2.8857 - val_accuracy: 0.6667
# Epoch 90/200
# 15/15 - 0s - loss: 0.0433 - accuracy: 0.9778 - val_loss: 2.4811 - val_accuracy: 0.7333
# Epoch 91/200
# 15/15 - 0s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 2.1526 - val_accuracy: 0.8000
# Epoch 92/200
# 15/15 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 2.2579 - val_accuracy: 0.8000
# Epoch 93/200
# 15/15 - 0s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 2.4100 - val_accuracy: 0.7333
# Epoch 94/200
# 15/15 - 0s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 2.7100 - val_accuracy: 0.6667
# Epoch 95/200
# 15/15 - 0s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 3.1277 - val_accuracy: 0.6000
# Epoch 96/200
# 15/15 - 0s - loss: 6.1178e-04 - accuracy: 1.0000 - val_loss: 3.5069 - val_accuracy: 0.6000
# Epoch 97/200
# 15/15 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.5952 - val_accuracy: 0.6000
# Epoch 98/200
# 15/15 - 0s - loss: 2.0239e-04 - accuracy: 1.0000 - val_loss: 3.5995 - val_accuracy: 0.6000
# Epoch 99/200
# 15/15 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.5727 - val_accuracy: 0.6000
# Epoch 100/200
# 15/15 - 0s - loss: 0.0642 - accuracy: 0.9778 - val_loss: 3.2338 - val_accuracy: 0.6000
# Epoch 101/200
# 15/15 - 0s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 2.2224 - val_accuracy: 0.8000
# Epoch 102/200
# 15/15 - 0s - loss: 0.0641 - accuracy: 0.9556 - val_loss: 3.5821 - val_accuracy: 0.5333
# Epoch 103/200
# 15/15 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 4.7521 - val_accuracy: 0.5333
# Epoch 104/200
# 15/15 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 4.0339 - val_accuracy: 0.6000
# Epoch 105/200
# 15/15 - 0s - loss: 3.8513e-04 - accuracy: 1.0000 - val_loss: 3.3417 - val_accuracy: 0.6667
# Epoch 106/200
# 15/15 - 0s - loss: 0.0354 - accuracy: 0.9556 - val_loss: 3.3518 - val_accuracy: 0.7333
# Epoch 107/200
# 15/15 - 0s - loss: 0.1544 - accuracy: 0.9556 - val_loss: 3.4686 - val_accuracy: 0.5333
# Epoch 108/200
# 15/15 - 0s - loss: 0.0428 - accuracy: 0.9778 - val_loss: 4.2835 - val_accuracy: 0.5333
# Epoch 109/200
# 15/15 - 0s - loss: 0.0853 - accuracy: 0.9556 - val_loss: 4.7809 - val_accuracy: 0.5333
# Epoch 110/200
# 15/15 - 0s - loss: 0.0764 - accuracy: 0.9778 - val_loss: 4.0468 - val_accuracy: 0.6667
# Epoch 111/200
# 15/15 - 0s - loss: 0.1474 - accuracy: 0.9333 - val_loss: 1.7271 - val_accuracy: 0.8000
# Epoch 112/200
# 15/15 - 0s - loss: 0.1890 - accuracy: 0.9333 - val_loss: 1.9009 - val_accuracy: 0.7333
# Epoch 113/200
# 15/15 - 0s - loss: 0.1769 - accuracy: 0.9333 - val_loss: 1.4855 - val_accuracy: 0.7333
# Epoch 114/200
# 15/15 - 0s - loss: 0.0439 - accuracy: 1.0000 - val_loss: 1.8697 - val_accuracy: 0.7333
# Epoch 115/200
# 15/15 - 0s - loss: 0.0260 - accuracy: 1.0000 - val_loss: 2.7275 - val_accuracy: 0.6667
# Epoch 116/200
# 15/15 - 0s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 2.8785 - val_accuracy: 0.6667
# Epoch 117/200
# 15/15 - 0s - loss: 0.0813 - accuracy: 0.9556 - val_loss: 2.9059 - val_accuracy: 0.6667
# Epoch 118/200
# 15/15 - 0s - loss: 0.0343 - accuracy: 0.9778 - val_loss: 2.1390 - val_accuracy: 0.8000
# Epoch 119/200
# 15/15 - 0s - loss: 0.1229 - accuracy: 0.9556 - val_loss: 2.6574 - val_accuracy: 0.7333
# Epoch 120/200
# 15/15 - 0s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 5.3791 - val_accuracy: 0.4667
# Epoch 121/200
# 15/15 - 0s - loss: 0.2036 - accuracy: 0.9556 - val_loss: 3.7581 - val_accuracy: 0.5333
# Epoch 122/200
# 15/15 - 0s - loss: 0.1007 - accuracy: 0.9778 - val_loss: 1.7760 - val_accuracy: 0.8000
# Epoch 123/200
# 15/15 - 0s - loss: 0.0692 - accuracy: 0.9778 - val_loss: 2.0011 - val_accuracy: 0.8000
# Epoch 124/200
# 15/15 - 0s - loss: 0.0408 - accuracy: 0.9778 - val_loss: 2.4148 - val_accuracy: 0.7333
# Epoch 125/200
# 15/15 - 0s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 2.1706 - val_accuracy: 0.8000
# Epoch 126/200
# 15/15 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.0089 - val_accuracy: 0.8000
# Epoch 127/200
# 15/15 - 0s - loss: 0.0237 - accuracy: 1.0000 - val_loss: 2.9099 - val_accuracy: 0.6667
# Epoch 128/200
# 15/15 - 0s - loss: 0.0613 - accuracy: 0.9778 - val_loss: 2.7297 - val_accuracy: 0.6667
# Epoch 129/200
# 15/15 - 0s - loss: 0.0314 - accuracy: 0.9778 - val_loss: 2.8422 - val_accuracy: 0.6667
# Epoch 130/200
# 15/15 - 0s - loss: 0.0894 - accuracy: 0.9556 - val_loss: 2.2046 - val_accuracy: 0.7333
# Epoch 131/200
# 15/15 - 0s - loss: 0.0751 - accuracy: 0.9778 - val_loss: 2.3857 - val_accuracy: 0.7333
# Epoch 132/200
# 15/15 - 0s - loss: 0.0265 - accuracy: 0.9778 - val_loss: 2.7092 - val_accuracy: 0.7333
# Epoch 133/200
# 15/15 - 0s - loss: 0.0385 - accuracy: 0.9778 - val_loss: 2.8502 - val_accuracy: 0.6667
# Epoch 134/200
# 15/15 - 0s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 3.1154 - val_accuracy: 0.6000
# Epoch 135/200
# 15/15 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 3.2453 - val_accuracy: 0.6000
# Epoch 136/200
# 15/15 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.3623 - val_accuracy: 0.5333
# Epoch 137/200
# 15/15 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 3.4814 - val_accuracy: 0.6000
# Epoch 138/200
# 15/15 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 3.4788 - val_accuracy: 0.6000
# Epoch 139/200
# 15/15 - 0s - loss: 0.1299 - accuracy: 0.9556 - val_loss: 4.3268 - val_accuracy: 0.6000
# Epoch 140/200
# 15/15 - 0s - loss: 0.1440 - accuracy: 0.9778 - val_loss: 1.5689 - val_accuracy: 0.7333
# Epoch 141/200
# 15/15 - 0s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 1.6873 - val_accuracy: 0.7333
# Epoch 142/200
# 15/15 - 0s - loss: 0.0441 - accuracy: 0.9778 - val_loss: 2.9713 - val_accuracy: 0.6667
# Epoch 143/200
# 15/15 - 0s - loss: 0.0418 - accuracy: 0.9778 - val_loss: 2.2301 - val_accuracy: 0.7333
# Epoch 144/200
# 15/15 - 0s - loss: 0.0525 - accuracy: 0.9778 - val_loss: 2.5146 - val_accuracy: 0.7333
# Epoch 145/200
# 15/15 - 0s - loss: 0.0802 - accuracy: 0.9778 - val_loss: 3.1872 - val_accuracy: 0.6667
# Epoch 146/200
# 15/15 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 3.5417 - val_accuracy: 0.6667
# Epoch 147/200
# 15/15 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 3.6184 - val_accuracy: 0.6667
# Epoch 148/200
# 15/15 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.6559 - val_accuracy: 0.6667
# Epoch 149/200
# 15/15 - 0s - loss: 7.8523e-04 - accuracy: 1.0000 - val_loss: 3.5309 - val_accuracy: 0.6667
# Epoch 150/200
# 15/15 - 0s - loss: 0.0315 - accuracy: 0.9778 - val_loss: 3.7770 - val_accuracy: 0.6667
# Epoch 151/200
# 15/15 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 4.0810 - val_accuracy: 0.6667
# Epoch 152/200
# 15/15 - 0s - loss: 0.0652 - accuracy: 0.9778 - val_loss: 2.4137 - val_accuracy: 0.8000
# Epoch 153/200
# 15/15 - 0s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 2.9831 - val_accuracy: 0.8000
# Epoch 154/200
# 15/15 - 0s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 3.2952 - val_accuracy: 0.8000
# Epoch 155/200
# 15/15 - 0s - loss: 0.0467 - accuracy: 0.9778 - val_loss: 2.8587 - val_accuracy: 0.8000
# Epoch 156/200
# 15/15 - 0s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 2.8015 - val_accuracy: 0.8000
# Epoch 157/200
# 15/15 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.7941 - val_accuracy: 0.8000
# Epoch 158/200
# 15/15 - 0s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 2.8119 - val_accuracy: 0.8000
# Epoch 159/200
# 15/15 - 0s - loss: 0.0489 - accuracy: 0.9778 - val_loss: 2.8907 - val_accuracy: 0.7333
# Epoch 160/200
# 15/15 - 0s - loss: 0.0365 - accuracy: 1.0000 - val_loss: 4.2164 - val_accuracy: 0.6000
# Epoch 161/200
# 15/15 - 0s - loss: 0.0397 - accuracy: 0.9778 - val_loss: 3.9723 - val_accuracy: 0.6667
# Epoch 162/200
# 15/15 - 0s - loss: 0.0356 - accuracy: 0.9778 - val_loss: 3.1783 - val_accuracy: 0.7333
# Epoch 163/200
# 15/15 - 0s - loss: 0.1069 - accuracy: 0.9778 - val_loss: 4.5219 - val_accuracy: 0.6000
# Epoch 164/200
# 15/15 - 0s - loss: 0.0666 - accuracy: 0.9778 - val_loss: 4.1057 - val_accuracy: 0.6667
# Epoch 165/200
# 15/15 - 0s - loss: 0.0628 - accuracy: 0.9778 - val_loss: 2.5122 - val_accuracy: 0.8000
# Epoch 166/200
# 15/15 - 0s - loss: 0.1423 - accuracy: 0.9778 - val_loss: 2.9977 - val_accuracy: 0.8000
# Epoch 167/200
# 15/15 - 0s - loss: 0.0284 - accuracy: 1.0000 - val_loss: 2.7183 - val_accuracy: 0.8000
# Epoch 168/200
# 15/15 - 0s - loss: 0.0989 - accuracy: 0.9556 - val_loss: 2.2456 - val_accuracy: 0.8000
# Epoch 169/200
# 15/15 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 2.4270 - val_accuracy: 0.8000
# Epoch 170/200
# 15/15 - 0s - loss: 0.0479 - accuracy: 0.9778 - val_loss: 2.3679 - val_accuracy: 0.7333
# Epoch 171/200
# 15/15 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.4226 - val_accuracy: 0.7333
# Epoch 172/200
# 15/15 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.4473 - val_accuracy: 0.7333
# Epoch 173/200
# 15/15 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.4734 - val_accuracy: 0.7333
# Epoch 174/200
# 15/15 - 0s - loss: 0.0668 - accuracy: 0.9778 - val_loss: 2.2436 - val_accuracy: 0.8000
# Epoch 175/200
# 15/15 - 0s - loss: 0.0207 - accuracy: 0.9778 - val_loss: 2.3980 - val_accuracy: 0.7333
# Epoch 176/200
# 15/15 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 2.5087 - val_accuracy: 0.8000
# Epoch 177/200
# 15/15 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.6571 - val_accuracy: 0.8000
# Epoch 178/200
# 15/15 - 0s - loss: 0.0619 - accuracy: 0.9778 - val_loss: 3.0778 - val_accuracy: 0.6667
# Epoch 179/200
# 15/15 - 0s - loss: 0.0490 - accuracy: 0.9556 - val_loss: 2.4464 - val_accuracy: 0.8000
# Epoch 180/200
# 15/15 - 0s - loss: 0.0852 - accuracy: 0.9778 - val_loss: 2.8035 - val_accuracy: 0.7333
# Epoch 181/200
# 15/15 - 0s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 3.3125 - val_accuracy: 0.6667
# Epoch 182/200
# 15/15 - 0s - loss: 0.2988 - accuracy: 0.9556 - val_loss: 1.8809 - val_accuracy: 0.7333
# Epoch 183/200
# 15/15 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 2.1175 - val_accuracy: 0.6667
# Epoch 184/200
# 15/15 - 0s - loss: 0.0244 - accuracy: 1.0000 - val_loss: 1.8036 - val_accuracy: 0.7333
# Epoch 185/200
# 15/15 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.7057 - val_accuracy: 0.7333
# Epoch 186/200
# 15/15 - 0s - loss: 0.0274 - accuracy: 1.0000 - val_loss: 1.8763 - val_accuracy: 0.7333
# Epoch 187/200
# 15/15 - 0s - loss: 0.0834 - accuracy: 0.9556 - val_loss: 1.9756 - val_accuracy: 0.8000
# Epoch 188/200
# 15/15 - 0s - loss: 0.1981 - accuracy: 0.9556 - val_loss: 1.7205 - val_accuracy: 0.8000
# Epoch 189/200
# 15/15 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.7076 - val_accuracy: 0.8000
# Epoch 190/200
# 15/15 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.8437 - val_accuracy: 0.8000
# Epoch 191/200
# 15/15 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 2.2772 - val_accuracy: 0.8000
# Epoch 192/200
# 15/15 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.4319 - val_accuracy: 0.7333
# Epoch 193/200
# 15/15 - 0s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 2.2366 - val_accuracy: 0.8000
# Epoch 194/200
# 15/15 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.1988 - val_accuracy: 0.8000
# Epoch 195/200
# 15/15 - 0s - loss: 6.6332e-04 - accuracy: 1.0000 - val_loss: 2.1963 - val_accuracy: 0.8000
# Epoch 196/200
# 15/15 - 0s - loss: 0.0615 - accuracy: 0.9778 - val_loss: 2.1459 - val_accuracy: 0.7333
# Epoch 197/200
# 15/15 - 0s - loss: 0.0220 - accuracy: 0.9778 - val_loss: 2.4656 - val_accuracy: 0.8000
# Epoch 198/200
# 15/15 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.5874 - val_accuracy: 0.8000
# Epoch 199/200
# 15/15 - 0s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 2.4280 - val_accuracy: 0.8000
# Epoch 200/200
# 15/15 - 0s - loss: 0.0165 - accuracy: 0.9778 - val_loss: 2.2846 - val_accuracy: 0.8000

# %% [markdown]
# ### 모델 평가

# %%
model.evaluate(test_generator, steps=5)
# Out:
# 5/5 [==============================] - 0s 5ms/step - loss: 2.2846 - accuracy: 0.8000
# [2.2846221923828125, 0.800000011920929]
